# %%
#imports
import katdal
import numpy as np
import matplotlib.pylab as plt
import astropy.coordinates as ac
import functools
import healpy as hp
import optparse
import warnings
from matplotlib.backends.backend_pdf import PdfPages
import healpy as hp
from astropy import units as u
from matplotlib.offsetbox import AnchoredText
import time
import pickle
import sys
import katcali
import katcali.visualizer as kv
import katcali.models as km
import katcali.rfi as kr
import katcali.solver as ks
import katcali.io as kio
import katcali.label_dump as kl
import katcali.diode as kd
import katcali.filter as kf
import katcali.beam as kb
from astropy.coordinates import SkyCoord
from astropy import units as u
from scipy.sparse import coo_matrix
import astropy.wcs
from astropy.wcs.utils import skycoord_to_pixel
from astropy.wcs.utils import pixel_to_skycoord
from astropy.io import fits
from astropy.wcs import WCS
from scipy.interpolate import UnivariateSpline
import matplotlib.colors as colors
Tcmb=2.725
k_B = 1.38E-23

# %%
print ('start @ ' + time.asctime(time.localtime(time.time())) +'...')
# Out:
# start @ Mon Feb  6 10:17:09 2023...

# %%
print  (plt.rcParams['font.size'], plt.rcParams[u'axes.linewidth'],plt.rcParams['lines.linewidth'])
plt.rcParams['font.size'], plt.rcParams[u'axes.linewidth'],plt.rcParams['lines.linewidth'] = 14, 1.5, 1.5
#plt.rcParams['font.size'], plt.rcParams[u'axes.linewidth'],plt.rcParams['lines.linewidth'] = 10.0, 0.8, 1.5
print  (plt.rcParams['font.size'], plt.rcParams[u'axes.linewidth'],plt.rcParams['lines.linewidth'])
# Out:
# 10.0 0.8 1.5
# 14.0 1.5 1.5

# %%
pix_deg=0.3 #0.15 #0.3
std_sigma=6. #2023 #the smaller number will make more data be delated 

ch_plot=800

# %%
p_radec=np.loadtxt('radio_source2021.txt')
ptr_pix=np.loadtxt('radio_source2021_pix_'+str(pix_deg)+'deg.txt')
ptr_ra_pix,ptr_dec_pix=ptr_pix[:,0],ptr_pix[:,1]

#input_file='/idia/projects/hi_im/raw_vis/MeerKLASS2021/level5/data/'
input_file='/scratch3/users/jywang/MeerKLASS2021/level5/data/'
output_file='./'

# %%
#fname_list=['1630519596','1631379874','1631387336','1631552188','1631559762','1631659886']

# %%
#'''
fname_list=['1630519596','1631379874','1631387336','1631552188','1631559762','1631659886',
            '1631667564','1631724508','1631732038','1631810671','1631818149','1631982988',
            '1631990463','1632069690','1632077222','1632184922','1632505883','1632760885',
            '1633365980','1633970780','1634252028','1634402485','1634748682','1634835083',
            '1637346562','1637354605','1637691677','1637699408','1638130295','1638294319',
            '1638301944','1638386189','1638639082','1638647186','1638898468','1639157507',
            '1639331184','1639935088','1640540184','1640712986','1640799689']
#'''

# %% [markdown]
# # try to load merged but unfiltered data

# %%
total_count_MAX=966 #114

niter=3 #2023

# %%
pix_ma_ra=[]
pix_ma_dec=[]

for i_iter in range(niter):
    print ('>>>>>>>>> Iteration '+str(i_iter)+' start...')
    
    ####load previous data in########
    try:
        if i_iter==0:#First
            Fits=output_file+'ALL_scan'+str(total_count_MAX)+'_Tresi_cube_p'+str(pix_deg)+'d.fits'
            Tresi_cube = fits.open(Fits)[0].data
            print (np.shape(Tresi_cube))
            #only need to load once###
            Npix_x= np.shape(Tresi_cube)[0]
            Npix_y= np.shape(Tresi_cube)[1]

            w2=WCS(Fits).dropaxis(-1)
            print (w2)
            
            ####mask point sources######    
            map_ra=np.zeros_like(Tresi_cube[:,:,ch_plot])
            map_dec=np.zeros_like(Tresi_cube[:,:,ch_plot])
            for i in range(np.shape(map_ra)[0]):
                for j in range(np.shape(map_ra)[1]):
                    radec=pixel_to_skycoord(i,j,w2)
                    map_ra[i,j]=radec.ra.deg
                    map_dec[i,j]=radec.dec.deg
            p = SkyCoord(map_ra*u.deg,  map_dec*u.deg, frame='icrs')

            for s in range(len(p_radec)):
                p_ra,p_dec=p_radec[s]
                c = SkyCoord(p_ra*u.deg,  p_dec*u.deg, frame='icrs')
                p_ang=(c.separation(p)/u.deg)
                dp_l=np.where(p_ang<1.)
                dp_l=np.array(dp_l)
                pix_ma_ra+=list(dp_l[0])
                pix_ma_dec+=list(dp_l[1])
                
        if i_iter>0: #Since second
            Fits=output_file+'Nscan'+str(total_count)+'_Tresi_cube_p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter-1)+'.fits'
                            
        Tresi_cube = fits.open(Fits)[0].data
        print (np.shape(Tresi_cube))

        plt.figure(figsize=(18,5))
        ax=plt.subplot(projection=w2)
        plt.imshow(Tresi_cube[:,:,ch_plot].T,cmap='jet',aspect='auto')
        plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
        #plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
        plt.colorbar(label='Kelvin')
        plt.xlabel('R. A. (J2000)')
        plt.ylabel('Dec (J2000)')
        plt.xlim([0,Npix_x])
        plt.ylim([0,Npix_y])
        ax.invert_xaxis()
        plt.title('reloaded data')
        plt.show()

        print (np.nanmin(Tresi_cube[:,:,ch_plot]),np.nanmax(Tresi_cube[:,:,ch_plot])) 

        Tresi_cube1=Tresi_cube.copy()
        Tresi_cube1[pix_ma_ra,pix_ma_dec,:]=np.nan
        print (np.nanmean(Tresi_cube1[:,:,ch_plot]),np.nanstd(Tresi_cube1[:,:,ch_plot])) 

        plt.figure(figsize=(18,5))
        ax=plt.subplot(projection=w2)
        plt.imshow(Tresi_cube1[:,:,ch_plot].T,cmap='jet',aspect='auto')
        plt.colorbar(label='Kelvin')
        plt.xlabel('R. A. (J2000)')
        plt.ylabel('Dec (J2000)')
        plt.xlim([0,Npix_x])
        plt.ylim([0,Npix_y])
        ax.invert_xaxis()
        plt.show()
 
        ######calculate std without point sources################
        ''' #2023
        Tresi_ra_std=np.nanstd(Tresi_cube1,axis=0)
        Tresi_ra_mean=np.nanmean(Tresi_cube1,axis=0)

        Tresi_ra_u=Tresi_ra_mean+std_sigma*Tresi_ra_std
        Tresi_ra_l=Tresi_ra_mean-std_sigma*Tresi_ra_std

        x_ticks=pixel_to_skycoord(0,range(np.shape(Tresi_cube)[1]),w2).dec/u.deg #pix_ra=0, get dec
        x_ticks=np.array(x_ticks)
        assert(np.shape(Tresi_cube)[1]==len(x_ticks))
        
        plt.figure(figsize=(8,4))
        plt.plot(Tresi_ra_mean[:,ch_plot],'r')
        plt.plot(Tresi_ra_u[:,ch_plot],'b--')
        plt.plot(Tresi_ra_l[:,ch_plot],'g--')
        
        tick_i=[0, 10, 20, 30, 40]
        plt.xticks(tick_i, np.round(x_ticks[tick_i],1))
        plt.xlabel('${Dec_{pix}}$ (Deg)')
        plt.ylabel('T (K)')
        plt.legend(['mean','mean+3sigma','mean-3sigma'],ncol=3)
        plt.title('$T_{res}$ along dec of ch'+str(ch_plot)+', all scans')
        plt.grid(color='grey', lw=.1)
        plt.savefig('Tresi_filter_iter'+str(i_iter)+'.pdf', bbox_inches='tight')
        plt.show()
        ''' #2023
        #2023 below
        Fits_Tresi_std=output_file+'ALL_scan'+str(total_count_MAX)+'_Tresi_std_cube_p'+str(pix_deg)+'d.fits' #2023
        Tresi_std = fits.open(Fits_Tresi_std)[0].data #2023
        Tresi_u=Tresi_cube1+std_sigma*Tresi_std #2023
        Tresi_l=Tresi_cube1-std_sigma*Tresi_std #2023
        
        plt.figure(figsize=(18,5))
        ax=plt.subplot(projection=w2)
        plt.imshow(Tresi_std[:,:,ch_plot].T,cmap='jet',aspect='auto')
        plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
        plt.colorbar(label='Kelvin')
        plt.xlabel('R. A. (J2000)')
        plt.ylabel('Dec (J2000)')
        plt.xlim([0,Npix_x])
        plt.ylim([0,Npix_y])
        ax.invert_xaxis()
        plt.title('reloaded Tresi_std')
        plt.show()
        #2023 above
        
    except IOError:
        if i_iter==0:#First
            print ('*** No previous data cube with label *ALL_scan*,',)
            print ('calculate ALL_scan now...',)
            print ('will stop after ALL_scan calculated ')
            Fits=input_file+fname_list[0]+'_m000_Tresi_xy_p'+str(pix_deg)+'d.fits'
            Tresi_cube = fits.open(Fits)[0].data
            Tresi_u=np.ones_like(Tresi_cube)*1e3 #2023
            Tresi_l=np.ones_like(Tresi_cube)*-1e3 #2023
        else:
            print ('*** No data cube for iter '+str(i_iter-1)+', EXIT!')
            break
         
    #######filter data##########################
    n_ch_del=0
    n_ch_keep=0
    total_count=0 #cube count
    total_count_plot=0 #channel count
    total_count_list=np.zeros(4096)
    
    for a_i in range(64):
        ant='m'+ "%03d" % a_i
        #print ant

        for f_i in range(len(fname_list)):
            fname=fname_list[f_i]
            #print fname

            try:
                #print 'set ch_mask'
                a=np.ma.array(np.zeros(4096),mask=True)
                ch_mask=a.mask
                
                Fits1=input_file+fname+'_'+ant+'_Tsky_xy_p'+str(pix_deg)+'d.fits'
                Tsky_cube = fits.open(Fits1)[0].data
                Fits2=input_file+fname+'_'+ant+'_Tresi_xy_p'+str(pix_deg)+'d.fits'
                Tresi_cube = fits.open(Fits2)[0].data
                Fits3=input_file+fname+'_'+ant+'_Npix_xy_count_p'+str(pix_deg)+'d.fits'
                Pcount_cube = fits.open(Fits3)[0].data
                
                assert(np.shape(Tsky_cube)==np.shape(Tresi_cube))
                assert((np.isnan(Tresi_cube)).all()==False)
                if (np.isnan(Tsky_cube)).all()==False: 
                    total_count+=1 #cube count
                    for ch_ii in range(4096):
                        if (np.isnan(Tsky_cube[:,:,ch_ii])).all()==False:
                            ch_mask[ch_ii]=False
                else:
                    print ('***empty cube')

                if (total_count==1):
                    Npix_x= np.shape(Tsky_cube)[0]
                    Npix_y= np.shape(Tsky_cube)[1]

                    w=WCS(Fits1).dropaxis(-1)
                    w2=WCS(Fits2).dropaxis(-1)
                    assert(w.wcs==w2.wcs)
                    print ('-------------------------------------------')
                    #print w
                    print ('-------------------------------------------')
                    fits_temp=np.zeros([Npix_x,Npix_y,4096])

                    Sum_Tsky_xy=fits_temp.copy()
                    Sum_Tresi_xy=fits_temp.copy()
                    Npix_xy_count1=fits_temp.copy()
                    Npix_xy_count2=fits_temp.copy()
                    P_xy_count1=fits_temp.copy()
                    P_xy_count2=fits_temp.copy()
                    Sum_Tresi_sq_xy=fits_temp.copy() #2023
                    assert((Sum_Tsky_xy==0).all()==True)
                    assert((Sum_Tresi_xy==0).all()==True)
                    assert((Npix_xy_count1==0).all()==True)
                    assert((Npix_xy_count2==0).all()==True)
                    print ('***stastic cubes initialized')

                print ('# cube '+str(total_count)+': '+fname+' '+ant)
                assert(np.shape(Tsky_cube)==np.shape(Sum_Tsky_xy))
                
                if (Tresi_u==1000).all()==True: #2023
                    print ('### no ch_drop!')
                else:
                    
                    #mean along dec to check rfi lines
                    Tresi_cube1=Tresi_cube.copy()
                    Tresi_cube1[pix_ma_ra,pix_ma_dec,:]=np.nan
                    # 2023 Tresi_ra_median=np.nanmedian(Tresi_cube1,axis=0) #always check Tresi since Tsky have the Galactic slope 

                    ch_drop=[]  
                    for ch_i in range(4096):
                        if ((Tresi_cube1[:,:,ch_i]<Tresi_l[:,:,ch_i]).any()==True 
                            or (Tresi_cube1[:,:,ch_i]>Tresi_u[:,:,ch_i]).any()==True): #2023
                            ch_drop.append(ch_i)

                    if len(ch_drop)>0:
                        Tsky_cube[:,:,ch_drop]=np.nan            
                        Tresi_cube[:,:,ch_drop]=np.nan
                        print ('***'+str(len(ch_drop))+' channels deleted')
                        n_ch_del+=len(ch_drop)
                        ch_mask[ch_drop]=True
                        
                    ch_l=len(np.where(ch_mask==False)[0])
                    n_ch_keep+=ch_l
                    print ('***'+str(ch_l)+' channels left')
                    d1={}
                    d1['ch_mask']=ch_mask
                    fs=open(output_file+str(fname)+'_'+str(ant)+'_level6_p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter)+'_mask','wb')
                    pickle.dump(d1,fs,protocol=2)
                    fs.close()
                       
                Sum_Tsky_xy[~np.isnan(Tsky_cube)]+=Tsky_cube[~np.isnan(Tsky_cube)]
                Sum_Tresi_xy[~np.isnan(Tresi_cube)]+=Tresi_cube[~np.isnan(Tresi_cube)]
                Sum_Tresi_sq_xy[~np.isnan(Tresi_cube)]+=Tresi_cube[~np.isnan(Tresi_cube)]**2 #2023
                Npix_xy_count1[~np.isnan(Tsky_cube)]+=1
                Npix_xy_count2[~np.isnan(Tresi_cube)]+=1
                P_xy_count1[~np.isnan(Tsky_cube)]+=Pcount_cube[~np.isnan(Tsky_cube)]
                P_xy_count2[~np.isnan(Tresi_cube)]+=Pcount_cube[~np.isnan(Tresi_cube)]
                if (np.isnan(Tsky_cube[:,:,ch_plot])).all()==False: #channel count
                    total_count_plot+=1
                    
                local_ch_count=0 #2023
                for ch_i in list(range(550,1051)) + list(range(2150,3101)):##set channels
                    if (np.isnan(Tsky_cube[:,:,ch_i])).all()==False: #channel count
                        total_count_list[ch_i]+=1
                        local_ch_count+=1 #2023
                #2023 below        
                text_local=fname+' '+ant+' '+str(local_ch_count)+'\n'
                #print (text_local)
                if (Tresi_u==1000).all()==True: #2023
                    f=open(output_file+'ch_count_ALL.dat','a')
                else:    
                    f=open(output_file+'ch_count_iter'+str(i_iter)+'.dat','a')
                f.writelines(text_local)
                f.close()
                #2023 above
            except IOError:
                print ('no data cube for '+ fname+', '+ant)
    
    ######check and save data#####
    print (n_ch_del)
    print ('total channel number left: '+str(n_ch_keep))

    if (Tresi_u==1000).all()==True: #2023
        np.savetxt(output_file+'ALL_scan'+str(total_count)+'_list_p'+str(pix_deg)+'d.dat',total_count_list)
        print ('list for ALL_scan saved')
    else:
        np.savetxt(output_file+'Nscan'+str(total_count)+'_list_p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter)+'.dat',total_count_list)
        print ('list for Iter'+str(i_iter)+' saved')
        
    assert(total_count_list[ch_plot]==total_count_plot)

    m=np.where(total_count_list==total_count_list.max())
    print (m,total_count_list[m])

    plt.figure(figsize=(8,4))
    #plt.plot(total_count_list,'.')
    ###plt.plot(ch_plot,total_count_plot,'r*')
    ###plt.plot(m,total_count_list[m],'g*')
    plt.xlabel('channel')
    plt.ylabel('scan count')
    try:
        total_count_list0=np.loadtxt(output_file+'ALL_scan'+str(total_count)+'_list_p'+str(pix_deg)+'d.dat')
        print (total_count_list0)
        plt.plot(total_count_list0,'.',color='grey')
        
    except IOError:
        print ('*** No previous data cube')
    #plt.legend(['scan count of channel after filter','total scan count of channel'])
    plt.plot(total_count_list,'.')
    plt.legend(['total scan count of channel','scan count of channel after filter'])
    
    if i_iter==niter-1:
        plt.savefig('count_comp_iter'+str(i_iter)+'.pdf', bbox_inches='tight')
    plt.show()

    Tsky_xy=Sum_Tsky_xy/Npix_xy_count1
    Tresi_xy=Sum_Tresi_xy/Npix_xy_count2
    Tresi_xy_std=np.sqrt(Sum_Tresi_sq_xy/Npix_xy_count1-Tresi_xy**2) #2023
    
    plt.figure(figsize=(18,5))
    ax=plt.subplot(projection=w)
    plt.grid(color='grey',lw=.1)
    plt.imshow(Npix_xy_count1[:,:,ch_plot].T,cmap=kv.cmap3(),aspect='auto')
    plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
    #plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
    plt.colorbar(label='Kelvin')
    plt.xlabel('R. A. (J2000)')
    plt.ylabel('Dec (J2000)')
    plt.xlim([0,Npix_x])
    plt.ylim([0,Npix_y])
    ax.invert_xaxis()
    if (Tresi_u==1000).all()==True: #2023:
        plt.savefig('ALL_count'+str(ch_plot)+'_iter'+str(i_iter)+'.png', bbox_inches='tight')
    else:
        plt.savefig('Ncount'+str(ch_plot)+'_iter'+str(i_iter)+'.png', bbox_inches='tight')
    plt.show()
    
    
    plt.figure(figsize=(18,5))
    ax=plt.subplot(projection=w)
    plt.grid(color='grey',lw=.1)
    plt.imshow(Tsky_xy[:,:,ch_plot].T,cmap=kv.cmap1(),aspect='auto',vmin=2.9,vmax=3.55)
    plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
    #plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
    plt.colorbar(label='Kelvin')
    plt.xlabel('R. A. (J2000)')
    plt.ylabel('Dec (J2000)')
    plt.title(r'$\bar T_{sky}$'+' map for '+str(total_count_plot)+' scans, '+str(pix_deg)+' deg/pix, '
                                  +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
    plt.xlim([0,Npix_x])
    plt.ylim([0,Npix_y])
    ax.invert_xaxis()
    if (Tresi_u==1000).all()==True: #2023:
        plt.savefig('F_Tsky_ALL_ch'+str(ch_plot)+'_iter'+str(i_iter)+'.png', bbox_inches='tight')
    else:
        plt.savefig('F_Tsky_all_ch'+str(ch_plot)+'_iter'+str(i_iter)+'.png', bbox_inches='tight')
    plt.show()

    plt.figure(figsize=(18,5))
    ax=plt.subplot(projection=w)
    plt.grid(color='grey',lw=.1)
    plt.imshow(Tresi_xy[:,:,ch_plot].T,cmap=kv.cmap2(),aspect='auto',vmin=-0.25, vmax=0.25)
    plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
    #plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
    #plt.text(ptr_ra_pix[19]-0.8,ptr_dec_pix[19]+0.8,'4C+00.35')    
    
    plt.colorbar(label='Kelvin')
    plt.xlabel('R. A. (J2000)')
    plt.ylabel('Dec (J2000)')
    plt.title(r'$\bar T_{res}$'+' map for '+str(total_count_plot)+' scans, '+str(pix_deg)+' deg/pix, '
                                  +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
    plt.xlim([0,Npix_x])
    plt.ylim([0,Npix_y])
    ax.invert_xaxis()
    if (Tresi_u==1000).all()==True: #2023:
        plt.savefig('F_Tresi_ALL_ch'+str(ch_plot)+'_iter'+str(i_iter)+'.png', bbox_inches='tight')
    else:
        plt.savefig('F_Tresi_all_ch'+str(ch_plot)+'_iter'+str(i_iter)+'.png', bbox_inches='tight')
    plt.show()

    assert((Npix_xy_count1==Npix_xy_count2).all())
    assert((P_xy_count1==P_xy_count2).all())
    print (total_count)

    
    #save data
    
    list_data=[Sum_Tsky_xy,Sum_Tresi_xy,Npix_xy_count1,Tsky_xy,Tresi_xy, P_xy_count1,Tresi_xy_std] #2023
    list_str=['Sum_Tsky_cube','Sum_Tresi_cube','Npix_count_cube','Tsky_cube','Tresi_cube','P_xy_count','Tresi_std_cube'] #2023
    for i in range(len(list_data)):
        hdu=w.to_fits()
        hdu[0].data=list_data[i]
        #if (std_list0==1000).all()==True:
        if (Tresi_u==1000).all()==True: #2023
            hdu.writeto(output_file+'ALL_scan'+str(total_count)+'_'+list_str[i]+'_p'+str(pix_deg)+'d.fits', overwrite=True)
            print ('ALL_scan finished, will EXIT soon ...')
        else:    
            hdu.writeto(output_file+'Nscan'+str(total_count)+'_'+list_str[i]+'_p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter)+'.fits', overwrite=True)
# Out:
# >>>>>>>>> Iteration 0 start...
# (133, 73, 4096)
# WCS Transformation
#
# This transformation has 2 pixel and 2 world dimensions
#
# Array shape (Numpy order): (133, 73, 4096)
#
# Pixel Dim  Data size  Bounds
#         0       4096  None
#         1         73  None
#
# World Dim  Physical Type  Units
#         0  pos.eq.ra      deg
#         1  pos.eq.dec     deg
#
# Correlation between pixel and world axes:
#
#            Pixel Dim
# World Dim    0    1
#         0  yes  yes
#         1  yes  yes
# (133, 73, 4096)
# -0.1603481974306652 0.1819862408794292
# -0.00596865093109689 0.04176947140182511
# -------------------------------------------
# -------------------------------------------
# ***stastic cubes initialized
# # cube 1: 1630519596 m000
# ***5 channels deleted
# ***1307 channels left
# no data cube for 1631379874, m000
# # cube 2: 1631387336 m000
# ***2 channels deleted
# ***61 channels left
# no data cube for 1631552188, m000
# # cube 3: 1631559762 m000
# ***21 channels deleted
# ***313 channels left
# no data cube for 1631659886, m000
# # cube 4: 1631667564 m000
# ***3 channels deleted
# ***476 channels left
# no data cube for 1631724508, m000
# # cube 5: 1631732038 m000
# ***11 channels left
# no data cube for 1631810671, m000
# no data cube for 1631818149, m000
# # cube 6: 1631982988 m000
# ***149 channels left
# # cube 7: 1631990463 m000
# ***11 channels deleted
# ***220 channels left
# # cube 8: 1632069690 m000
# ***58 channels left
# no data cube for 1632077222, m000
# # cube 9: 1632184922 m000
# ***2 channels left
# no data cube for 1632505883, m000
# # cube 10: 1632760885 m000
# ***2 channels deleted
# ***1005 channels left
# # cube 11: 1633365980 m000
# ***338 channels left
# no data cube for 1633970780, m000
# no data cube for 1634252028, m000
# no data cube for 1634402485, m000
# no data cube for 1634748682, m000
# no data cube for 1634835083, m000
# no data cube for 1637346562, m000
# no data cube for 1637354605, m000
# # cube 12: 1637691677 m000
# ***2 channels deleted
# ***792 channels left
# # cube 13: 1637699408 m000
# ***3 channels deleted
# ***1091 channels left
# no data cube for 1638130295, m000
# no data cube for 1638294319, m000
# # cube 14: 1638301944 m000
# ***363 channels left
# # cube 15: 1638386189 m000
# ***430 channels left
# no data cube for 1638639082, m000
# no data cube for 1638647186, m000
# no data cube for 1638898468, m000
# no data cube for 1639157507, m000
# no data cube for 1639331184, m000
# no data cube for 1639935088, m000
# no data cube for 1640540184, m000
# no data cube for 1640712986, m000
# no data cube for 1640799689, m000
# # cube 16: 1630519596 m001
# ***11 channels deleted
# ***45 channels left
# no data cube for 1631379874, m001
# no data cube for 1631387336, m001
# no data cube for 1631552188, m001
# no data cube for 1631559762, m001
# no data cube for 1631659886, m001
# no data cube for 1631667564, m001
# no data cube for 1631724508, m001
# no data cube for 1631732038, m001
# no data cube for 1631810671, m001
# no data cube for 1631818149, m001
# no data cube for 1631982988, m001
# no data cube for 1631990463, m001
# # cube 17: 1632069690 m001
# ***1 channels deleted
# ***561 channels left
# # cube 18: 1632077222 m001
# ***1 channels deleted
# ***617 channels left
# # cube 19: 1632184922 m001
# ***1 channels deleted
# ***909 channels left
# no data cube for 1632505883, m001
# # cube 20: 1632760885 m001
# # cube 31: 1631810671 m002
# ***6 channels deleted
# ***819 channels left
# no data cube for 1631818149, m002
# # cube 32: 1631982988 m002
# ***813 channels left
# # cube 33: 1631990463 m002
# ***304 channels deleted
# ***508 channels left
# # cube 34: 1632069690 m002
# ***5 channels deleted
# ***803 channels left
# # cube 35: 1632077222 m002
# ***5 channels deleted
# ***1272 channels left
# # cube 36: 1632184922 m002
# ***873 channels left
# no data cube for 1632505883, m002
# # cube 37: 1632760885 m002
# ***2 channels deleted
# ***607 channels left
# # cube 38: 1633365980 m002
# ***11 channels deleted
# ***1336 channels left
# no data cube for 1633970780, m002
# # cube 39: 1634252028 m002
# ***11 channels deleted
# ***1297 channels left
# # cube 40: 1634402485 m002
# ***5 channels deleted
# ***776 channels left
# no data cube for 1634748682, m002
# no data cube for 1634835083, m002
# no data cube for 1637346562, m002
# # cube 41: 1637354605 m002
# ***1309 channels left
# # cube 42: 1637691677 m002
# ***799 channels left
# # cube 43: 1637699408 m002
# ***1 channels deleted
# ***803 channels left
# no data cube for 1638130295, m002
# no data cube for 1638294319, m002
# # cube 44: 1638301944 m002
# ***966 channels left
# # cube 45: 1638386189 m002
# ***4 channels deleted
# ***1335 channels left
# no data cube for 1638639082, m002
# no data cube for 1638647186, m002
# no data cube for 1638898468, m002
# no data cube for 1639157507, m002
# no data cube for 1639331184, m002
# no data cube for 1639935088, m002
# no data cube for 1640540184, m002
# no data cube for 1640712986, m002
# no data cube for 1640799689, m002
# # cube 46: 1630519596 m003
# ***7 channels deleted
# ***811 channels left
# no data cube for 1631379874, m003
# no data cube for 1631387336, m003
# no data cube for 1631552188, m003
# no data cube for 1631559762, m003
# no data cube for 1631659886, m003
# no data cube for 1631667564, m003
# no data cube for 1631724508, m003
# no data cube for 1631732038, m003
# # cube 47: 1631810671 m003
# ***1 channels deleted
# ***384 channels left
# # cube 48: 1631818149 m003
# ***131 channels deleted
# ***758 channels left
# # cube 49: 1631982988 m003
# ***500 channels left
# no data cube for 1631990463, m003
# # cube 50: 1632069690 m003
# ***183 channels left
# # cube 51: 1632077222 m003
# ***258 channels left
# # cube 52: 1632184922 m003
# ***663 channels left
# no data cube for 1632505883, m003
# # cube 53: 1632760885 m003
# ***2 channels deleted
# ***629 channels left
# # cube 54: 1633365980 m003
# ***996 channels left
# no data cube for 1633970780, m003
# # cube 55: 1634252028 m003
# ***536 channels left
# no data cube for 1634402485, m003
# no data cube for 1634748682, m003
# no data cube for 1634835083, m003
# no data cube for 1637346562, m003
# no data cube for 1637354605, m003
# no data cube for 1637691677, m003
# # cube 56: 1637699408 m003
# ***15 channels deleted
# ***585 channels left
# no data cube for 1638130295, m003
# no data cube for 1638294319, m003
# no data cube for 1638301944, m003
# no data cube for 1638386189, m003
# no data cube for 1638639082, m003
# no data cube for 1638647186, m003
# no data cube for 1638898468, m003
# no data cube for 1639157507, m003
# no data cube for 1639331184, m003
# no data cube for 1639935088, m003
# no data cube for 1640540184, m003
# no data cube for 1640712986, m003
# no data cube for 1640799689, m003
# # cube 57: 1630519596 m004
# ***16 channels deleted
# ***84 channels left
# no data cube for 1631379874, m004
# no data cube for 1631387336, m004
# no data cube for 1631552188, m004
# # cube 58: 1631559762 m004
# ***55 channels deleted
# ***147 channels left
# no data cube for 1631659886, m004
# no data cube for 1631667564, m004
# no data cube for 1631724508, m004
# # cube 59: 1631732038 m004
# ***64 channels left
# # cube 60: 1631810671 m004
# ***288 channels left
# # cube 61: 1631818149 m004
# ***1 channels deleted
# ***725 channels left
# # cube 62: 1631982988 m004
# ***717 channels left
# no data cube for 1631990463, m004
# # cube 63: 1632069690 m004
# ***205 channels left
# # cube 64: 1632077222 m004
# ***946 channels left
# # cube 65: 1632184922 m004
# ***2 channels deleted
# ***727 channels left
# no data cube for 1632505883, m004
# # cube 66: 1632760885 m004
# ***910 channels left
# no data cube for 1633365980, m004
# no data cube for 1633970780, m004
# # cube 67: 1634252028 m004
# ***1 channels deleted
# ***1075 channels left
# # cube 68: 1634402485 m004
# ***730 channels left
# no data cube for 1634748682, m004
# no data cube for 1634835083, m004
# no data cube for 1637346562, m004
# # cube 69: 1637354605 m004
# ***886 channels left
# no data cube for 1637691677, m004
# # cube 70: 1637699408 m004
# ***322 channels left
# no data cube for 1638130295, m004
# no data cube for 1638294319, m004
# # cube 71: 1638301944 m004
# ***40 channels deleted
# ***329 channels left
# no data cube for 1638386189, m004
# no data cube for 1638639082, m004
# no data cube for 1638647186, m004
# no data cube for 1638898468, m004
# no data cube for 1639157507, m004
# no data cube for 1639331184, m004
# no data cube for 1639935088, m004
# no data cube for 1640540184, m004
# no data cube for 1640712986, m004
# no data cube for 1640799689, m004
# # cube 72: 1630519596 m005
# ***105 channels deleted
# ***751 channels left
# no data cube for 1631379874, m005
# # cube 73: 1631387336 m005
# ***269 channels left
# no data cube for 1631552188, m005
# # cube 74: 1631559762 m005
# ***60 channels deleted
# ***765 channels left
# no data cube for 1631659886, m005
# # cube 75: 1631667564 m005
# ***88 channels deleted
# ***791 channels left
# no data cube for 1631724508, m005
# # cube 76: 1631732038 m005
# ***2 channels deleted
# ***786 channels left
# # cube 77: 1631810671 m005
# ***6 channels deleted
# ***819 channels left
# # cube 78: 1631818149 m005
# ***4 channels deleted
# ***553 channels left
# # cube 79: 1631982988 m005
# ***817 channels left
# # cube 80: 1631990463 m005
# ***6 channels deleted
# ***817 channels left
# # cube 81: 1632069690 m005
# ***3 channels deleted
# ***801 channels left
# # cube 82: 1632077222 m005
# ***2 channels deleted
# ***1337 channels left
# # cube 83: 1632184922 m005
# ***929 channels left
# no data cube for 1632505883, m005
# # cube 84: 1632760885 m005
# ***1099 channels left
# # cube 85: 1633365980 m005
# ***7 channels deleted
# ***1228 channels left
# no data cube for 1633970780, m005
# # cube 86: 1634252028 m005
# ***14 channels deleted
# ***1166 channels left
# # cube 87: 1634402485 m005
# ***783 channels left
# no data cube for 1634748682, m005
# no data cube for 1634835083, m005
# no data cube for 1637346562, m005
# # cube 88: 1637354605 m005
# ***201 channels deleted
# ***1160 channels left
# # cube 89: 1637691677 m005
# ***122 channels deleted
# ***702 channels left
# # cube 90: 1637699408 m005
# ***1256 channels left
# no data cube for 1638130295, m005
# no data cube for 1638294319, m005
# # cube 91: 1638301944 m005
# ***1244 channels left
# # cube 92: 1638386189 m005
# ***1367 channels deleted
# ***5 channels left
# no data cube for 1638639082, m005
# no data cube for 1638647186, m005
# no data cube for 1638898468, m005
# # cube 93: 1639157507 m005
# ***2 channels deleted
# ***3 channels left
# no data cube for 1639331184, m005
# no data cube for 1639935088, m005
# no data cube for 1640540184, m005
# no data cube for 1640712986, m005
# no data cube for 1640799689, m005
# # cube 94: 1630519596 m006
# ***16 channels deleted
# ***166 channels left
# no data cube for 1631379874, m006
# no data cube for 1631387336, m006
# no data cube for 1631552188, m006
# no data cube for 1631559762, m006
# no data cube for 1631659886, m006
# # cube 95: 1631667564 m006
# ***3 channels deleted
# ***234 channels left
# no data cube for 1631724508, m006
# # cube 96: 1631732038 m006
# ***8 channels deleted
# ***395 channels left
# # cube 97: 1631810671 m006
# ***4 channels deleted
# ***629 channels left
# # cube 98: 1631818149 m006
# ***585 channels deleted
# ***130 channels left
# # cube 99: 1631982988 m006
# ***2 channels deleted
# ***644 channels left
# # cube 100: 1631990463 m006
# ***8 channels deleted
# ***18 channels left
# # cube 101: 1632069690 m006
# ***149 channels left
# # cube 102: 1632077222 m006
# ***810 channels left
# # cube 103: 1632184922 m006
# ***949 channels left
# no data cube for 1632505883, m006
# # cube 104: 1632760885 m006
# ***929 channels left
# no data cube for 1633365980, m006
# no data cube for 1633970780, m006
# # cube 105: 1634252028 m006
# ***1 channels deleted
# ***691 channels left
# no data cube for 1634402485, m006
# no data cube for 1634748682, m006
# no data cube for 1634835083, m006
# no data cube for 1637346562, m006
# no data cube for 1637354605, m006
# # cube 106: 1637691677 m006
# ***6 channels deleted
# ***659 channels left
# # cube 107: 1637699408 m006
# ***1088 channels left
# no data cube for 1638130295, m006
# no data cube for 1638294319, m006
# # cube 108: 1638301944 m006
# ***984 channels left
# no data cube for 1638386189, m006
# no data cube for 1638639082, m006
# no data cube for 1638647186, m006
# no data cube for 1638898468, m006
# no data cube for 1639157507, m006
# no data cube for 1639331184, m006
# no data cube for 1639935088, m006
# no data cube for 1640540184, m006
# no data cube for 1640712986, m006
# no data cube for 1640799689, m006
# no data cube for 1630519596, m007
# no data cube for 1631379874, m007
# no data cube for 1631387336, m007
# no data cube for 1631552188, m007
# no data cube for 1631559762, m007
# no data cube for 1631659886, m007
# no data cube for 1631667564, m007
# no data cube for 1631724508, m007
# # cube 109: 1631732038 m007
# ***23 channels deleted
# ***463 channels left
# # cube 110: 1631810671 m007
# ***5 channels deleted
# ***132 channels left
# # cube 111: 1631818149 m007
# ***27 channels deleted
# ***473 channels left
# # cube 112: 1631982988 m007
# ***714 channels left
# # cube 113: 1631990463 m007
# ***1 channels deleted
# ***6 channels left
# # cube 114: 1632069690 m007
# ***241 channels left
# # cube 115: 1632077222 m007
# ***827 channels left
# # cube 116: 1632184922 m007
# ***749 channels left
# no data cube for 1632505883, m007
# # cube 117: 1632760885 m007
# ***8 channels deleted
# ***256 channels left
# no data cube for 1633365980, m007
# no data cube for 1633970780, m007
# # cube 118: 1634252028 m007
# ***792 channels left
# # cube 119: 1634402485 m007
# ***681 channels left
# no data cube for 1634748682, m007
# no data cube for 1634835083, m007
# no data cube for 1637346562, m007
# no data cube for 1637354605, m007
# # cube 120: 1637691677 m007
# ***239 channels deleted
# ***391 channels left
# # cube 121: 1637699408 m007
# ***2 channels deleted
# ***710 channels left
# no data cube for 1638130295, m007
# no data cube for 1638294319, m007
# # cube 122: 1638301944 m007
# ***120 channels deleted
# ***1001 channels left
# no data cube for 1638386189, m007
# no data cube for 1638639082, m007
# no data cube for 1638647186, m007
# no data cube for 1638898468, m007
# no data cube for 1639157507, m007
# no data cube for 1639331184, m007
# no data cube for 1639935088, m007
# no data cube for 1640540184, m007
# no data cube for 1640712986, m007
# no data cube for 1640799689, m007
# # cube 123: 1630519596 m008
# ***17 channels deleted
# ***717 channels left
# no data cube for 1631379874, m008
# # cube 124: 1631387336 m008
# ***1 channels deleted
# ***947 channels left
# no data cube for 1631552188, m008
# no data cube for 1631559762, m008
# no data cube for 1631659886, m008
# no data cube for 1631667564, m008
# no data cube for 1631724508, m008
# no data cube for 1631732038, m008
# # cube 125: 1631810671 m008
# ***3 channels deleted
# ***737 channels left
# # cube 126: 1631818149 m008
# ***20 channels deleted
# ***924 channels left
# # cube 127: 1631982988 m008
# ***678 channels left
# # cube 128: 1631990463 m008
# ***300 channels left
# # cube 129: 1632069690 m008
# # cube 136: 1631387336 m009
# ***987 channels left
# no data cube for 1631552188, m009
# # cube 137: 1631559762 m009
# ***852 channels deleted
# ***184 channels left
# no data cube for 1631659886, m009
# # cube 138: 1631667564 m009
# ***1 channels deleted
# ***808 channels left
# no data cube for 1631724508, m009
# # cube 139: 1631732038 m009
# ***1 channels deleted
# ***798 channels left
# # cube 140: 1631810671 m009
# ***1 channels deleted
# ***569 channels left
# # cube 141: 1631818149 m009
# ***13 channels deleted
# ***957 channels left
# # cube 142: 1631982988 m009
# ***798 channels left
# # cube 143: 1631990463 m009
# ***13 channels deleted
# ***801 channels left
# # cube 144: 1632069690 m009
# ***1 channels deleted
# ***690 channels left
# # cube 145: 1632077222 m009
# ***1397 channels left
# # cube 146: 1632184922 m009
# ***1 channels deleted
# ***887 channels left
# no data cube for 1632505883, m009
# # cube 147: 1632760885 m009
# ***1205 channels left
# # cube 148: 1633365980 m009
# ***4 channels deleted
# ***760 channels left
# no data cube for 1633970780, m009
# # cube 149: 1634252028 m009
# ***1241 channels left
# # cube 150: 1634402485 m009
# ***666 channels deleted
# ***77 channels left
# no data cube for 1634748682, m009
# no data cube for 1634835083, m009
# no data cube for 1637346562, m009
# # cube 151: 1637354605 m009
# ***1267 channels left
# # cube 152: 1637691677 m009
# ***3 channels deleted
# ***801 channels left
# # cube 153: 1637699408 m009
# ***3 channels deleted
# ***856 channels left
# no data cube for 1638130295, m009
# no data cube for 1638294319, m009
# # cube 154: 1638301944 m009
# ***718 channels left
# # cube 155: 1638386189 m009
# ***2 channels deleted
# ***1120 channels left
# no data cube for 1638639082, m009
# no data cube for 1638647186, m009
# no data cube for 1638898468, m009
# no data cube for 1639157507, m009
# no data cube for 1639331184, m009
# no data cube for 1639935088, m009
# no data cube for 1640540184, m009
# no data cube for 1640712986, m009
# no data cube for 1640799689, m009
# # cube 156: 1630519596 m010
# ***30 channels deleted
# ***209 channels left
# no data cube for 1631379874, m010
# # cube 157: 1631387336 m010
# ***5 channels deleted
# ***955 channels left
# no data cube for 1631552188, m010
# # cube 158: 1631559762 m010
# ***5 channels deleted
# ***1391 channels left
# no data cube for 1631659886, m010
# # cube 159: 1631667564 m010
# ***1 channels deleted
# ***745 channels left
# no data cube for 1631724508, m010
# # cube 160: 1631732038 m010
# ***6 channels deleted
# ***796 channels left
# # cube 161: 1631810671 m010
# ***7 channels deleted
# ***826 channels left
# no data cube for 1631818149, m010
# # cube 162: 1631982988 m010
# ***838 channels left
# # cube 163: 1631990463 m010
# ***819 channels left
# # cube 164: 1632069690 m010
# ***4 channels deleted
# ***792 channels left
# # cube 165: 1632077222 m010
# ***4 channels deleted
# ***1057 channels left
# # cube 166: 1632184922 m010
# ***876 channels left
# no data cube for 1632505883, m010
# # cube 167: 1632760885 m010
# ***1 channels deleted
# ***651 channels left
# # cube 168: 1633365980 m010
# ***7 channels deleted
# ***1328 channels left
# no data cube for 1633970780, m010
# # cube 169: 1634252028 m010
# ***1 channels deleted
# ***865 channels left
# # cube 170: 1634402485 m010
# ***3 channels deleted
# ***772 channels left
# no data cube for 1634748682, m010
# no data cube for 1634835083, m010
# no data cube for 1637346562, m010
# # cube 171: 1637354605 m010
# ***1216 channels left
# # cube 172: 1637691677 m010
# ***1 channels deleted
# ***800 channels left
# # cube 173: 1637699408 m010
# ***1 channels deleted
# ***1233 channels left
# no data cube for 1638130295, m010
# # cube 174: 1638294319 m010
# ***16 channels deleted
# ***955 channels left
# # cube 175: 1638301944 m010
# ***1 channels deleted
# ***378 channels left
# # cube 176: 1638386189 m010
# ***1 channels deleted
# ***586 channels left
# no data cube for 1638639082, m010
# no data cube for 1638647186, m010
# no data cube for 1638898468, m010
# # cube 177: 1639157507 m010
# ***352 channels deleted
# ***873 channels left
# no data cube for 1639331184, m010
# no data cube for 1639935088, m010
# no data cube for 1640540184, m010
# no data cube for 1640712986, m010
# no data cube for 1640799689, m010
# # cube 178: 1630519596 m011
# ***144 channels left
# no data cube for 1631379874, m011
# # cube 179: 1631387336 m011
# ***6 channels deleted
# ***818 channels left
# no data cube for 1631552188, m011
# # cube 180: 1631559762 m011
# ***261 channels deleted
# ***950 channels left
# no data cube for 1631659886, m011
# no data cube for 1631667564, m011
# no data cube for 1631724508, m011
# no data cube for 1631732038, m011
# # cube 181: 1631810671 m011
# ***185 channels left
# # cube 182: 1631818149 m011
# ***1 channels deleted
# ***558 channels left
# # cube 183: 1631982988 m011
# ***819 channels left
# # cube 184: 1631990463 m011
# ***94 channels deleted
# ***686 channels left
# # cube 185: 1632069690 m011
# ***747 channels left
# # cube 186: 1632077222 m011
# ***1 channels deleted
# ***1307 channels left
# # cube 187: 1632184922 m011
# ***495 channels left
# no data cube for 1632505883, m011
# # cube 188: 1632760885 m011
# ***1 channels deleted
# ***687 channels left
# # cube 189: 1633365980 m011
# ***2 channels deleted
# ***865 channels left
# no data cube for 1633970780, m011
# # cube 190: 1634252028 m011
# ***2 channels deleted
# ***1185 channels left
# # cube 191: 1634402485 m011
# ***1 channels deleted
# ***669 channels left
# no data cube for 1634748682, m011
# no data cube for 1634835083, m011
# no data cube for 1637346562, m011
# # cube 192: 1637354605 m011
# ***406 channels left
# # cube 193: 1637691677 m011
# ***2 channels deleted
# ***787 channels left
# # cube 194: 1637699408 m011
# ***375 channels left
# no data cube for 1638130295, m011
# # cube 195: 1638294319 m011
# ***3 channels deleted
# ***426 channels left
# # cube 196: 1638301944 m011
# ***449 channels left
# # cube 197: 1638386189 m011
# ***3 channels deleted
# ***1336 channels left
# no data cube for 1638639082, m011
# no data cube for 1638647186, m011
# no data cube for 1638898468, m011
# no data cube for 1639157507, m011
# no data cube for 1639331184, m011
# no data cube for 1639935088, m011
# no data cube for 1640540184, m011
# no data cube for 1640712986, m011
# no data cube for 1640799689, m011
# # cube 198: 1630519596 m012
# ***2 channels deleted
# ***1218 channels left
# no data cube for 1631379874, m012
# # cube 199: 1631387336 m012
# ***404 channels left
# no data cube for 1631552188, m012
# # cube 200: 1631559762 m012
# ***1 channels deleted
# ***1118 channels left
# no data cube for 1631659886, m012
# # cube 201: 1631667564 m012
# ***2 channels deleted
# ***325 channels left
# no data cube for 1631724508, m012
# # cube 202: 1631732038 m012
# ***3 channels deleted
# ***537 channels left
# # cube 203: 1631810671 m012
# ***1 channels deleted
# ***364 channels left
# # cube 204: 1631818149 m012
# ***1 channels deleted
# ***499 channels left
# # cube 205: 1631982988 m012
# ***703 channels left
# # cube 206: 1631990463 m012
# ***2 channels deleted
# ***602 channels left
# # cube 207: 1632069690 m012
# ***2 channels deleted
# ***778 channels left
# # cube 208: 1632077222 m012
# ***1290 channels left
# # cube 209: 1632184922 m012
# ***863 channels left
# no data cube for 1632505883, m012
# # cube 210: 1632760885 m012
# ***1087 channels left
# # cube 211: 1633365980 m012
# ***11 channels deleted
# ***1343 channels left
# no data cube for 1633970780, m012
# # cube 212: 1634252028 m012
# ***1273 channels left
# # cube 213: 1634402485 m012
# ***785 channels left
# no data cube for 1634748682, m012
# no data cube for 1634835083, m012
# no data cube for 1637346562, m012
# # cube 214: 1637354605 m012
# ***1018 channels left
# # cube 215: 1637691677 m012
# ***1 channels deleted
# ***805 channels left
# # cube 216: 1637699408 m012
# ***5 channels deleted
# ***1089 channels left
# no data cube for 1638130295, m012
# # cube 217: 1638294319 m012
# ***8 channels deleted
# ***1327 channels left
# # cube 218: 1638301944 m012
# ***1312 channels left
# # cube 219: 1638386189 m012
# ***5 channels deleted
# ***1314 channels left
# no data cube for 1638639082, m012
# no data cube for 1638647186, m012
# no data cube for 1638898468, m012
# # cube 220: 1639157507 m012
# ***3 channels deleted
# ***1331 channels left
# no data cube for 1639331184, m012
# no data cube for 1639935088, m012
# no data cube for 1640540184, m012
# no data cube for 1640712986, m012
# no data cube for 1640799689, m012
# no data cube for 1630519596, m013
# no data cube for 1631379874, m013
# no data cube for 1631387336, m013
# no data cube for 1631552188, m013
# no data cube for 1631559762, m013
# no data cube for 1631659886, m013
# # cube 221: 1631667564 m013
# ***59 channels deleted
# ***752 channels left
# no data cube for 1631724508, m013
# no data cube for 1631732038, m013
# no data cube for 1631810671, m013
# no data cube for 1631818149, m013
# no data cube for 1631982988, m013
# no data cube for 1631990463, m013
# no data cube for 1632069690, m013
# no data cube for 1632077222, m013
# no data cube for 1632184922, m013
# no data cube for 1632505883, m013
# no data cube for 1632760885, m013
# no data cube for 1633365980, m013
# no data cube for 1633970780, m013
# # cube 222: 1634252028 m013
# ***1 channels deleted
# ***1058 channels left
# # cube 223: 1634402485 m013
# ***680 channels left
# no data cube for 1634748682, m013
# no data cube for 1634835083, m013
# no data cube for 1637346562, m013
# no data cube for 1637354605, m013
# no data cube for 1637691677, m013
# no data cube for 1637699408, m013
# no data cube for 1638130295, m013
# no data cube for 1638294319, m013
# no data cube for 1638301944, m013
# no data cube for 1638386189, m013
# no data cube for 1638639082, m013
# no data cube for 1638647186, m013
# no data cube for 1638898468, m013
# no data cube for 1639157507, m013
# no data cube for 1639331184, m013
# no data cube for 1639935088, m013
# no data cube for 1640540184, m013
# no data cube for 1640712986, m013
# no data cube for 1640799689, m013
# no data cube for 1630519596, m014
# no data cube for 1631379874, m014
# no data cube for 1631387336, m014
# no data cube for 1631552188, m014
# no data cube for 1631559762, m014
# no data cube for 1631659886, m014
# no data cube for 1631667564, m014
# no data cube for 1631724508, m014
# no data cube for 1631732038, m014
# no data cube for 1631810671, m014
# no data cube for 1631818149, m014
# # cube 224: 1631982988 m014
# ***587 channels deleted
# ***198 channels left
# no data cube for 1631990463, m014
# # cube 225: 1632069690 m014
# ***14 channels deleted
# ***271 channels left
# # cube 226: 1632077222 m014
# ***868 channels deleted
# ***427 channels left
# # cube 227: 1632184922 m014
# ***569 channels left
# no data cube for 1632505883, m014
# # cube 228: 1632760885 m014
# ***871 channels left
# no data cube for 1633365980, m014
# no data cube for 1633970780, m014
# no data cube for 1634252028, m014
# # cube 229: 1634402485 m014
# ***706 channels left
# no data cube for 1634748682, m014
# no data cube for 1634835083, m014
# no data cube for 1637346562, m014
# no data cube for 1637354605, m014
# no data cube for 1637691677, m014
# no data cube for 1637699408, m014
# no data cube for 1638130295, m014
# no data cube for 1638294319, m014
# no data cube for 1638301944, m014
# no data cube for 1638386189, m014
# no data cube for 1638639082, m014
# no data cube for 1638647186, m014
# no data cube for 1638898468, m014
# no data cube for 1639157507, m014
# no data cube for 1639331184, m014
# no data cube for 1639935088, m014
# no data cube for 1640540184, m014
# no data cube for 1640712986, m014
# no data cube for 1640799689, m014
# # cube 230: 1630519596 m015
# ***97 channels left
# no data cube for 1631379874, m015
# no data cube for 1631387336, m015
# no data cube for 1631552188, m015
# no data cube for 1631559762, m015
# no data cube for 1631659886, m015
# no data cube for 1631667564, m015
# no data cube for 1631724508, m015
# # cube 231: 1631732038 m015
# ***521 channels left
# # cube 232: 1631810671 m015
# ***642 channels left
# no data cube for 1631818149, m015
# # cube 233: 1631982988 m015
# ***8 channels deleted
# ***674 channels left
# # cube 234: 1631990463 m015
# ***11 channels deleted
# ***3 channels left
# # cube 235: 1632069690 m015
# ***2 channels deleted
# ***13 channels left
# # cube 236: 1632077222 m015
# ***460 channels left
# # cube 237: 1632184922 m015
# ***770 channels left
# no data cube for 1632505883, m015
# no data cube for 1632760885, m015
# no data cube for 1633365980, m015
# no data cube for 1633970780, m015
# # cube 238: 1634252028 m015
# ***1 channels deleted
# ***757 channels left
# # cube 239: 1634402485 m015
# ***733 channels left
# no data cube for 1634748682, m015
# no data cube for 1634835083, m015
# no data cube for 1637346562, m015
# # cube 240: 1637354605 m015
# ***1 channels deleted
# ***1022 channels left
# # cube 241: 1637691677 m015
# ***1 channels deleted
# ***798 channels left
# no data cube for 1637699408, m015
# no data cube for 1638130295, m015
# no data cube for 1638294319, m015
# no data cube for 1638301944, m015
# no data cube for 1638386189, m015
# no data cube for 1638639082, m015
# no data cube for 1638647186, m015
# no data cube for 1638898468, m015
# no data cube for 1639157507, m015
# no data cube for 1639331184, m015
# no data cube for 1639935088, m015
# no data cube for 1640540184, m015
# no data cube for 1640712986, m015
# no data cube for 1640799689, m015
# # cube 242: 1630519596 m016
# ***348 channels deleted
# ***0 channels left
# no data cube for 1631379874, m016
# no data cube for 1631387336, m016
# no data cube for 1631552188, m016
# no data cube for 1631559762, m016
# no data cube for 1631659886, m016
# no data cube for 1631667564, m016
# no data cube for 1631724508, m016
# no data cube for 1631732038, m016
# no data cube for 1631810671, m016
# no data cube for 1631818149, m016
# no data cube for 1631982988, m016
# no data cube for 1631990463, m016
# no data cube for 1632069690, m016
# no data cube for 1632077222, m016
# no data cube for 1632184922, m016
# no data cube for 1632505883, m016
# no data cube for 1632760885, m016
# no data cube for 1633365980, m016
# no data cube for 1633970780, m016
# # cube 243: 1634252028 m016
# ***1 channels deleted
# ***748 channels left
# # cube 244: 1634402485 m016
# ***1 channels deleted
# ***678 channels left
# no data cube for 1634748682, m016
# no data cube for 1634835083, m016
# no data cube for 1637346562, m016
# # cube 245: 1637354605 m016
# ***1 channels deleted
# ***1257 channels left
# no data cube for 1637691677, m016
# no data cube for 1637699408, m016
# no data cube for 1638130295, m016
# no data cube for 1638294319, m016
# # cube 246: 1638301944 m016
# ***472 channels deleted
# ***212 channels left
# # cube 247: 1638386189 m016
# ***1 channels deleted
# ***903 channels left
# no data cube for 1638639082, m016
# no data cube for 1638647186, m016
# no data cube for 1638898468, m016
# no data cube for 1639157507, m016
# no data cube for 1639331184, m016
# no data cube for 1639935088, m016
# no data cube for 1640540184, m016
# no data cube for 1640712986, m016
# no data cube for 1640799689, m016
# # cube 248: 1630519596 m017
# ***94 channels left
# no data cube for 1631379874, m017
# no data cube for 1631387336, m017
# no data cube for 1631552188, m017
# # cube 249: 1631559762 m017
# ***96 channels deleted
# ***118 channels left
# no data cube for 1631659886, m017
# # cube 250: 1631667564 m017
# ***506 channels left
# no data cube for 1631724508, m017
# no data cube for 1631732038, m017
# # cube 251: 1631810671 m017
# ***2 channels deleted
# ***768 channels left
# # cube 252: 1631818149 m017
# ***4 channels deleted
# ***315 channels left
# # cube 253: 1631982988 m017
# ***3 channels deleted
# ***783 channels left
# # cube 254: 1631990463 m017
# ***22 channels left
# # cube 255: 1632069690 m017
# ***4 channels deleted
# ***550 channels left
# # cube 256: 1632077222 m017
# ***144 channels left
# # cube 257: 1632184922 m017
# ***535 channels left
# no data cube for 1632505883, m017
# # cube 258: 1632760885 m017
# ***217 channels left
# no data cube for 1633365980, m017
# no data cube for 1633970780, m017
# # cube 259: 1634252028 m017
# ***301 channels left
# # cube 260: 1634402485 m017
# ***54 channels deleted
# ***49 channels left
# no data cube for 1634748682, m017
# no data cube for 1634835083, m017
# no data cube for 1637346562, m017
# # cube 261: 1637354605 m017
# ***1038 channels left
# # cube 262: 1637691677 m017
# ***587 channels deleted
# ***201 channels left
# # cube 263: 1637699408 m017
# ***586 channels left
# no data cube for 1638130295, m017
# no data cube for 1638294319, m017
# # cube 264: 1638301944 m017
# ***63 channels deleted
# ***344 channels left
# # cube 265: 1638386189 m017
# ***272 channels left
# no data cube for 1638639082, m017
# no data cube for 1638647186, m017
# no data cube for 1638898468, m017
# no data cube for 1639157507, m017
# no data cube for 1639331184, m017
# no data cube for 1639935088, m017
# no data cube for 1640540184, m017
# no data cube for 1640712986, m017
# no data cube for 1640799689, m017
# # cube 266: 1630519596 m018
# ***583 channels left
# no data cube for 1631379874, m018
# # cube 267: 1631387336 m018
# ***113 channels deleted
# ***844 channels left
# no data cube for 1631552188, m018
# # cube 268: 1631559762 m018
# ***74 channels deleted
# ***180 channels left
# no data cube for 1631659886, m018
# # cube 269: 1631667564 m018
# ***2 channels deleted
# ***287 channels left
# no data cube for 1631724508, m018
# # cube 270: 1631732038 m018
# ***21 channels deleted
# ***626 channels left
# # cube 271: 1631810671 m018
# ***5 channels deleted
# ***255 channels left
# # cube 272: 1631818149 m018
# ***5 channels deleted
# ***584 channels left
# # cube 273: 1631982988 m018
# ***9 channels deleted
# ***706 channels left
# # cube 274: 1631990463 m018
# ***165 channels deleted
# ***353 channels left
# # cube 275: 1632069690 m018
# ***187 channels left
# # cube 276: 1632077222 m018
# ***7 channels deleted
# ***1283 channels left
# # cube 277: 1632184922 m018
# ***43 channels deleted
# ***598 channels left
# no data cube for 1632505883, m018
# # cube 278: 1632760885 m018
# ***572 channels left
# no data cube for 1633365980, m018
# no data cube for 1633970780, m018
# # cube 279: 1634252028 m018
# ***1 channels deleted
# ***559 channels left
# # cube 280: 1634402485 m018
# ***3 channels deleted
# ***680 channels left
# no data cube for 1634748682, m018
# no data cube for 1634835083, m018
# no data cube for 1637346562, m018
# # cube 281: 1637354605 m018
# ***1 channels deleted
# ***1097 channels left
# # cube 282: 1637691677 m018
# ***652 channels left
# # cube 283: 1637699408 m018
# ***469 channels left
# no data cube for 1638130295, m018
# no data cube for 1638294319, m018
# # cube 284: 1638301944 m018
# ***1 channels deleted
# ***874 channels left
# # cube 285: 1638386189 m018
# ***1175 channels left
# no data cube for 1638639082, m018
# no data cube for 1638647186, m018
# no data cube for 1638898468, m018
# # cube 286: 1639157507 m018
# ***1068 channels deleted
# ***181 channels left
# no data cube for 1639331184, m018
# no data cube for 1639935088, m018
# no data cube for 1640540184, m018
# no data cube for 1640712986, m018
# no data cube for 1640799689, m018
# # cube 287: 1630519596 m019
# ***141 channels left
# no data cube for 1631379874, m019
# no data cube for 1631387336, m019
# no data cube for 1631552188, m019
# no data cube for 1631559762, m019
# no data cube for 1631659886, m019
# # cube 288: 1631667564 m019
# ***184 channels left
# no data cube for 1631724508, m019
# # cube 289: 1631732038 m019
# ***451 channels left
# # cube 290: 1631810671 m019
# ***2 channels deleted
# ***234 channels left
# # cube 291: 1631818149 m019
# ***1 channels deleted
# ***973 channels left
# # cube 292: 1631982988 m019
# ***569 channels left
# # cube 293: 1631990463 m019
# ***1 channels deleted
# ***6 channels left
# # cube 294: 1632069690 m019
# ***128 channels left
# # cube 295: 1632077222 m019
# ***202 channels left
# # cube 296: 1632184922 m019
# ***600 channels left
# no data cube for 1632505883, m019
# # cube 297: 1632760885 m019
# ***753 channels left
# no data cube for 1633365980, m019
# no data cube for 1633970780, m019
# # cube 298: 1634252028 m019
# ***1 channels deleted
# ***627 channels left
# # cube 299: 1634402485 m019
# ***671 channels left
# no data cube for 1634748682, m019
# no data cube for 1634835083, m019
# no data cube for 1637346562, m019
# # cube 300: 1637354605 m019
# ***1066 channels left
# # cube 301: 1637691677 m019
# ***4 channels deleted
# ***749 channels left
# # cube 302: 1637699408 m019
# ***710 channels left
# no data cube for 1638130295, m019
# no data cube for 1638294319, m019
# # cube 303: 1638301944 m019
# ***1 channels deleted
# ***661 channels left
# # cube 304: 1638386189 m019
# ***6 channels deleted
# ***446 channels left
# no data cube for 1638639082, m019
# no data cube for 1638647186, m019
# no data cube for 1638898468, m019
# no data cube for 1639157507, m019
# no data cube for 1639331184, m019
# no data cube for 1639935088, m019
# no data cube for 1640540184, m019
# no data cube for 1640712986, m019
# no data cube for 1640799689, m019
# # cube 305: 1630519596 m020
# ***706 channels left
# no data cube for 1631379874, m020
# no data cube for 1631387336, m020
# no data cube for 1631552188, m020
# no data cube for 1631559762, m020
# no data cube for 1631659886, m020
# # cube 306: 1631667564 m020
# ***254 channels left
# no data cube for 1631724508, m020
# # cube 307: 1631732038 m020
# ***1 channels deleted
# ***707 channels left
# # cube 308: 1631810671 m020
# ***95 channels left
# no data cube for 1631818149, m020
# # cube 309: 1631982988 m020
# ***534 channels left
# # cube 310: 1631990463 m020
# ***14 channels deleted
# ***13 channels left
# # cube 311: 1632069690 m020
# ***90 channels left
# # cube 312: 1632077222 m020
# ***1152 channels left
# # cube 313: 1632184922 m020
# ***710 channels left
# no data cube for 1632505883, m020
# # cube 314: 1632760885 m020
# ***1060 channels left
# no data cube for 1633365980, m020
# no data cube for 1633970780, m020
# # cube 315: 1634252028 m020
# ***941 channels left
# # cube 316: 1634402485 m020
# ***1 channels deleted
# ***764 channels left
# no data cube for 1634748682, m020
# no data cube for 1634835083, m020
# no data cube for 1637346562, m020
# # cube 317: 1637354605 m020
# ***1303 channels left
# # cube 318: 1637691677 m020
# ***796 channels left
# # cube 319: 1637699408 m020
# ***659 channels left
# no data cube for 1638130295, m020
# no data cube for 1638294319, m020
# # cube 320: 1638301944 m020
# ***539 channels left
# no data cube for 1638386189, m020
# no data cube for 1638639082, m020
# no data cube for 1638647186, m020
# no data cube for 1638898468, m020
# no data cube for 1639157507, m020
# no data cube for 1639331184, m020
# no data cube for 1639935088, m020
# no data cube for 1640540184, m020
# no data cube for 1640712986, m020
# no data cube for 1640799689, m020
# # cube 321: 1630519596 m021
# ***8 channels deleted
# ***255 channels left
# no data cube for 1631379874, m021
# # cube 322: 1631387336 m021
# ***92 channels left
# no data cube for 1631552188, m021
# # cube 323: 1631559762 m021
# ***18 channels deleted
# ***283 channels left
# no data cube for 1631659886, m021
# # cube 324: 1631667564 m021
# ***17 channels deleted
# ***283 channels left
# no data cube for 1631724508, m021
# # cube 325: 1631732038 m021
# ***1 channels deleted
# ***677 channels left
# # cube 326: 1631810671 m021
# ***2 channels deleted
# ***307 channels left
# # cube 327: 1631818149 m021
# ***517 channels left
# # cube 328: 1631982988 m021
# ***651 channels left
# # cube 329: 1631990463 m021
# ***142 channels left
# # cube 330: 1632069690 m021
# ***1 channels deleted
# ***376 channels left
# # cube 331: 1632077222 m021
# ***1 channels deleted
# ***1359 channels left
# # cube 332: 1632184922 m021
# ***140 channels left
# no data cube for 1632505883, m021
# no data cube for 1632760885, m021
# # cube 333: 1633365980 m021
# ***7 channels deleted
# ***405 channels left
# no data cube for 1633970780, m021
# # cube 334: 1634252028 m021
# ***489 channels left
# # cube 335: 1634402485 m021
# ***456 channels left
# no data cube for 1634748682, m021
# no data cube for 1634835083, m021
# no data cube for 1637346562, m021
# # cube 336: 1637354605 m021
# ***734 channels left
# # cube 337: 1637691677 m021
# ***720 channels left
# # cube 338: 1637699408 m021
# ***334 channels left
# no data cube for 1638130295, m021
# no data cube for 1638294319, m021
# # cube 339: 1638301944 m021
# ***622 channels left
# no data cube for 1638386189, m021
# no data cube for 1638639082, m021
# no data cube for 1638647186, m021
# no data cube for 1638898468, m021
# # cube 340: 1639157507 m021
# ***157 channels deleted
# ***442 channels left
# no data cube for 1639331184, m021
# no data cube for 1639935088, m021
# no data cube for 1640540184, m021
# no data cube for 1640712986, m021
# no data cube for 1640799689, m021
# no data cube for 1630519596, m022
# no data cube for 1631379874, m022
# no data cube for 1631387336, m022
# no data cube for 1631552188, m022
# no data cube for 1631559762, m022
# no data cube for 1631659886, m022
# no data cube for 1631667564, m022
# no data cube for 1631724508, m022
# no data cube for 1631732038, m022
# # cube 341: 1631810671 m022
# ***1 channels deleted
# ***249 channels left
# no data cube for 1631818149, m022
# # cube 342: 1631982988 m022
# ***1 channels deleted
# ***521 channels left
# # cube 343: 1631990463 m022
# ***168 channels deleted
# ***57 channels left
# # cube 344: 1632069690 m022
# ***1 channels deleted
# ***613 channels left
# # cube 345: 1632077222 m022
# ***383 channels left
# # cube 346: 1632184922 m022
# ***545 channels left
# no data cube for 1632505883, m022
# # cube 347: 1632760885 m022
# ***1204 channels left
# no data cube for 1633365980, m022
# no data cube for 1633970780, m022
# # cube 348: 1634252028 m022
# ***542 channels left
# # cube 349: 1634402485 m022
# ***575 channels left
# no data cube for 1634748682, m022
# no data cube for 1634835083, m022
# no data cube for 1637346562, m022
# # cube 350: 1637354605 m022
# ***2 channels deleted
# ***1020 channels left
# no data cube for 1637691677, m022
# # cube 351: 1637699408 m022
# ***464 channels left
# no data cube for 1638130295, m022
# no data cube for 1638294319, m022
# # cube 352: 1638301944 m022
# ***482 channels left
# # cube 353: 1638386189 m022
# ***527 channels left
# no data cube for 1638639082, m022
# no data cube for 1638647186, m022
# no data cube for 1638898468, m022
# no data cube for 1639157507, m022
# no data cube for 1639331184, m022
# no data cube for 1639935088, m022
# no data cube for 1640540184, m022
# no data cube for 1640712986, m022
# no data cube for 1640799689, m022
# # cube 354: 1630519596 m023
# ***4 channels left
# no data cube for 1631379874, m023
# no data cube for 1631387336, m023
# no data cube for 1631552188, m023
# # cube 355: 1631559762 m023
# ***937 channels deleted
# ***43 channels left
# no data cube for 1631659886, m023
# no data cube for 1631667564, m023
# no data cube for 1631724508, m023
# no data cube for 1631732038, m023
# # cube 356: 1631810671 m023
# ***3 channels deleted
# ***491 channels left
# no data cube for 1631818149, m023
# # cube 357: 1631982988 m023
# ***800 channels left
# # cube 358: 1631990463 m023
# ***1 channels deleted
# ***5 channels left
# # cube 359: 1632069690 m023
# ***1 channels deleted
# ***77 channels left
# # cube 360: 1632077222 m023
# ***1 channels deleted
# ***419 channels left
# # cube 361: 1632184922 m023
# ***5 channels deleted
# ***853 channels left
# no data cube for 1632505883, m023
# # cube 362: 1632760885 m023
# ***1 channels deleted
# ***1125 channels left
# no data cube for 1633365980, m023
# no data cube for 1633970780, m023
# # cube 363: 1634252028 m023
# ***2 channels deleted
# ***1129 channels left
# no data cube for 1634402485, m023
# no data cube for 1634748682, m023
# no data cube for 1634835083, m023
# no data cube for 1637346562, m023
# # cube 364: 1637354605 m023
# ***54 channels deleted
# ***835 channels left
# # cube 365: 1637691677 m023
# ***787 channels deleted
# ***0 channels left
# # cube 366: 1637699408 m023
# ***709 channels left
# no data cube for 1638130295, m023
# no data cube for 1638294319, m023
# # cube 367: 1638301944 m023
# ***5 channels deleted
# ***346 channels left
# no data cube for 1638386189, m023
# no data cube for 1638639082, m023
# no data cube for 1638647186, m023
# no data cube for 1638898468, m023
# no data cube for 1639157507, m023
# no data cube for 1639331184, m023
# no data cube for 1639935088, m023
# no data cube for 1640540184, m023
# no data cube for 1640712986, m023
# no data cube for 1640799689, m023
# no data cube for 1630519596, m024
# no data cube for 1631379874, m024
# no data cube for 1631387336, m024
# no data cube for 1631552188, m024
# no data cube for 1631559762, m024
# no data cube for 1631659886, m024
# no data cube for 1631667564, m024
# no data cube for 1631724508, m024
# no data cube for 1631732038, m024
# no data cube for 1631810671, m024
# no data cube for 1631818149, m024
# # cube 368: 1631982988 m024
# ***711 channels deleted
# ***23 channels left
# # cube 369: 1631990463 m024
# ***130 channels deleted
# ***0 channels left
# no data cube for 1632069690, m024
# # cube 370: 1632077222 m024
# ***404 channels deleted
# ***852 channels left
# # cube 371: 1632184922 m024
# ***78 channels deleted
# ***551 channels left
# no data cube for 1632505883, m024
# no data cube for 1632760885, m024
# no data cube for 1633365980, m024
# no data cube for 1633970780, m024
# no data cube for 1634252028, m024
# # cube 372: 1634402485 m024
# ***239 channels deleted
# ***543 channels left
# no data cube for 1634748682, m024
# no data cube for 1634835083, m024
# no data cube for 1637346562, m024
# no data cube for 1637354605, m024
# no data cube for 1637691677, m024
# no data cube for 1637699408, m024
# no data cube for 1638130295, m024
# no data cube for 1638294319, m024
# no data cube for 1638301944, m024
# no data cube for 1638386189, m024
# no data cube for 1638639082, m024
# no data cube for 1638647186, m024
# no data cube for 1638898468, m024
# no data cube for 1639157507, m024
# no data cube for 1639331184, m024
# no data cube for 1639935088, m024
# no data cube for 1640540184, m024
# no data cube for 1640712986, m024
# no data cube for 1640799689, m024
# # cube 373: 1630519596 m025
# ***100 channels deleted
# ***153 channels left
# no data cube for 1631379874, m025
# no data cube for 1631387336, m025
# no data cube for 1631552188, m025
# no data cube for 1631559762, m025
# no data cube for 1631659886, m025
# no data cube for 1631667564, m025
# no data cube for 1631724508, m025
# # cube 374: 1631732038 m025
# ***1 channels deleted
# ***319 channels left
# # cube 375: 1631810671 m025
# ***3 channels deleted
# ***291 channels left
# no data cube for 1631818149, m025
# # cube 376: 1631982988 m025
# ***434 channels left
# # cube 377: 1631990463 m025
# ***3 channels deleted
# ***6 channels left
# # cube 378: 1632069690 m025
# ***3 channels deleted
# ***577 channels left
# # cube 379: 1632077222 m025
# ***1003 channels left
# # cube 380: 1632184922 m025
# ***570 channels left
# no data cube for 1632505883, m025
# no data cube for 1632760885, m025
# no data cube for 1633365980, m025
# no data cube for 1633970780, m025
# # cube 381: 1634252028 m025
# ***252 channels left
# # cube 382: 1634402485 m025
# ***4 channels deleted
# ***564 channels left
# no data cube for 1634748682, m025
# no data cube for 1634835083, m025
# no data cube for 1637346562, m025
# # cube 383: 1637354605 m025
# ***41 channels deleted
# ***412 channels left
# # cube 384: 1637691677 m025
# ***374 channels deleted
# ***138 channels left
# # cube 385: 1637699408 m025
# ***315 channels deleted
# ***640 channels left
# no data cube for 1638130295, m025
# no data cube for 1638294319, m025
# # cube 386: 1638301944 m025
# ***197 channels deleted
# ***353 channels left
# # cube 387: 1638386189 m025
# ***7 channels deleted
# ***817 channels left
# no data cube for 1638639082, m025
# no data cube for 1638647186, m025
# no data cube for 1638898468, m025
# no data cube for 1639157507, m025
# no data cube for 1639331184, m025
# no data cube for 1639935088, m025
# no data cube for 1640540184, m025
# no data cube for 1640712986, m025
# no data cube for 1640799689, m025
# no data cube for 1630519596, m026
# no data cube for 1631379874, m026
# no data cube for 1631387336, m026
# no data cube for 1631552188, m026
# no data cube for 1631559762, m026
# no data cube for 1631659886, m026
# no data cube for 1631667564, m026
# no data cube for 1631724508, m026
# # cube 388: 1631732038 m026
# ***263 channels left
# # cube 389: 1631810671 m026
# ***4 channels deleted
# ***481 channels left
# no data cube for 1631818149, m026
# # cube 390: 1631982988 m026
# ***393 channels left
# # cube 391: 1631990463 m026
# ***4 channels deleted
# ***5 channels left
# # cube 392: 1632069690 m026
# ***266 channels left
# # cube 393: 1632077222 m026
# ***1265 channels left
# # cube 394: 1632184922 m026
# ***582 channels left
# no data cube for 1632505883, m026
# # cube 395: 1632760885 m026
# ***988 channels left
# no data cube for 1633365980, m026
# no data cube for 1633970780, m026
# # cube 396: 1634252028 m026
# ***626 channels left
# # cube 397: 1634402485 m026
# ***807 channels left
# no data cube for 1634748682, m026
# no data cube for 1634835083, m026
# no data cube for 1637346562, m026
# # cube 398: 1637354605 m026
# ***1308 channels left
# no data cube for 1637691677, m026
# # cube 399: 1637699408 m026
# ***618 channels left
# no data cube for 1638130295, m026
# no data cube for 1638294319, m026
# no data cube for 1638301944, m026
# no data cube for 1638386189, m026
# no data cube for 1638639082, m026
# no data cube for 1638647186, m026
# no data cube for 1638898468, m026
# no data cube for 1639157507, m026
# no data cube for 1639331184, m026
# no data cube for 1639935088, m026
# no data cube for 1640540184, m026
# no data cube for 1640712986, m026
# no data cube for 1640799689, m026
# # cube 400: 1630519596 m027
# ***506 channels left
# no data cube for 1631379874, m027
# no data cube for 1631387336, m027
# no data cube for 1631552188, m027
# no data cube for 1631559762, m027
# no data cube for 1631659886, m027
# no data cube for 1631667564, m027
# no data cube for 1631724508, m027
# no data cube for 1631732038, m027
# # cube 401: 1631810671 m027
# ***289 channels left
# # cube 402: 1631818149 m027
# ***2 channels deleted
# ***689 channels left
# no data cube for 1631982988, m027
# no data cube for 1631990463, m027
# # cube 403: 1632069690 m027
# ***548 channels left
# # cube 404: 1632077222 m027
# ***1 channels deleted
# ***1370 channels left
# # cube 405: 1632184922 m027
# ***637 channels left
# no data cube for 1632505883, m027
# # cube 406: 1632760885 m027
# ***574 channels left
# no data cube for 1633365980, m027
# no data cube for 1633970780, m027
# # cube 407: 1634252028 m027
# ***509 channels left
# # cube 408: 1634402485 m027
# ***800 channels left
# no data cube for 1634748682, m027
# no data cube for 1634835083, m027
# no data cube for 1637346562, m027
# # cube 409: 1637354605 m027
# ***1357 channels left
# # cube 410: 1637691677 m027
# ***87 channels deleted
# ***709 channels left
# # cube 411: 1637699408 m027
# ***1 channels deleted
# ...
# no data cube for 1637699408, m055
# no data cube for 1638130295, m055
# no data cube for 1638294319, m055
# # cube 846: 1638301944 m055
# ***165 channels deleted
# ***135 channels left
# no data cube for 1638386189, m055
# no data cube for 1638639082, m055
# no data cube for 1638647186, m055
# no data cube for 1638898468, m055
# no data cube for 1639157507, m055
# no data cube for 1639331184, m055
# no data cube for 1639935088, m055
# no data cube for 1640540184, m055
# no data cube for 1640712986, m055
# no data cube for 1640799689, m055
# # cube 847: 1630519596 m056
# ***523 channels left
# no data cube for 1631379874, m056
# # cube 848: 1631387336 m056
# ***1 channels deleted
# ***898 channels left
# no data cube for 1631552188, m056
# # cube 849: 1631559762 m056
# ***2 channels deleted
# ***705 channels left
# no data cube for 1631659886, m056
# # cube 850: 1631667564 m056
# ***1 channels deleted
# ***549 channels left
# no data cube for 1631724508, m056
# # cube 851: 1631732038 m056
# ***2 channels deleted
# ***799 channels left
# # cube 852: 1631810671 m056
# ***690 channels left
# # cube 853: 1631818149 m056
# ***1 channels deleted
# ***241 channels left
# # cube 854: 1631982988 m056
# ***1 channels deleted
# ***823 channels left
# # cube 855: 1631990463 m056
# ***3 channels deleted
# ***802 channels left
# # cube 856: 1632069690 m056
# ***8 channels deleted
# ***727 channels left
# # cube 857: 1632077222 m056
# ***4 channels deleted
# ***1330 channels left
# # cube 858: 1632184922 m056
# ***447 channels left
# no data cube for 1632505883, m056
# no data cube for 1632760885, m056
# # cube 859: 1633365980 m056
# ***11 channels deleted
# ***1244 channels left
# no data cube for 1633970780, m056
# # cube 860: 1634252028 m056
# ***492 channels left
# # cube 861: 1634402485 m056
# ***1 channels deleted
# ***695 channels left
# no data cube for 1634748682, m056
# no data cube for 1634835083, m056
# no data cube for 1637346562, m056
# # cube 862: 1637354605 m056
# ***399 channels left
# # cube 863: 1637691677 m056
# ***4 channels deleted
# ***779 channels left
# # cube 864: 1637699408 m056
# ***849 channels left
# no data cube for 1638130295, m056
# no data cube for 1638294319, m056
# no data cube for 1638301944, m056
# # cube 865: 1638386189 m056
# ***5 channels deleted
# ***1230 channels left
# no data cube for 1638639082, m056
# no data cube for 1638647186, m056
# no data cube for 1638898468, m056
# no data cube for 1639157507, m056
# no data cube for 1639331184, m056
# no data cube for 1639935088, m056
# no data cube for 1640540184, m056
# no data cube for 1640712986, m056
# no data cube for 1640799689, m056
# # cube 866: 1630519596 m057
# ***206 channels deleted
# ***265 channels left
# no data cube for 1631379874, m057
# # cube 867: 1631387336 m057
# ***260 channels deleted
# ***89 channels left
# no data cube for 1631552188, m057
# # cube 868: 1631559762 m057
# ***51 channels deleted
# ***195 channels left
# no data cube for 1631659886, m057
# no data cube for 1631667564, m057
# no data cube for 1631724508, m057
# # cube 869: 1631732038 m057
# ***1 channels deleted
# ***689 channels left
# # cube 870: 1631810671 m057
# ***4 channels deleted
# ***372 channels left
# no data cube for 1631818149, m057
# # cube 871: 1631982988 m057
# ***3 channels deleted
# ***630 channels left
# # cube 872: 1631990463 m057
# ***6 channels deleted
# ***10 channels left
# # cube 873: 1632069690 m057
# ***135 channels left
# # cube 874: 1632077222 m057
# ***1 channels deleted
# ***1282 channels left
# # cube 875: 1632184922 m057
# ***1 channels deleted
# ***912 channels left
# no data cube for 1632505883, m057
# no data cube for 1632760885, m057
# no data cube for 1633365980, m057
# no data cube for 1633970780, m057
# # cube 876: 1634252028 m057
# ***2 channels deleted
# ***1084 channels left
# # cube 877: 1634402485 m057
# ***2 channels deleted
# ***653 channels left
# no data cube for 1634748682, m057
# no data cube for 1634835083, m057
# no data cube for 1637346562, m057
# # cube 878: 1637354605 m057
# ***375 channels deleted
# ***341 channels left
# # cube 879: 1637691677 m057
# ***452 channels deleted
# ***227 channels left
# # cube 880: 1637699408 m057
# ***2 channels deleted
# ***820 channels left
# no data cube for 1638130295, m057
# no data cube for 1638294319, m057
# # cube 881: 1638301944 m057
# ***237 channels left
# no data cube for 1638386189, m057
# no data cube for 1638639082, m057
# no data cube for 1638647186, m057
# no data cube for 1638898468, m057
# no data cube for 1639157507, m057
# no data cube for 1639331184, m057
# no data cube for 1639935088, m057
# no data cube for 1640540184, m057
# no data cube for 1640712986, m057
# no data cube for 1640799689, m057
# # cube 882: 1630519596 m058
# ***5 channels deleted
# ***1273 channels left
# no data cube for 1631379874, m058
# # cube 883: 1631387336 m058
# ***1068 channels left
# no data cube for 1631552188, m058
# # cube 884: 1631559762 m058
# ***8 channels deleted
# ***1230 channels left
# no data cube for 1631659886, m058
# # cube 885: 1631667564 m058
# ***2 channels deleted
# ***868 channels left
# no data cube for 1631724508, m058
# # cube 886: 1631732038 m058
# ***1 channels deleted
# ***751 channels left
# # cube 887: 1631810671 m058
# ***4 channels deleted
# ***727 channels left
# # cube 888: 1631818149 m058
# ***5 channels deleted
# ***540 channels left
# # cube 889: 1631982988 m058
# ***2 channels deleted
# ***804 channels left
# # cube 890: 1631990463 m058
# ***2 channels deleted
# ***679 channels left
# # cube 891: 1632069690 m058
# ***11 channels deleted
# ***693 channels left
# # cube 892: 1632077222 m058
# ***2 channels deleted
# ***1145 channels left
# # cube 893: 1632184922 m058
# ***862 channels left
# no data cube for 1632505883, m058
# # cube 894: 1632760885 m058
# ***3 channels deleted
# ***1175 channels left
# # cube 895: 1633365980 m058
# ***7 channels deleted
# ***1168 channels left
# no data cube for 1633970780, m058
# # cube 896: 1634252028 m058
# ***11 channels deleted
# ***1217 channels left
# # cube 897: 1634402485 m058
# ***1 channels deleted
# ***763 channels left
# no data cube for 1634748682, m058
# no data cube for 1634835083, m058
# no data cube for 1637346562, m058
# # cube 898: 1637354605 m058
# ***11 channels deleted
# ***1235 channels left
# # cube 899: 1637691677 m058
# ***3 channels deleted
# ***799 channels left
# # cube 900: 1637699408 m058
# ***1144 channels left
# no data cube for 1638130295, m058
# no data cube for 1638294319, m058
# # cube 901: 1638301944 m058
# ***14 channels deleted
# ***855 channels left
# # cube 902: 1638386189 m058
# ***9 channels deleted
# ***1250 channels left
# no data cube for 1638639082, m058
# no data cube for 1638647186, m058
# no data cube for 1638898468, m058
# no data cube for 1639157507, m058
# no data cube for 1639331184, m058
# no data cube for 1639935088, m058
# no data cube for 1640540184, m058
# no data cube for 1640712986, m058
# no data cube for 1640799689, m058
# # cube 903: 1630519596 m059
# ***1414 channels left
# no data cube for 1631379874, m059
# # cube 904: 1631387336 m059
# ***11 channels deleted
# ***1407 channels left
# no data cube for 1631552188, m059
# # cube 905: 1631559762 m059
# ***4 channels deleted
# ***1425 channels left
# no data cube for 1631659886, m059
# # cube 906: 1631667564 m059
# ***1261 channels left
# no data cube for 1631724508, m059
# # cube 907: 1631732038 m059
# ***72 channels deleted
# ***412 channels left
# # cube 908: 1631810671 m059
# ***5 channels deleted
# ***815 channels left
# # cube 909: 1631818149 m059
# ***628 channels left
# # cube 910: 1631982988 m059
# ***1 channels deleted
# ***806 channels left
# # cube 911: 1631990463 m059
# ***2 channels deleted
# ***810 channels left
# # cube 912: 1632069690 m059
# ***20 channels deleted
# ***789 channels left
# # cube 913: 1632077222 m059
# ***11 channels deleted
# ***1408 channels left
# # cube 914: 1632184922 m059
# ***2 channels deleted
# ***869 channels left
# no data cube for 1632505883, m059
# # cube 915: 1632760885 m059
# ***2 channels deleted
# ***1337 channels left
# # cube 916: 1633365980 m059
# ***5 channels deleted
# ***705 channels left
# no data cube for 1633970780, m059
# # cube 917: 1634252028 m059
# ***8 channels deleted
# ***1205 channels left
# # cube 918: 1634402485 m059
# ***636 channels left
# no data cube for 1634748682, m059
# no data cube for 1634835083, m059
# # cube 919: 1637346562 m059
# ***253 channels left
# # cube 920: 1637354605 m059
# ***2 channels deleted
# ***1232 channels left
# # cube 921: 1637691677 m059
# ***4 channels deleted
# ***812 channels left
# # cube 922: 1637699408 m059
# ***1022 channels left
# no data cube for 1638130295, m059
# # cube 923: 1638294319 m059
# ***3 channels deleted
# ***408 channels left
# # cube 924: 1638301944 m059
# ***4 channels deleted
# ***1288 channels left
# # cube 925: 1638386189 m059
# ***51 channels deleted
# ***1310 channels left
# # cube 926: 1638639082 m059
# ***1 channels deleted
# ***1245 channels left
# no data cube for 1638647186, m059
# no data cube for 1638898468, m059
# # cube 927: 1639157507 m059
# ***401 channels left
# no data cube for 1639331184, m059
# no data cube for 1639935088, m059
# no data cube for 1640540184, m059
# no data cube for 1640712986, m059
# # cube 928: 1640799689 m059
# ***16 channels deleted
# ***328 channels left
# no data cube for 1630519596, m060
# no data cube for 1631379874, m060
# no data cube for 1631387336, m060
# no data cube for 1631552188, m060
# no data cube for 1631559762, m060
# no data cube for 1631659886, m060
# no data cube for 1631667564, m060
# no data cube for 1631724508, m060
# no data cube for 1631732038, m060
# no data cube for 1631810671, m060
# no data cube for 1631818149, m060
# no data cube for 1631982988, m060
# no data cube for 1631990463, m060
# no data cube for 1632069690, m060
# no data cube for 1632077222, m060
# no data cube for 1632184922, m060
# no data cube for 1632505883, m060
# no data cube for 1632760885, m060
# no data cube for 1633365980, m060
# no data cube for 1633970780, m060
# no data cube for 1634252028, m060
# no data cube for 1634402485, m060
# no data cube for 1634748682, m060
# no data cube for 1634835083, m060
# no data cube for 1637346562, m060
# no data cube for 1637354605, m060
# no data cube for 1637691677, m060
# no data cube for 1637699408, m060
# no data cube for 1638130295, m060
# no data cube for 1638294319, m060
# no data cube for 1638301944, m060
# no data cube for 1638386189, m060
# no data cube for 1638639082, m060
# no data cube for 1638647186, m060
# no data cube for 1638898468, m060
# no data cube for 1639157507, m060
# no data cube for 1639331184, m060
# no data cube for 1639935088, m060
# no data cube for 1640540184, m060
# no data cube for 1640712986, m060
# no data cube for 1640799689, m060
# # cube 929: 1630519596 m061
# ***10 channels deleted
# ***417 channels left
# no data cube for 1631379874, m061
# # cube 930: 1631387336 m061
# ***559 channels left
# no data cube for 1631552188, m061
# no data cube for 1631559762, m061
# no data cube for 1631659886, m061
# no data cube for 1631667564, m061
# no data cube for 1631724508, m061
# no data cube for 1631732038, m061
# # cube 931: 1631810671 m061
# ***128 channels left
# # cube 932: 1631818149 m061
# ***213 channels deleted
# ***187 channels left
# # cube 933: 1631982988 m061
# ***75 channels left
# # cube 934: 1631990463 m061
# ***245 channels deleted
# ***386 channels left
# # cube 935: 1632069690 m061
# ***5 channels deleted
# ***816 channels left
# # cube 936: 1632077222 m061
# ***706 channels left
# # cube 937: 1632184922 m061
# ***442 channels left
# no data cube for 1632505883, m061
# no data cube for 1632760885, m061
# # cube 938: 1633365980 m061
# ***1051 channels left
# no data cube for 1633970780, m061
# # cube 939: 1634252028 m061
# ***1 channels deleted
# ***378 channels left
# no data cube for 1634402485, m061
# no data cube for 1634748682, m061
# no data cube for 1634835083, m061
# no data cube for 1637346562, m061
# # cube 940: 1637354605 m061
# ***2 channels deleted
# ***1232 channels left
# no data cube for 1637691677, m061
# no data cube for 1637699408, m061
# no data cube for 1638130295, m061
# no data cube for 1638294319, m061
# # cube 941: 1638301944 m061
# ***828 channels left
# # cube 942: 1638386189 m061
# ***3 channels deleted
# ***1175 channels left
# no data cube for 1638639082, m061
# no data cube for 1638647186, m061
# no data cube for 1638898468, m061
# no data cube for 1639157507, m061
# no data cube for 1639331184, m061
# no data cube for 1639935088, m061
# no data cube for 1640540184, m061
# no data cube for 1640712986, m061
# no data cube for 1640799689, m061
# # cube 943: 1630519596 m062
# ***204 channels deleted
# ***160 channels left
# no data cube for 1631379874, m062
# # cube 944: 1631387336 m062
# ***35 channels deleted
# ***895 channels left
# no data cube for 1631552188, m062
# no data cube for 1631559762, m062
# no data cube for 1631659886, m062
# # cube 945: 1631667564 m062
# ***1 channels deleted
# ***779 channels left
# no data cube for 1631724508, m062
# # cube 946: 1631732038 m062
# ***2 channels deleted
# ***776 channels left
# # cube 947: 1631810671 m062
# ***51 channels deleted
# ***447 channels left
# no data cube for 1631818149, m062
# no data cube for 1631982988, m062
# # cube 948: 1631990463 m062
# ***569 channels deleted
# ***53 channels left
# no data cube for 1632069690, m062
# # cube 949: 1632077222 m062
# ***1 channels deleted
# ***1276 channels left
# # cube 950: 1632184922 m062
# ***388 channels left
# no data cube for 1632505883, m062
# # cube 951: 1632760885 m062
# ***58 channels deleted
# ***1090 channels left
# no data cube for 1633365980, m062
# no data cube for 1633970780, m062
# # cube 952: 1634252028 m062
# ***631 channels left
# # cube 953: 1634402485 m062
# ***567 channels left
# no data cube for 1634748682, m062
# no data cube for 1634835083, m062
# no data cube for 1637346562, m062
# # cube 954: 1637354605 m062
# ***1178 channels left
# # cube 955: 1637691677 m062
# ***7 channels deleted
# ***807 channels left
# # cube 956: 1637699408 m062
# ***14 channels deleted
# ***955 channels left
# no data cube for 1638130295, m062
# no data cube for 1638294319, m062
# no data cube for 1638301944, m062
# # cube 957: 1638386189 m062
# ***2 channels deleted
# ***261 channels left
# no data cube for 1638639082, m062
# no data cube for 1638647186, m062
# no data cube for 1638898468, m062
# no data cube for 1639157507, m062
# no data cube for 1639331184, m062
# no data cube for 1639935088, m062
# no data cube for 1640540184, m062
# no data cube for 1640712986, m062
# no data cube for 1640799689, m062
# # cube 958: 1630519596 m063
# ***14 channels deleted
# ***909 channels left
# no data cube for 1631379874, m063
# no data cube for 1631387336, m063
# no data cube for 1631552188, m063
# no data cube for 1631559762, m063
# no data cube for 1631659886, m063
# no data cube for 1631667564, m063
# no data cube for 1631724508, m063
# no data cube for 1631732038, m063
# # cube 959: 1631810671 m063
# ***293 channels deleted
# ***136 channels left
# no data cube for 1631818149, m063
# # cube 960: 1631982988 m063
# ***424 channels deleted
# ***36 channels left
# # cube 961: 1631990463 m063
# ***566 channels deleted
# ***5 channels left
# # cube 962: 1632069690 m063
# ***2 channels left
# no data cube for 1632077222, m063
# # cube 963: 1632184922 m063
# ***720 channels deleted
# ***122 channels left
# no data cube for 1632505883, m063
# no data cube for 1632760885, m063
# no data cube for 1633365980, m063
# no data cube for 1633970780, m063
# # cube 964: 1634252028 m063
# ***1 channels deleted
# ***667 channels left
# # cube 965: 1634402485 m063
# ***18 channels deleted
# ***631 channels left
# no data cube for 1634748682, m063
# no data cube for 1634835083, m063
# no data cube for 1637346562, m063
# no data cube for 1637354605, m063
# no data cube for 1637691677, m063
# # cube 966: 1637699408 m063
# ***129 channels deleted
# ***0 channels left
# no data cube for 1638130295, m063
# no data cube for 1638294319, m063
# no data cube for 1638301944, m063
# no data cube for 1638386189, m063
# no data cube for 1638639082, m063
# no data cube for 1638647186, m063
# no data cube for 1638898468, m063
# no data cube for 1639157507, m063
# no data cube for 1639331184, m063
# no data cube for 1639935088, m063
# no data cube for 1640540184, m063
# no data cube for 1640712986, m063
# no data cube for 1640799689, m063
# 36334
# total channel number left: 634042
# list for Iter2 saved
# (array([601]),) [732.]
# [0. 0. 0. ... 0. 0. 0.]
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:297: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:298: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:299: RuntimeWarning: invalid value encountered in true_divide
# 966

# %%
print (n_ch_keep,np.sum(total_count_list))
if n_ch_keep==int(np.sum(total_count_list)):
    print ('# n_ch_keep==np.sum(total_count_list)')
else:
    print ('*** n_ch_keep!=np.sum(total_count_list)')
# Out:
# 634042 634042.0
# # n_ch_keep==np.sum(total_count_list)

# %%
end
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2ff02905e7b7> in <module>()
# ----> 1 end
#
# NameError: name 'end' is not defined

# %% [markdown]
# # reload data to check

# %%
print (pix_deg, std_sigma, i_iter)

# %%
total_count=966
i_iter=0

# %%
#input_file2='/idia/projects/hi_im/raw_vis/MeerKLASS2021/level6/'
input_file2='./'

# %%
Fits0=input_file2+'ALL_scan'+str(total_count)+'_Tsky_cube_p0.3d.fits'
cube0 = fits.open(Fits0)[0].data
print (np.shape(cube0))

Fits1=input_file2+'ALL_scan'+str(total_count)+'_Tresi_cube_p0.3d.fits'
cube1 = fits.open(Fits1)[0].data
print (np.shape(cube1))

Fits2=input_file2+'ALL_scan'+str(total_count)+'_Npix_count_cube_p0.3d.fits'
cube2 = fits.open(Fits2)[0].data
print (np.shape(cube2))

Fits3=input_file2+'ALL_scan'+str(total_count)+'_P_xy_count_p0.3d.fits'
cube3 = fits.open(Fits3)[0].data
print (np.shape(cube3))

# %%
w2=WCS(Fits0).dropaxis(-1)
print (w2)

# %%
#check data
assert((cube0[~np.isnan(cube0)]==Tsky_xy[~np.isnan(Tsky_xy)]).all()==True)
print (np.where(Tsky_xy==np.nanmax(Tsky_xy)), np.nanmax(Tsky_xy))
assert((cube1[~np.isnan(cube1)]==Tresi_xy[~np.isnan(Tresi_xy)]).all()==True)
print (np.where(Tresi_xy==np.nanmax(Tresi_xy)), np.nanmax(Tresi_xy))

# %%
plt.figure(figsize=(18,5))
plt.subplot(projection=w)
plt.grid(color='grey',lw=.1)
plt.imshow(Tsky_xy[:,:,ch_plot].T,cmap=kv.cmap1(),aspect='auto',vmin=2.9,vmax=3.55)
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
#plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
plt.colorbar(label='Kelvin')
plt.xlabel('R. A. (J2000)')
plt.ylabel('Dec (J2000)')
plt.title(r'$\bar T_{sky}$'+' map for '+str(total_count_plot)+' scans, '+str(pix_deg)+' deg/pix, '
                              +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
#plt.savefig('F_Tsky_all_ch'+str(ch_plot)+'_iter'+str(i_iter)+'.pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(18,5))
plt.subplot(projection=w)
plt.grid(color='grey',lw=.1)
plt.imshow(Tresi_xy[:,:,ch_plot].T,cmap=kv.cmap2(),aspect='auto',vmin=-0.25,vmax=0.25)
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
#plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
plt.colorbar(label='Kelvin')
plt.xlabel('R. A. (J2000)')
plt.ylabel('Dec (J2000)')
plt.title(r'$\bar T_{res}$'+' map for '+str(total_count_plot)+' scans, '+str(pix_deg)+' deg/pix, '
                              +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
#plt.savefig('F_Tsky_all_ch'+str(ch_plot)+'_iter'+str(i_iter)+'.pdf', bbox_inches='tight')
plt.show()

# %%
total_count_plot1=total_count

# %%
plt.figure(figsize=(15,5))
ax=plt.subplot(projection=w2)
plt.grid(color='grey',lw=.15)
plt.imshow(cube0[:,:,ch_plot].T,cmap=kv.cmap1(),aspect='auto', vmin=2.9,vmax=3.55)
#plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar(label='Kelvin')
plt.xlabel('R. A. (J2000)',fontsize=16)
plt.ylabel('Dec (J2000)',fontsize=16)
plt.title(r'$\bar T_{sky}$'+' map for '+str(total_count_plot1)+' scans, '+str(pix_deg)+' deg/pix, '
                               +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
plt.xlim([15,Npix_x-15])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
plt.savefig('ALL2.png', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(15,5))
ax=plt.subplot(projection=w2)
plt.grid(color='grey',lw=.15)
plt.imshow(cube1[:,:,ch_plot].T,cmap=kv.cmap2(),aspect='auto', vmin=-0.25,vmax=0.25)
#plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar(label='Kelvin')
plt.xlabel('R. A. (J2000)',fontsize=16)
plt.ylabel('Dec (J2000)',fontsize=16)
plt.title(r'$\bar T_{res}$'+' map for '+str(total_count_plot1)+' scans, '+str(pix_deg)+' deg/pix, '
                                  +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
plt.xlim([15,Npix_x-15])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
plt.savefig('ALL2.png', bbox_inches='tight')
plt.show()

# %%
aa=cube1[:,:,ch_plot]
aa=aa[~np.isnan(aa)]
print (np.shape(aa))
print (np.mean(aa))

# %%
rms1 = np.sqrt(np.mean(np.square(aa)))
print (rms1)
print (str(round(rms1*1e3,2))+' mK')

# %%
for ch_i in [ch_plot-1,ch_plot,ch_plot+1,ch_plot+2]:
    plt.figure(figsize=(9,2.5))
    ax=plt.subplot(projection=w2)
    plt.grid(color='grey',lw=.1)
    plt.imshow(cube1[:,:,ch_i].T,cmap=kv.cmap2(),aspect='auto')#, vmin=-0.25,vmax=0.25)
    plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
    plt.colorbar(label='Kelvin')
    plt.xlabel('R. A.')
    plt.ylabel('Dec')
    plt.xlim([0,Npix_x])
    plt.ylim([0,Npix_y])
    plt.title('ch'+str(ch_i))
    ax.invert_xaxis()
    #plt.plot('test B')
    plt.show()

# %%
#ABBA 
bb0=(cube0[:,:,ch_plot]+cube0[:,:,ch_plot+1])/2.-(cube0[:,:,ch_plot-1]+cube0[:,:,ch_plot+2])/2.
bb1=(cube1[:,:,ch_plot]+cube1[:,:,ch_plot+1])/2.-(cube1[:,:,ch_plot-1]+cube1[:,:,ch_plot+2])/2.

# %%
plt.figure(figsize=(18,5))
ax=plt.subplot(projection=w2)
plt.grid(color='grey',lw=.1)
plt.imshow(bb0.T,cmap=kv.cmap2(),aspect='auto')
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar(label='Kelvin')
plt.xlabel('R. A.')
plt.ylabel('Dec')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
#plt.plot('test B')
plt.show()

# %%
plt.figure(figsize=(18,5))
ax=plt.subplot(projection=w2)
plt.grid(color='grey',lw=.1)
plt.imshow(bb1.T,cmap=kv.cmap2(),aspect='auto')
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar(label='Kelvin')
plt.xlabel('R. A.')
plt.ylabel('Dec')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
#plt.plot('test B')
plt.show()

# %%
bb0=bb0[~np.isnan(bb0)]
print (np.shape(bb0))
print (np.mean(bb0))

# %%
rms2 = np.sqrt(np.mean(np.square(bb0)))
print (rms2)
print (str(round(rms2*1e3,2))+' mK')

# %%
plt.figure(figsize=(18,5))
plt.subplot(projection=w2)
plt.imshow(cube2[:,:,ch_plot].T,cmap='jet',aspect='auto')
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar()
plt.xlabel('R. A.')
plt.ylabel('Dec')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
plt.show()

# %%
map_2=cube2.copy() #Ncount
map_22=np.ma.array(map_2,mask=True)
map_22.mask[~np.isnan(map_2)]=False
map_22.mask[map_2==0]=True

plt.figure(figsize=(18,5))
ax=plt.subplot(projection=w)
plt.grid(color='grey',lw=.1)
plt.imshow(map_22[:,:,ch_plot].T,cmap='YlOrRd', aspect='auto')
#plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
#plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
plt.colorbar(label='  ')
plt.xlabel('R. A. (J2000)')
plt.ylabel('Dec (J2000)')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
plt.title(r'$N_{count}$'+' map')
plt.savefig('Ncount_'+str(ch_plot)+'_final.pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(18,5))
plt.subplot(projection=w2)
plt.imshow(cube3[:,:,ch_plot].T,cmap='jet',aspect='auto')
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar()
plt.xlabel('R. A.')
plt.ylabel('Dec')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
plt.show()

# %%
map_3=cube3.copy() #Ncount
map_33=np.ma.array(map_3,mask=True)
map_33.mask[~np.isnan(map_3)]=False
map_33.mask[map_3==0]=True

plt.figure(figsize=(18,5))
ax=plt.subplot(projection=w)
plt.grid(color='grey',lw=.1)
plt.imshow(map_33[:,:,ch_plot].T,cmap=kv.cmap3(), aspect='auto')
#plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
#plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
plt.colorbar(label='  ')
plt.xlabel('R. A. (J2000)')
plt.ylabel('Dec (J2000)')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
plt.title(r'$P_{count}$'+' map')
plt.savefig('Pcount_'+str(ch_plot)+'_final.pdf', bbox_inches='tight')
plt.show()

# %%
#test below

# %%
plt.figure(figsize=(8,4))
plt.plot(total_count_list,'.')
plt.plot(ch_plot,total_count_plot,'r*')
plt.xlim(500,1050)
plt.plot([550,550],[150,1350],'k--')
plt.plot([810,810],[150,1350],'k--')
plt.xlabel('channel')
plt.ylabel('scan count')

# %%
print (kio.cal_freq(550)/1e6,kio.cal_freq(810)/1e6)

# %%
total_count

# %%
freqs=kio.cal_freqs(range(4096))

# %%
total_count_list0=np.loadtxt(output_file+'ALL_scan'+str(total_count)+'_list_p'+str(pix_deg)+'d.dat')
#scan_count_list=np.loadtxt('Nscan366_list_p0.3d_sigma2.5_iter2.dat')
scan_count_list=np.loadtxt('ALL_scan966_list_p0.3d.dat')
plt.figure(figsize=(8,5))
plt.plot([freqs[0]/1e6,freqs[-1]/1e6],[total_count,total_count], 'k--')
plt.plot(freqs/1e6, total_count_list0,'.',color='grey')
plt.plot(freqs/1e6, scan_count_list,'.')
plt.legend(['total number of scans (966)','number of calibrated scans in each channel', 'number of scans after weak RFI flagging'],fontsize=14)
#plt.ylim(0,530)
plt.xlabel('Frequency (MHz)')
plt.ylabel('Count')
plt.savefig('F_count_comp_final.pdf', bbox_inches='tight')
plt.show()

# %%
for i in range(4096):
    plt.plot(kio.cal_freq(i)/1e6, scan_count_list[i]/total_count,'.')
plt.show()

# %%
a_dat=[]
for i in range(4096):
    a_dat.append([kio.cal_freq(i)/1e6, scan_count_list[i]/total_count])
a_dat=np.array(a_dat)

np.savetxt('freq_MHz_vs_good_scan_ratio.dat',a_dat)

# %%
a_list=np.loadtxt('freq_MHz_vs_good_scan_ratio.dat')

# %%
(a_dat==a_list).all()

# %%
plt.plot(a_list[:,0],a_list[:,1],'.')
plt.show()

# %%
#test above

# %% [markdown]
# # the Galactic model

# %%
nside=64 #healpix nside, 64: Mean Spacing (deg) is 0.9161
import pysm
from pysm.nominal import models

# %%
def cal_Gal_pix (pix_ra, pix_dec, freq, nside):
    sky_config = {
        'synchrotron': models("s1", nside),
    }

    sky = pysm.Sky(sky_config)
    
    c = SkyCoord(ra=pix_ra * u.degree, dec=pix_dec * u.degree, frame='icrs')
    theta = 90 - (c.galactic.b / u.degree).value
    phi = (c.galactic.l / u.degree).value
        
    syn = sky.synchrotron(nu=freq/1e9) / 1e6  # K
    I = hp.pixelfunc.get_interp_val(syn[0, :], theta / 180 * np.pi, phi / 180 * np.pi)
        
    return I

# %%
total_count=total_count
model_key=0 #0 for full band count, to achieve a good sky coverage; 
            #1 for Tresi map, to have same coverage as Tresi in certain channel

if model_key==1:
    #Fits='/idia/projects/hi_im/raw_vis/katcali_output/level6_output/p'+str(pix_deg)+'d/p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter)+'/Nscan'+str(total_count)+'_Tresi_cube_p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter)+'.fits'
    Fits='ALL_scan966_Tresi_cube_p0.3d.fits'
    cube = fits.open(Fits)[0].data
    print (np.shape(cube))
    a=np.where(~np.isnan(cube[:,:,ch_plot]))
    print (np.shape(a))
    
if model_key==0:
    #Fits='/idia/projects/hi_im/raw_vis/katcali_output/level6_output/p0.3d/ALL/ALL_scan366_Npix_count_cube_p0.3d.fits'
    Fits='ALL_scan966_Npix_count_cube_p0.3d.fits'
    cube = fits.open(Fits)[0].data
    print (np.shape(cube))
    #cube1=np.sum(cube,axis=2)
    cube1=cube[:,:,ch_plot]
    a=np.where(cube1>0)
    print (np.shape(a))

# %%
pix_list_x=np.array(a[0])
pix_list_y=np.array(a[1])

# %%
pix_radec=pixel_to_skycoord(pix_list_x,pix_list_y,w)
pix_ra,pix_dec=(pix_radec.ra/u.deg).value,(pix_radec.dec/u.deg).value

# %%
gal_pix=np.zeros([Npix_x,Npix_y])
gal_pix[pix_list_x,pix_list_y]=cal_Gal_pix (pix_ra, pix_dec, kio.cal_freq(ch_plot), nside)    

if model_key==1: #1 for Tresi map, to have same coverage as Tresi in certain channel
    gal_pix[np.isnan(cube[:,:,ch_plot])]=np.nan
if model_key==0: #0 for full band count, to achieve a good sky coverage; 
    gal_pix[np.where(cube1==0)]=np.nan

# %%
Tcmb

# %%
plt.figure(figsize=(18,5))
ax=plt.subplot(projection=w)
plt.grid(color='grey',lw=.1)
plt.imshow(gal_pix.T,cmap=kv.cmap1(),aspect='auto',vmin=2.9-Tcmb,vmax=3.55-Tcmb)
#plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
#plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
plt.colorbar(label='Kelvin')
plt.xlabel('R. A. (J2000)')
plt.ylabel('Dec (J2000)')
plt.title('Galactic model at '+str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
plt.savefig('F_Tgal_model_ch'+str(ch_plot)+'.pdf', bbox_inches='tight')
plt.show()

# %%
print ('end @ ' + time.asctime(time.localtime(time.time())) +'#')
