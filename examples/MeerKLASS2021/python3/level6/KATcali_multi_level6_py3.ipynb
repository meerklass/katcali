# %%
#imports
import katdal
import numpy as np
import matplotlib.pylab as plt
import astropy.coordinates as ac
import functools
import healpy as hp
import optparse
import warnings
from matplotlib.backends.backend_pdf import PdfPages
import healpy as hp
from astropy import units as u
from matplotlib.offsetbox import AnchoredText
import time
import pickle
import sys
import katcali
import katcali.visualizer as kv
import katcali.models as km
import katcali.rfi as kr
import katcali.solver as ks
import katcali.io as kio
import katcali.label_dump as kl
import katcali.diode as kd
import katcali.filter as kf
import katcali.beam as kb
from astropy.coordinates import SkyCoord
from astropy import units as u
from scipy.sparse import coo_matrix
import astropy.wcs
from astropy.wcs.utils import skycoord_to_pixel
from astropy.wcs.utils import pixel_to_skycoord
from astropy.io import fits
from astropy.wcs import WCS
from scipy.interpolate import UnivariateSpline
import matplotlib.colors as colors
Tcmb=2.725
k_B = 1.38E-23

# %%
print ('start @ ' + time.asctime(time.localtime(time.time())) +'...')
# Out:
# start @ Wed Aug 10 17:39:09 2022...

# %%
print  (plt.rcParams['font.size'], plt.rcParams[u'axes.linewidth'],plt.rcParams['lines.linewidth'])
plt.rcParams['font.size'], plt.rcParams[u'axes.linewidth'],plt.rcParams['lines.linewidth'] = 14, 1.5, 1.5
#plt.rcParams['font.size'], plt.rcParams[u'axes.linewidth'],plt.rcParams['lines.linewidth'] = 10.0, 0.8, 1.5
print  (plt.rcParams['font.size'], plt.rcParams[u'axes.linewidth'],plt.rcParams['lines.linewidth'])
# Out:
# 10.0 0.8 1.5
# 14.0 1.5 1.5

# %%
pix_deg=0.3 #0.15 #0.3
std_sigma=2.5 #the smaller number will make more data be delated 

ch_plot=800

# %%
p_radec=np.loadtxt('radio_source2021.txt')
ptr_pix=np.loadtxt('radio_source2021_pix_'+str(pix_deg)+'deg.txt')
ptr_ra_pix,ptr_dec_pix=ptr_pix[:,0],ptr_pix[:,1]

input_file='/idia/projects/hi_im/raw_vis/MeerKLASS2021/level5/data/'
output_file='./'

# %%
#fname_list=['1630519596','1631379874','1631387336','1631552188','1631559762','1631659886']

# %%
#'''
fname_list=['1630519596','1631379874','1631387336','1631552188','1631559762','1631659886',
            '1631667564','1631724508','1631732038','1631810671','1631818149','1631982988',
            '1631990463','1632069690','1632077222','1632184922','1632505883','1632760885',
            '1633365980','1633970780','1634252028','1634402485','1634748682','1634835083',
            '1637346562','1637354605','1637691677','1637699408','1638130295','1638294319',
            '1638301944','1638386189','1638639082','1638647186','1638898468','1639157507',
            '1639331184','1639935088','1640540184','1640712986','1640799689']
#'''

# %% [markdown]
# # try to load merged but unfiltered data

# %%
total_count_MAX=1339

niter=1 # no filter applied

# %%
pix_ma_ra=[]
pix_ma_dec=[]

for i_iter in range(niter):
    print ('>>>>>>>>> Iteration '+str(i_iter)+' start...')
    
    ####load previous data in########
    try:
        if i_iter==0:#First
            Fits=output_file+'ALL_scan'+str(total_count_MAX)+'_Tresi_cube_p'+str(pix_deg)+'d.fits'
            Tresi_cube = fits.open(Fits)[0].data
            print (np.shape(Tresi_cube))
            #only need to load once###
            Npix_x= np.shape(Tresi_cube)[0]
            Npix_y= np.shape(Tresi_cube)[1]

            w2=WCS(Fits).dropaxis(-1)
            print (w2)
            
            ####mask point sources######    
            map_ra=np.zeros_like(Tresi_cube[:,:,ch_plot])
            map_dec=np.zeros_like(Tresi_cube[:,:,ch_plot])
            for i in range(np.shape(map_ra)[0]):
                for j in range(np.shape(map_ra)[1]):
                    radec=pixel_to_skycoord(i,j,w2)
                    map_ra[i,j]=radec.ra.deg
                    map_dec[i,j]=radec.dec.deg
            p = SkyCoord(map_ra*u.deg,  map_dec*u.deg, frame='icrs')

            for s in range(len(p_radec)):
                p_ra,p_dec=p_radec[s]
                c = SkyCoord(p_ra*u.deg,  p_dec*u.deg, frame='icrs')
                p_ang=(c.separation(p)/u.deg)
                dp_l=np.where(p_ang<1.)
                dp_l=np.array(dp_l)
                pix_ma_ra+=list(dp_l[0])
                pix_ma_dec+=list(dp_l[1])
                
        if i_iter>0: #Since second
            Fits=output_file+'Nscan'+str(total_count)+'_Tresi_cube_p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter-1)+'.fits'
                            
        Tresi_cube = fits.open(Fits)[0].data
        print (np.shape(Tresi_cube))

        plt.figure(figsize=(18,5))
        ax=plt.subplot(projection=w2)
        plt.imshow(Tresi_cube[:,:,ch_plot].T,cmap='jet',aspect='auto')
        plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
        #plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
        plt.colorbar(label='Kelvin')
        plt.xlabel('R. A. (J2000)')
        plt.ylabel('Dec (J2000)')
        plt.xlim([0,Npix_x])
        plt.ylim([0,Npix_y])
        ax.invert_xaxis()
        plt.title('reloaded data')
        plt.show()

        print (np.nanmin(Tresi_cube[:,:,ch_plot]),np.nanmax(Tresi_cube[:,:,ch_plot])) 

        Tresi_cube1=Tresi_cube.copy()
        Tresi_cube1[pix_ma_ra,pix_ma_dec,:]=np.nan
        print (np.nanmean(Tresi_cube1[:,:,ch_plot]),np.nanstd(Tresi_cube1[:,:,ch_plot])) 

        plt.figure(figsize=(18,5))
        ax=plt.subplot(projection=w2)
        plt.imshow(Tresi_cube1[:,:,ch_plot].T,cmap='jet',aspect='auto')
        plt.colorbar(label='Kelvin')
        plt.xlabel('R. A. (J2000)')
        plt.ylabel('Dec (J2000)')
        plt.xlim([0,Npix_x])
        plt.ylim([0,Npix_y])
        ax.invert_xaxis()
        plt.show()
 
        ######calculate std without point sources################
        Tresi_ra_std=np.nanstd(Tresi_cube1,axis=0)
        Tresi_ra_mean=np.nanmean(Tresi_cube1,axis=0)

        Tresi_ra_u=Tresi_ra_mean+std_sigma*Tresi_ra_std
        Tresi_ra_l=Tresi_ra_mean-std_sigma*Tresi_ra_std

        x_ticks=pixel_to_skycoord(0,range(np.shape(Tresi_cube)[1]),w2).dec/u.deg #pix_ra=0, get dec
        x_ticks=np.array(x_ticks)
        assert(np.shape(Tresi_cube)[1]==len(x_ticks))
        
        plt.figure(figsize=(8,4))
        plt.plot(Tresi_ra_mean[:,ch_plot],'r')
        plt.plot(Tresi_ra_u[:,ch_plot],'b--')
        plt.plot(Tresi_ra_l[:,ch_plot],'g--')
        
        tick_i=[0, 10, 20, 30, 40]
        plt.xticks(tick_i, np.round(x_ticks[tick_i],1))
        plt.xlabel('${Dec_{pix}}$ (Deg)')
        plt.ylabel('T (K)')
        plt.legend(['mean','mean+3sigma','mean-3sigma'],ncol=3)
        plt.title('$T_{res}$ along dec of ch'+str(ch_plot)+', all scans')
        plt.grid(color='grey', lw=.1)
        plt.savefig('Tresi_filter_iter'+str(i_iter)+'.pdf', bbox_inches='tight')
        plt.show()

    except IOError:
        if i_iter==0:#First
            print ('*** No previous data cube with label *ALL_scan*,',)
            print ('calculate ALL_scan now...',)
            print ('will stop after ALL_scan calculated ')
            Fits=input_file+fname_list[0]+'_m000_Tresi_xy_p'+str(pix_deg)+'d.fits'
            Tresi_cube = fits.open(Fits)[0].data
            Tresi_ra_u=np.ones_like(Tresi_cube[0,:,:])*1e3
            Tresi_ra_l=np.ones_like(Tresi_cube[0,:,:])*-1e3
        else:
            print ('*** No data cube for iter '+str(i_iter-1)+', EXIT!')
            break
         
    #######filter data##########################
    n_ch_del=0
    n_ch_keep=0
    total_count=0 #cube count
    total_count_plot=0 #channel count
    total_count_list=np.zeros(4096)
    
    for a_i in range(64):
        ant='m'+ "%03d" % a_i
        #print ant

        for f_i in range(len(fname_list)):
            fname=fname_list[f_i]
            #print fname

            try:
                #print 'set ch_mask'
                a=np.ma.array(np.zeros(4096),mask=True)
                ch_mask=a.mask
                
                Fits1=input_file+fname+'_'+ant+'_Tsky_xy_p'+str(pix_deg)+'d.fits'
                Tsky_cube = fits.open(Fits1)[0].data
                Fits2=input_file+fname+'_'+ant+'_Tresi_xy_p'+str(pix_deg)+'d.fits'
                Tresi_cube = fits.open(Fits2)[0].data
                Fits3=input_file+fname+'_'+ant+'_Npix_xy_count_p'+str(pix_deg)+'d.fits'
                Pcount_cube = fits.open(Fits3)[0].data
                
                assert(np.shape(Tsky_cube)==np.shape(Tresi_cube))
                assert((np.isnan(Tresi_cube)).all()==False)
                if (np.isnan(Tsky_cube)).all()==False: 
                    total_count+=1 #cube count
                    for ch_ii in range(4096):
                        if (np.isnan(Tsky_cube[:,:,ch_ii])).all()==False:
                            ch_mask[ch_ii]=False
                else:
                    print ('***empty cube')

                if (total_count==1):
                    Npix_x= np.shape(Tsky_cube)[0]
                    Npix_y= np.shape(Tsky_cube)[1]

                    w=WCS(Fits1).dropaxis(-1)
                    w2=WCS(Fits2).dropaxis(-1)
                    assert(w.wcs==w2.wcs)
                    print ('-------------------------------------------')
                    #print w
                    print ('-------------------------------------------')
                    fits_temp=np.zeros([Npix_x,Npix_y,4096])

                    Sum_Tsky_xy=fits_temp.copy()
                    Sum_Tresi_xy=fits_temp.copy()
                    Npix_xy_count1=fits_temp.copy()
                    Npix_xy_count2=fits_temp.copy()
                    P_xy_count1=fits_temp.copy()
                    P_xy_count2=fits_temp.copy()
                    assert((Sum_Tsky_xy==0).all()==True)
                    assert((Sum_Tresi_xy==0).all()==True)
                    assert((Npix_xy_count1==0).all()==True)
                    assert((Npix_xy_count2==0).all()==True)
                    print ('***stastic cubes initialized')

                print ('# cube '+str(total_count)+': '+fname+' '+ant)
                assert(np.shape(Tsky_cube)==np.shape(Sum_Tsky_xy))
                
                if (Tresi_ra_u==1000).all()==True:
                    print ('### no ch_drop!')
                else:
                    
                    #mean along dec to check rfi lines
                    Tresi_cube1=Tresi_cube.copy()
                    Tresi_cube1[pix_ma_ra,pix_ma_dec,:]=np.nan
                    Tresi_ra_median=np.nanmedian(Tresi_cube1,axis=0) #always check Tresi since Tsky have the Galactic slope 

                    ch_drop=[]  
                    for ch_i in range(4096):
                        if ((Tresi_ra_median[:,ch_i]<Tresi_ra_l[:,ch_i]).any()==True 
                            or (Tresi_ra_median[:,ch_i]>Tresi_ra_u[:,ch_i]).any()==True):
                            ch_drop.append(ch_i)

                    if len(ch_drop)>0:
                        Tsky_cube[:,:,ch_drop]=np.nan            
                        Tresi_cube[:,:,ch_drop]=np.nan
                        print ('***'+str(len(ch_drop))+' channels deleted')
                        n_ch_del+=len(ch_drop)
                        ch_mask[ch_drop]=True
                        
                    ch_l=len(np.where(ch_mask==False)[0])
                    n_ch_keep+=ch_l
                    print ('***'+str(ch_l)+' channels left')
                    d1={}
                    d1['ch_mask']=ch_mask
                    fs=open(output_file+str(fname)+'_'+str(ant)+'_level6_p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter)+'_mask','wb')
                    pickle.dump(d1,fs,protocol=2)
                    fs.close()
                       
                Sum_Tsky_xy[~np.isnan(Tsky_cube)]+=Tsky_cube[~np.isnan(Tsky_cube)]
                Sum_Tresi_xy[~np.isnan(Tresi_cube)]+=Tresi_cube[~np.isnan(Tresi_cube)]
                Npix_xy_count1[~np.isnan(Tsky_cube)]+=1
                Npix_xy_count2[~np.isnan(Tresi_cube)]+=1
                P_xy_count1[~np.isnan(Tsky_cube)]+=Pcount_cube[~np.isnan(Tsky_cube)]
                P_xy_count2[~np.isnan(Tresi_cube)]+=Pcount_cube[~np.isnan(Tresi_cube)]
                if (np.isnan(Tsky_cube[:,:,ch_plot])).all()==False: #channel count
                    total_count_plot+=1

                for ch_i in list(range(550,1051)) + list(range(2150,3101)):##set channels
                    if (np.isnan(Tsky_cube[:,:,ch_i])).all()==False: #channel count
                        total_count_list[ch_i]+=1

            except IOError:
                print ('no data cube for '+ fname+', '+ant)
    
    ######check and save data#####
    print (n_ch_del)
    print ('total channel number left: '+str(n_ch_keep))

    if (Tresi_ra_u==1000).all()==True:
        np.savetxt(output_file+'ALL_scan'+str(total_count)+'_list_p'+str(pix_deg)+'d.dat',total_count_list)
        print ('list for ALL_scan saved')
    else:
        np.savetxt(output_file+'Nscan'+str(total_count)+'_list_p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter)+'.dat',total_count_list)
        print ('list for Iter'+str(i_iter)+' saved')
        
    assert(total_count_list[ch_plot]==total_count_plot)

    m=np.where(total_count_list==total_count_list.max())
    print (m,total_count_list[m])

    plt.figure(figsize=(8,4))
    #plt.plot(total_count_list,'.')
    ###plt.plot(ch_plot,total_count_plot,'r*')
    ###plt.plot(m,total_count_list[m],'g*')
    plt.xlabel('channel')
    plt.ylabel('scan count')
    try:
        total_count_list0=np.loadtxt(output_file+'ALL_scan'+str(total_count)+'_list_p'+str(pix_deg)+'d.dat')
        print (total_count_list0)
        plt.plot(total_count_list0,'.',color='grey')
        
    except IOError:
        print ('*** No previous data cube')
    #plt.legend(['scan count of channel after filter','total scan count of channel'])
    plt.plot(total_count_list,'.')
    plt.legend(['total scan count of channel','scan count of channel after filter'])
    
    if i_iter==niter-1:
        plt.savefig('count_comp_iter'+str(i_iter)+'.pdf', bbox_inches='tight')
    plt.show()

    Tsky_xy=Sum_Tsky_xy/Npix_xy_count1
    Tresi_xy=Sum_Tresi_xy/Npix_xy_count2

    plt.figure(figsize=(18,5))
    ax=plt.subplot(projection=w)
    plt.grid(color='grey',lw=.1)
    plt.imshow(Npix_xy_count1[:,:,ch_plot].T,cmap=kv.cmap3(),aspect='auto')
    plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
    #plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
    plt.colorbar(label='Kelvin')
    plt.xlabel('R. A. (J2000)')
    plt.ylabel('Dec (J2000)')
    plt.xlim([0,Npix_x])
    plt.ylim([0,Npix_y])
    ax.invert_xaxis()
    plt.savefig('Ncount'+str(ch_plot)+'_iter'+str(i_iter)+'.png', bbox_inches='tight')
    plt.show()
    
    
    plt.figure(figsize=(18,5))
    ax=plt.subplot(projection=w)
    plt.grid(color='grey',lw=.1)
    plt.imshow(Tsky_xy[:,:,ch_plot].T,cmap=kv.cmap1(),aspect='auto',vmin=2.9,vmax=3.55)
    plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
    #plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
    plt.colorbar(label='Kelvin')
    plt.xlabel('R. A. (J2000)')
    plt.ylabel('Dec (J2000)')
    plt.title(r'$\bar T_{sky}$'+' map for '+str(total_count_plot)+' scans, '+str(pix_deg)+' deg/pix, '
                                  +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
    plt.xlim([0,Npix_x])
    plt.ylim([0,Npix_y])
    ax.invert_xaxis()
    plt.savefig('F_Tsky_all_ch'+str(ch_plot)+'_iter'+str(i_iter)+'.png', bbox_inches='tight')
    plt.show()

    plt.figure(figsize=(18,5))
    ax=plt.subplot(projection=w)
    plt.grid(color='grey',lw=.1)
    plt.imshow(Tresi_xy[:,:,ch_plot].T,cmap=kv.cmap2(),aspect='auto',vmin=-0.25, vmax=0.25)
    plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
    #plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
    #plt.text(ptr_ra_pix[19]-0.8,ptr_dec_pix[19]+0.8,'4C+00.35')    
    
    plt.colorbar(label='Kelvin')
    plt.xlabel('R. A. (J2000)')
    plt.ylabel('Dec (J2000)')
    plt.title(r'$\bar T_{res}$'+' map for '+str(total_count_plot)+' scans, '+str(pix_deg)+' deg/pix, '
                                  +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
    plt.xlim([0,Npix_x])
    plt.ylim([0,Npix_y])
    ax.invert_xaxis()
    plt.savefig('F_Tresi_all_ch'+str(ch_plot)+'_iter'+str(i_iter)+'.png', bbox_inches='tight')
    plt.show()

    assert((Npix_xy_count1==Npix_xy_count2).all())
    assert((P_xy_count1==P_xy_count2).all())
    print (total_count)

    #save data
    list_data=[Sum_Tsky_xy,Sum_Tresi_xy,Npix_xy_count1,Tsky_xy,Tresi_xy, P_xy_count1]
    list_str=['Sum_Tsky_cube','Sum_Tresi_cube','Npix_count_cube','Tsky_cube','Tresi_cube','P_xy_count']
    for i in range(len(list_data)):
        hdu=w.to_fits()
        hdu[0].data=list_data[i]
        #if (std_list0==1000).all()==True:
        if (Tresi_ra_u==1000).all()==True:
            hdu.writeto(output_file+'ALL_scan'+str(total_count)+'_'+list_str[i]+'_p'+str(pix_deg)+'d.fits', overwrite=True)
            print ('ALL_scan finished, will EXIT soon ...')
        else:    
            hdu.writeto(output_file+'Nscan'+str(total_count)+'_'+list_str[i]+'_p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter)+'.fits', overwrite=True)
# Out:
# >>>>>>>>> Iteration 0 start...
# *** No previous data cube with label *ALL_scan*,
# calculate ALL_scan now...
# will stop after ALL_scan calculated
# -------------------------------------------
# -------------------------------------------
# ***stastic cubes initialized
# # cube 1: 1630519596 m000
# ### no ch_drop!
# no data cube for 1631379874, m000
# no data cube for 1631387336, m000
# no data cube for 1631552188, m000
# # cube 2: 1631559762 m000
# ### no ch_drop!
# # cube 3: 1631659886 m000
# ### no ch_drop!
# # cube 4: 1631667564 m000
# ### no ch_drop!
# no data cube for 1631724508, m000
# no data cube for 1631732038, m000
# no data cube for 1631810671, m000
# no data cube for 1631818149, m000
# no data cube for 1631982988, m000
# no data cube for 1631990463, m000
# no data cube for 1632069690, m000
# # cube 5: 1632077222 m000
# ### no ch_drop!
# no data cube for 1632184922, m000
# no data cube for 1632505883, m000
# no data cube for 1632760885, m000
# # cube 6: 1633365980 m000
# ### no ch_drop!
# no data cube for 1633970780, m000
# # cube 7: 1634252028 m000
# ### no ch_drop!
# no data cube for 1634402485, m000
# no data cube for 1634748682, m000
# no data cube for 1634835083, m000
# no data cube for 1637346562, m000
# # cube 8: 1637354605 m000
# ### no ch_drop!
# no data cube for 1637691677, m000
# # cube 9: 1637699408 m000
# ### no ch_drop!
# # cube 10: 1638130295 m000
# ### no ch_drop!
# # cube 11: 1638294319 m000
# ### no ch_drop!
# # cube 12: 1638301944 m000
# ### no ch_drop!
# no data cube for 1638386189, m000
# no data cube for 1638639082, m000
# no data cube for 1638647186, m000
# # cube 13: 1638898468 m000
# ### no ch_drop!
# no data cube for 1639157507, m000
# # cube 14: 1639331184 m000
# ### no ch_drop!
# # cube 15: 1639935088 m000
# ### no ch_drop!
# no data cube for 1640540184, m000
# # cube 16: 1640712986 m000
# ### no ch_drop!
# no data cube for 1640799689, m000
# no data cube for 1630519596, m001
# # cube 17: 1631379874 m001
# ### no ch_drop!
# no data cube for 1631387336, m001
# # cube 18: 1631552188 m001
# ### no ch_drop!
# # cube 19: 1631559762 m001
# ### no ch_drop!
# no data cube for 1631659886, m001
# # cube 20: 1631667564 m001
# ### no ch_drop!
# # cube 21: 1631724508 m001
# ### no ch_drop!
# # cube 22: 1631732038 m001
# ### no ch_drop!
# # cube 23: 1631810671 m001
# ### no ch_drop!
# no data cube for 1631818149, m001
# # cube 24: 1631982988 m001
# ### no ch_drop!
# # cube 25: 1631990463 m001
# ### no ch_drop!
# # cube 26: 1632069690 m001
# ### no ch_drop!
# # cube 27: 1632077222 m001
# ### no ch_drop!
# # cube 28: 1632184922 m001
# ### no ch_drop!
# no data cube for 1632505883, m001
# # cube 29: 1632760885 m001
# ### no ch_drop!
# # cube 30: 1633365980 m001
# ### no ch_drop!
# no data cube for 1633970780, m001
# # cube 31: 1634252028 m001
# ### no ch_drop!
# # cube 32: 1634402485 m001
# ### no ch_drop!
# no data cube for 1634748682, m001
# no data cube for 1634835083, m001
# no data cube for 1637346562, m001
# # cube 33: 1637354605 m001
# ### no ch_drop!
# no data cube for 1637691677, m001
# # cube 34: 1637699408 m001
# ### no ch_drop!
# # cube 35: 1638130295 m001
# ### no ch_drop!
# # cube 36: 1638294319 m001
# ### no ch_drop!
# # cube 37: 1638301944 m001
# ### no ch_drop!
# # cube 38: 1638386189 m001
# ### no ch_drop!
# # cube 39: 1638639082 m001
# ### no ch_drop!
# no data cube for 1638647186, m001
# # cube 40: 1638898468 m001
# ### no ch_drop!
# # cube 41: 1639157507 m001
# ### no ch_drop!
# no data cube for 1639331184, m001
# # cube 42: 1639935088 m001
# ### no ch_drop!
# no data cube for 1640540184, m001
# # cube 43: 1640712986 m001
# ### no ch_drop!
# no data cube for 1640799689, m001
# # cube 44: 1630519596 m002
# ### no ch_drop!
# # cube 45: 1631379874 m002
# ### no ch_drop!
# # cube 46: 1631387336 m002
# ### no ch_drop!
# # cube 47: 1631552188 m002
# ### no ch_drop!
# # cube 48: 1631559762 m002
# ### no ch_drop!
# no data cube for 1631659886, m002
# # cube 49: 1631667564 m002
# ### no ch_drop!
# # cube 50: 1631724508 m002
# ### no ch_drop!
# # cube 51: 1631732038 m002
# ### no ch_drop!
# # cube 52: 1631810671 m002
# ### no ch_drop!
# no data cube for 1631818149, m002
# no data cube for 1631982988, m002
# # cube 53: 1631990463 m002
# ### no ch_drop!
# # cube 54: 1632069690 m002
# ### no ch_drop!
# # cube 55: 1632077222 m002
# ### no ch_drop!
# # cube 56: 1632184922 m002
# ### no ch_drop!
# no data cube for 1632505883, m002
# # cube 57: 1632760885 m002
# ### no ch_drop!
# # cube 58: 1633365980 m002
# ### no ch_drop!
# no data cube for 1633970780, m002
# # cube 59: 1634252028 m002
# ### no ch_drop!
# # cube 60: 1634402485 m002
# ### no ch_drop!
# no data cube for 1634748682, m002
# no data cube for 1634835083, m002
# no data cube for 1637346562, m002
# # cube 61: 1637354605 m002
# ### no ch_drop!
# no data cube for 1637691677, m002
# # cube 62: 1637699408 m002
# ### no ch_drop!
# # cube 63: 1638130295 m002
# ### no ch_drop!
# # cube 64: 1638294319 m002
# ### no ch_drop!
# # cube 65: 1638301944 m002
# ### no ch_drop!
# no data cube for 1638386189, m002
# # cube 66: 1638639082 m002
# ### no ch_drop!
# # cube 67: 1638647186 m002
# ### no ch_drop!
# # cube 68: 1638898468 m002
# ### no ch_drop!
# # cube 69: 1639157507 m002
# ### no ch_drop!
# no data cube for 1639331184, m002
# # cube 70: 1639935088 m002
# ### no ch_drop!
# no data cube for 1640540184, m002
# # cube 71: 1640712986 m002
# ### no ch_drop!
# # cube 72: 1640799689 m002
# ### no ch_drop!
# # cube 73: 1630519596 m003
# ### no ch_drop!
# # cube 74: 1631379874 m003
# ### no ch_drop!
# no data cube for 1631387336, m003
# # cube 75: 1631552188 m003
# ### no ch_drop!
# # cube 76: 1631559762 m003
# ### no ch_drop!
# # cube 77: 1631659886 m003
# ### no ch_drop!
# # cube 78: 1631667564 m003
# ### no ch_drop!
# no data cube for 1631724508, m003
# # cube 79: 1631732038 m003
# ### no ch_drop!
# # cube 80: 1631810671 m003
# ### no ch_drop!
# # cube 81: 1631818149 m003
# ### no ch_drop!
# no data cube for 1631982988, m003
# no data cube for 1631990463, m003
# no data cube for 1632069690, m003
# # cube 82: 1632077222 m003
# ### no ch_drop!
# # cube 83: 1632184922 m003
# ### no ch_drop!
# no data cube for 1632505883, m003
# no data cube for 1632760885, m003
# # cube 84: 1633365980 m003
# ### no ch_drop!
# no data cube for 1633970780, m003
# # cube 85: 1634252028 m003
# ### no ch_drop!
# no data cube for 1634402485, m003
# no data cube for 1634748682, m003
# no data cube for 1634835083, m003
# no data cube for 1637346562, m003
# # cube 86: 1637354605 m003
# ### no ch_drop!
# no data cube for 1637691677, m003
# # cube 87: 1637699408 m003
# ### no ch_drop!
# # cube 88: 1638130295 m003
# ### no ch_drop!
# # cube 89: 1638294319 m003
# ### no ch_drop!
# # cube 90: 1638301944 m003
# ### no ch_drop!
# no data cube for 1638386189, m003
# no data cube for 1638639082, m003
# # cube 91: 1638647186 m003
# ### no ch_drop!
# # cube 92: 1638898468 m003
# ### no ch_drop!
# no data cube for 1639157507, m003
# no data cube for 1639331184, m003
# # cube 93: 1639935088 m003
# ### no ch_drop!
# no data cube for 1640540184, m003
# # cube 94: 1640712986 m003
# ### no ch_drop!
# no data cube for 1640799689, m003
# # cube 95: 1630519596 m004
# ### no ch_drop!
# # cube 96: 1631379874 m004
# ### no ch_drop!
# no data cube for 1631387336, m004
# # cube 97: 1631552188 m004
# ### no ch_drop!
# # cube 98: 1631559762 m004
# ### no ch_drop!
# # cube 99: 1631659886 m004
# ### no ch_drop!
# no data cube for 1631667564, m004
# # cube 100: 1631724508 m004
# ### no ch_drop!
# # cube 101: 1631732038 m004
# ### no ch_drop!
# # cube 102: 1631810671 m004
# ### no ch_drop!
# no data cube for 1631818149, m004
# no data cube for 1631982988, m004
# no data cube for 1631990463, m004
# # cube 103: 1632069690 m004
# ### no ch_drop!
# # cube 104: 1632077222 m004
# ### no ch_drop!
# # cube 105: 1632184922 m004
# ### no ch_drop!
# no data cube for 1632505883, m004
# # cube 106: 1632760885 m004
# ### no ch_drop!
# # cube 107: 1633365980 m004
# ### no ch_drop!
# no data cube for 1633970780, m004
# # cube 108: 1634252028 m004
# ### no ch_drop!
# # cube 109: 1634402485 m004
# ### no ch_drop!
# no data cube for 1634748682, m004
# no data cube for 1634835083, m004
# no data cube for 1637346562, m004
# no data cube for 1637354605, m004
# no data cube for 1637691677, m004
# # cube 110: 1637699408 m004
# ### no ch_drop!
# # cube 111: 1638130295 m004
# ### no ch_drop!
# # cube 112: 1638294319 m004
# ### no ch_drop!
# # cube 113: 1638301944 m004
# ### no ch_drop!
# no data cube for 1638386189, m004
# # cube 114: 1638639082 m004
# ### no ch_drop!
# # cube 115: 1638647186 m004
# ### no ch_drop!
# # cube 116: 1638898468 m004
# ### no ch_drop!
# # cube 117: 1639157507 m004
# ### no ch_drop!
# no data cube for 1639331184, m004
# # cube 118: 1639935088 m004
# ### no ch_drop!
# no data cube for 1640540184, m004
# # cube 119: 1640712986 m004
# ### no ch_drop!
# # cube 120: 1640799689 m004
# ### no ch_drop!
# # cube 121: 1630519596 m005
# ### no ch_drop!
# # cube 122: 1631379874 m005
# ### no ch_drop!
# # cube 123: 1631387336 m005
# ### no ch_drop!
# # cube 124: 1631552188 m005
# ### no ch_drop!
# # cube 125: 1631559762 m005
# ### no ch_drop!
# # cube 126: 1631659886 m005
# ### no ch_drop!
# no data cube for 1631667564, m005
# # cube 127: 1631724508 m005
# ### no ch_drop!
# # cube 128: 1631732038 m005
# ### no ch_drop!
# # cube 129: 1631810671 m005
# ### no ch_drop!
# no data cube for 1631818149, m005
# # cube 130: 1631982988 m005
# ### no ch_drop!
# # cube 131: 1631990463 m005
# ### no ch_drop!
# # cube 132: 1632069690 m005
# ### no ch_drop!
# # cube 133: 1632077222 m005
# ### no ch_drop!
# # cube 134: 1632184922 m005
# ### no ch_drop!
# no data cube for 1632505883, m005
# # cube 135: 1632760885 m005
# ### no ch_drop!
# # cube 136: 1633365980 m005
# ### no ch_drop!
# no data cube for 1633970780, m005
# # cube 137: 1634252028 m005
# ### no ch_drop!
# # cube 138: 1634402485 m005
# ### no ch_drop!
# no data cube for 1634748682, m005
# no data cube for 1634835083, m005
# no data cube for 1637346562, m005
# no data cube for 1637354605, m005
# no data cube for 1637691677, m005
# # cube 139: 1637699408 m005
# ### no ch_drop!
# # cube 140: 1638130295 m005
# ### no ch_drop!
# # cube 141: 1638294319 m005
# ### no ch_drop!
# # cube 142: 1638301944 m005
# ### no ch_drop!
# no data cube for 1638386189, m005
# # cube 143: 1638639082 m005
# ### no ch_drop!
# # cube 144: 1638647186 m005
# ### no ch_drop!
# # cube 145: 1638898468 m005
# ### no ch_drop!
# # cube 146: 1639157507 m005
# ### no ch_drop!
# no data cube for 1639331184, m005
# no data cube for 1639935088, m005
# no data cube for 1640540184, m005
# no data cube for 1640712986, m005
# no data cube for 1640799689, m005
# # cube 147: 1630519596 m006
# ### no ch_drop!
# # cube 148: 1631379874 m006
# ### no ch_drop!
# no data cube for 1631387336, m006
# # cube 149: 1631552188 m006
# ### no ch_drop!
# # cube 150: 1631559762 m006
# ### no ch_drop!
# # cube 151: 1631659886 m006
# ### no ch_drop!
# # cube 152: 1631667564 m006
# ### no ch_drop!
# no data cube for 1631724508, m006
# # cube 153: 1631732038 m006
# ### no ch_drop!
# # cube 154: 1631810671 m006
# ### no ch_drop!
# no data cube for 1631818149, m006
# no data cube for 1631982988, m006
# no data cube for 1631990463, m006
# no data cube for 1632069690, m006
# # cube 155: 1632077222 m006
# ### no ch_drop!
# # cube 156: 1632184922 m006
# ### no ch_drop!
# no data cube for 1632505883, m006
# no data cube for 1632760885, m006
# # cube 157: 1633365980 m006
# ### no ch_drop!
# no data cube for 1633970780, m006
# # cube 158: 1634252028 m006
# ### no ch_drop!
# no data cube for 1634402485, m006
# no data cube for 1634748682, m006
# no data cube for 1634835083, m006
# no data cube for 1637346562, m006
# no data cube for 1637354605, m006
# no data cube for 1637691677, m006
# # cube 159: 1637699408 m006
# ### no ch_drop!
# # cube 160: 1638130295 m006
# ### no ch_drop!
# # cube 161: 1638294319 m006
# ### no ch_drop!
# # cube 162: 1638301944 m006
# ### no ch_drop!
# no data cube for 1638386189, m006
# no data cube for 1638639082, m006
# no data cube for 1638647186, m006
# no data cube for 1638898468, m006
# no data cube for 1639157507, m006
# # cube 163: 1639331184 m006
# ### no ch_drop!
# # cube 164: 1639935088 m006
# ### no ch_drop!
# no data cube for 1640540184, m006
# # cube 165: 1640712986 m006
# ### no ch_drop!
# no data cube for 1640799689, m006
# no data cube for 1630519596, m007
# # cube 166: 1631379874 m007
# ### no ch_drop!
# no data cube for 1631387336, m007
# # cube 167: 1631552188 m007
# ### no ch_drop!
# # cube 168: 1631559762 m007
# ### no ch_drop!
# # cube 169: 1631659886 m007
# ### no ch_drop!
# no data cube for 1631667564, m007
# # cube 170: 1631724508 m007
# ### no ch_drop!
# # cube 171: 1631732038 m007
# ### no ch_drop!
# # cube 172: 1631810671 m007
# ### no ch_drop!
# # cube 173: 1631818149 m007
# ### no ch_drop!
# no data cube for 1631982988, m007
# no data cube for 1631990463, m007
# # cube 174: 1632069690 m007
# ### no ch_drop!
# # cube 175: 1632077222 m007
# ### no ch_drop!
# # cube 176: 1632184922 m007
# ### no ch_drop!
# no data cube for 1632505883, m007
# # cube 177: 1632760885 m007
# ### no ch_drop!
# # cube 178: 1633365980 m007
# ### no ch_drop!
# no data cube for 1633970780, m007
# # cube 179: 1634252028 m007
# ### no ch_drop!
# # cube 180: 1634402485 m007
# ### no ch_drop!
# no data cube for 1634748682, m007
# no data cube for 1634835083, m007
# no data cube for 1637346562, m007
# # cube 181: 1637354605 m007
# ### no ch_drop!
# no data cube for 1637691677, m007
# # cube 182: 1637699408 m007
# ### no ch_drop!
# # cube 183: 1638130295 m007
# ### no ch_drop!
# # cube 184: 1638294319 m007
# ### no ch_drop!
# # cube 185: 1638301944 m007
# ### no ch_drop!
# # cube 186: 1638386189 m007
# ### no ch_drop!
# # cube 187: 1638639082 m007
# ### no ch_drop!
# # cube 188: 1638647186 m007
# ### no ch_drop!
# # cube 189: 1638898468 m007
# ### no ch_drop!
# no data cube for 1639157507, m007
# no data cube for 1639331184, m007
# # cube 190: 1639935088 m007
# ### no ch_drop!
# no data cube for 1640540184, m007
# # cube 191: 1640712986 m007
# ### no ch_drop!
# # cube 192: 1640799689 m007
# ### no ch_drop!
# # cube 193: 1630519596 m008
# ### no ch_drop!
# no data cube for 1631379874, m008
# # cube 194: 1631387336 m008
# ### no ch_drop!
# no data cube for 1631552188, m008
# no data cube for 1631559762, m008
# no data cube for 1631659886, m008
# no data cube for 1631667564, m008
# no data cube for 1631724508, m008
# # cube 195: 1631732038 m008
# ### no ch_drop!
# # cube 196: 1631810671 m008
# ### no ch_drop!
# no data cube for 1631818149, m008
# no data cube for 1631982988, m008
# # cube 197: 1631990463 m008
# ### no ch_drop!
# # cube 198: 1632069690 m008
# ### no ch_drop!
# # cube 199: 1632077222 m008
# ### no ch_drop!
# no data cube for 1632184922, m008
# no data cube for 1632505883, m008
# no data cube for 1632760885, m008
# # cube 200: 1633365980 m008
# ### no ch_drop!
# no data cube for 1633970780, m008
# # cube 201: 1634252028 m008
# ### no ch_drop!
# # cube 202: 1634402485 m008
# ### no ch_drop!
# no data cube for 1634748682, m008
# no data cube for 1634835083, m008
# no data cube for 1637346562, m008
# no data cube for 1637354605, m008
# no data cube for 1637691677, m008
# no data cube for 1637699408, m008
# # cube 203: 1638130295 m008
# ### no ch_drop!
# # cube 204: 1638294319 m008
# ### no ch_drop!
# # cube 205: 1638301944 m008
# ### no ch_drop!
# no data cube for 1638386189, m008
# no data cube for 1638639082, m008
# no data cube for 1638647186, m008
# # cube 206: 1638898468 m008
# ### no ch_drop!
# no data cube for 1639157507, m008
# no data cube for 1639331184, m008
# # cube 207: 1639935088 m008
# ### no ch_drop!
# no data cube for 1640540184, m008
# # cube 208: 1640712986 m008
# ### no ch_drop!
# no data cube for 1640799689, m008
# no data cube for 1630519596, m009
# # cube 209: 1631379874 m009
# ### no ch_drop!
# # cube 210: 1631387336 m009
# ### no ch_drop!
# # cube 211: 1631552188 m009
# ### no ch_drop!
# # cube 212: 1631559762 m009
# ### no ch_drop!
# # cube 213: 1631659886 m009
# ### no ch_drop!
# # cube 214: 1631667564 m009
# ### no ch_drop!
# # cube 215: 1631724508 m009
# ### no ch_drop!
# # cube 216: 1631732038 m009
# ### no ch_drop!
# # cube 217: 1631810671 m009
# ### no ch_drop!
# # cube 218: 1631818149 m009
# ### no ch_drop!
# no data cube for 1631982988, m009
# no data cube for 1631990463, m009
# # cube 219: 1632069690 m009
# ### no ch_drop!
# # cube 220: 1632077222 m009
# ### no ch_drop!
# # cube 221: 1632184922 m009
# ### no ch_drop!
# no data cube for 1632505883, m009
# # cube 222: 1632760885 m009
# ### no ch_drop!
# # cube 223: 1633365980 m009
# ### no ch_drop!
# no data cube for 1633970780, m009
# # cube 224: 1634252028 m009
# ### no ch_drop!
# # cube 225: 1634402485 m009
# ### no ch_drop!
# no data cube for 1634748682, m009
# # cube 226: 1634835083 m009
# ### no ch_drop!
# no data cube for 1637346562, m009
# no data cube for 1637354605, m009
# no data cube for 1637691677, m009
# # cube 227: 1637699408 m009
# ### no ch_drop!
# # cube 228: 1638130295 m009
# ### no ch_drop!
# # cube 229: 1638294319 m009
# ### no ch_drop!
# # cube 230: 1638301944 m009
# ### no ch_drop!
# no data cube for 1638386189, m009
# no data cube for 1638639082, m009
# # cube 231: 1638647186 m009
# ### no ch_drop!
# # cube 232: 1638898468 m009
# ### no ch_drop!
# # cube 233: 1639157507 m009
# ### no ch_drop!
# no data cube for 1639331184, m009
# # cube 234: 1639935088 m009
# ### no ch_drop!
# no data cube for 1640540184, m009
# # cube 235: 1640712986 m009
# ### no ch_drop!
# # cube 236: 1640799689 m009
# ### no ch_drop!
# # cube 237: 1630519596 m010
# ### no ch_drop!
# # cube 238: 1631379874 m010
# ### no ch_drop!
# # cube 239: 1631387336 m010
# ### no ch_drop!
# # cube 240: 1631552188 m010
# ### no ch_drop!
# # cube 241: 1631559762 m010
# ### no ch_drop!
# # cube 242: 1631659886 m010
# ### no ch_drop!
# no data cube for 1631667564, m010
# no data cube for 1631724508, m010
# # cube 243: 1631732038 m010
# ### no ch_drop!
# no data cube for 1631810671, m010
# no data cube for 1631818149, m010
# no data cube for 1631982988, m010
# no data cube for 1631990463, m010
# no data cube for 1632069690, m010
# # cube 244: 1632077222 m010
# ### no ch_drop!
# # cube 245: 1632184922 m010
# ### no ch_drop!
# no data cube for 1632505883, m010
# no data cube for 1632760885, m010
# # cube 246: 1633365980 m010
# ### no ch_drop!
# no data cube for 1633970780, m010
# # cube 247: 1634252028 m010
# ### no ch_drop!
# # cube 248: 1634402485 m010
# ### no ch_drop!
# no data cube for 1634748682, m010
# no data cube for 1634835083, m010
# no data cube for 1637346562, m010
# # cube 249: 1637354605 m010
# ### no ch_drop!
# no data cube for 1637691677, m010
# # cube 250: 1637699408 m010
# ### no ch_drop!
# # cube 251: 1638130295 m010
# ### no ch_drop!
# # cube 252: 1638294319 m010
# ### no ch_drop!
# # cube 253: 1638301944 m010
# ### no ch_drop!
# no data cube for 1638386189, m010
# no data cube for 1638639082, m010
# # cube 254: 1638647186 m010
# ### no ch_drop!
# # cube 255: 1638898468 m010
# ### no ch_drop!
# no data cube for 1639157507, m010
# # cube 256: 1639331184 m010
# ### no ch_drop!
# # cube 257: 1639935088 m010
# ### no ch_drop!
# no data cube for 1640540184, m010
# # cube 258: 1640712986 m010
# ### no ch_drop!
# # cube 259: 1640799689 m010
# ### no ch_drop!
# # cube 260: 1630519596 m011
# ### no ch_drop!
# # cube 261: 1631379874 m011
# ### no ch_drop!
# # cube 262: 1631387336 m011
# ### no ch_drop!
# # cube 263: 1631552188 m011
# ### no ch_drop!
# # cube 264: 1631559762 m011
# ### no ch_drop!
# no data cube for 1631659886, m011
# no data cube for 1631667564, m011
# no data cube for 1631724508, m011
# no data cube for 1631732038, m011
# # cube 265: 1631810671 m011
# ### no ch_drop!
# no data cube for 1631818149, m011
# no data cube for 1631982988, m011
# no data cube for 1631990463, m011
# no data cube for 1632069690, m011
# # cube 266: 1632077222 m011
# ### no ch_drop!
# # cube 267: 1632184922 m011
# ### no ch_drop!
# no data cube for 1632505883, m011
# no data cube for 1632760885, m011
# # cube 268: 1633365980 m011
# ### no ch_drop!
# no data cube for 1633970780, m011
# # cube 269: 1634252028 m011
# ### no ch_drop!
# # cube 270: 1634402485 m011
# ### no ch_drop!
# no data cube for 1634748682, m011
# no data cube for 1634835083, m011
# no data cube for 1637346562, m011
# # cube 271: 1637354605 m011
# ### no ch_drop!
# no data cube for 1637691677, m011
# # cube 272: 1637699408 m011
# ### no ch_drop!
# # cube 273: 1638130295 m011
# ### no ch_drop!
# # cube 274: 1638294319 m011
# ### no ch_drop!
# # cube 275: 1638301944 m011
# ### no ch_drop!
# no data cube for 1638386189, m011
# no data cube for 1638639082, m011
# # cube 276: 1638647186 m011
# ### no ch_drop!
# # cube 277: 1638898468 m011
# ### no ch_drop!
# # cube 278: 1639157507 m011
# ### no ch_drop!
# no data cube for 1639331184, m011
# # cube 279: 1639935088 m011
# ### no ch_drop!
# no data cube for 1640540184, m011
# # cube 280: 1640712986 m011
# ### no ch_drop!
# # cube 281: 1640799689 m011
# ### no ch_drop!
# # cube 282: 1630519596 m012
# ### no ch_drop!
# # cube 283: 1631379874 m012
# ### no ch_drop!
# no data cube for 1631387336, m012
# # cube 284: 1631552188 m012
# ### no ch_drop!
# # cube 285: 1631559762 m012
# ### no ch_drop!
# # cube 286: 1631659886 m012
# ### no ch_drop!
# # cube 287: 1631667564 m012
# ### no ch_drop!
# no data cube for 1631724508, m012
# # cube 288: 1631732038 m012
# ### no ch_drop!
# # cube 289: 1631810671 m012
# ### no ch_drop!
# no data cube for 1631818149, m012
# no data cube for 1631982988, m012
# no data cube for 1631990463, m012
# no data cube for 1632069690, m012
# # cube 290: 1632077222 m012
# ### no ch_drop!
# # cube 291: 1632184922 m012
# ### no ch_drop!
# no data cube for 1632505883, m012
# no data cube for 1632760885, m012
# # cube 292: 1633365980 m012
# ### no ch_drop!
# no data cube for 1633970780, m012
# # cube 293: 1634252028 m012
# ### no ch_drop!
# # cube 294: 1634402485 m012
# ### no ch_drop!
# no data cube for 1634748682, m012
# no data cube for 1634835083, m012
# no data cube for 1637346562, m012
# # cube 295: 1637354605 m012
# ### no ch_drop!
# no data cube for 1637691677, m012
# # cube 296: 1637699408 m012
# ### no ch_drop!
# # cube 297: 1638130295 m012
# ### no ch_drop!
# # cube 298: 1638294319 m012
# ### no ch_drop!
# # cube 299: 1638301944 m012
# ### no ch_drop!
# no data cube for 1638386189, m012
# no data cube for 1638639082, m012
# no data cube for 1638647186, m012
# # cube 300: 1638898468 m012
# ### no ch_drop!
# # cube 301: 1639157507 m012
# ### no ch_drop!
# no data cube for 1639331184, m012
# # cube 302: 1639935088 m012
# ### no ch_drop!
# no data cube for 1640540184, m012
# # cube 303: 1640712986 m012
# ### no ch_drop!
# # cube 304: 1640799689 m012
# ### no ch_drop!
# no data cube for 1630519596, m013
# no data cube for 1631379874, m013
# no data cube for 1631387336, m013
# no data cube for 1631552188, m013
# no data cube for 1631559762, m013
# no data cube for 1631659886, m013
# no data cube for 1631667564, m013
# no data cube for 1631724508, m013
# no data cube for 1631732038, m013
# no data cube for 1631810671, m013
# no data cube for 1631818149, m013
# no data cube for 1631982988, m013
# no data cube for 1631990463, m013
# no data cube for 1632069690, m013
# no data cube for 1632077222, m013
# no data cube for 1632184922, m013
# no data cube for 1632505883, m013
# no data cube for 1632760885, m013
# no data cube for 1633365980, m013
# no data cube for 1633970780, m013
# no data cube for 1634252028, m013
# no data cube for 1634402485, m013
# no data cube for 1634748682, m013
# no data cube for 1634835083, m013
# no data cube for 1637346562, m013
# no data cube for 1637354605, m013
# no data cube for 1637691677, m013
# no data cube for 1637699408, m013
# no data cube for 1638130295, m013
# no data cube for 1638294319, m013
# no data cube for 1638301944, m013
# no data cube for 1638386189, m013
# no data cube for 1638639082, m013
# no data cube for 1638647186, m013
# no data cube for 1638898468, m013
# no data cube for 1639157507, m013
# no data cube for 1639331184, m013
# no data cube for 1639935088, m013
# no data cube for 1640540184, m013
# no data cube for 1640712986, m013
# no data cube for 1640799689, m013
# # cube 305: 1630519596 m014
# ### no ch_drop!
# # cube 306: 1631379874 m014
# ### no ch_drop!
# no data cube for 1631387336, m014
# no data cube for 1631552188, m014
# no data cube for 1631559762, m014
# # cube 307: 1631659886 m014
# ### no ch_drop!
# no data cube for 1631667564, m014
# no data cube for 1631724508, m014
# no data cube for 1631732038, m014
# no data cube for 1631810671, m014
# no data cube for 1631818149, m014
# # cube 308: 1631982988 m014
# ### no ch_drop!
# no data cube for 1631990463, m014
# no data cube for 1632069690, m014
# # cube 309: 1632077222 m014
# ### no ch_drop!
# # cube 310: 1632184922 m014
# ### no ch_drop!
# no data cube for 1632505883, m014
# # cube 311: 1632760885 m014
# ### no ch_drop!
# # cube 312: 1633365980 m014
# ### no ch_drop!
# no data cube for 1633970780, m014
# # cube 313: 1634252028 m014
# ### no ch_drop!
# # cube 314: 1634402485 m014
# ### no ch_drop!
# no data cube for 1634748682, m014
# no data cube for 1634835083, m014
# no data cube for 1637346562, m014
# no data cube for 1637354605, m014
# no data cube for 1637691677, m014
# no data cube for 1637699408, m014
# # cube 315: 1638130295 m014
# ### no ch_drop!
# # cube 316: 1638294319 m014
# ### no ch_drop!
# # cube 317: 1638301944 m014
# ### no ch_drop!
# # cube 318: 1638386189 m014
# ### no ch_drop!
# # cube 319: 1638639082 m014
# ### no ch_drop!
# no data cube for 1638647186, m014
# no data cube for 1638898468, m014
# no data cube for 1639157507, m014
# no data cube for 1639331184, m014
# no data cube for 1639935088, m014
# no data cube for 1640540184, m014
# no data cube for 1640712986, m014
# no data cube for 1640799689, m014
# no data cube for 1630519596, m015
# # cube 320: 1631379874 m015
# ### no ch_drop!
# no data cube for 1631387336, m015
# # cube 321: 1631552188 m015
# ### no ch_drop!
# # cube 322: 1631559762 m015
# ### no ch_drop!
# # cube 323: 1631659886 m015
# ### no ch_drop!
# # cube 324: 1631667564 m015
# ### no ch_drop!
# no data cube for 1631724508, m015
# # cube 325: 1631732038 m015
# ### no ch_drop!
# no data cube for 1631810671, m015
# no data cube for 1631818149, m015
# no data cube for 1631982988, m015
# no data cube for 1631990463, m015
# no data cube for 1632069690, m015
# # cube 326: 1632077222 m015
# ### no ch_drop!
# # cube 327: 1632184922 m015
# ### no ch_drop!
# no data cube for 1632505883, m015
# no data cube for 1632760885, m015
# # cube 328: 1633365980 m015
# ### no ch_drop!
# no data cube for 1633970780, m015
# # cube 329: 1634252028 m015
# ### no ch_drop!
# # cube 330: 1634402485 m015
# ### no ch_drop!
# no data cube for 1634748682, m015
# no data cube for 1634835083, m015
# no data cube for 1637346562, m015
# # cube 331: 1637354605 m015
# ### no ch_drop!
# no data cube for 1637691677, m015
# # cube 332: 1637699408 m015
# ### no ch_drop!
# # cube 333: 1638130295 m015
# ### no ch_drop!
# # cube 334: 1638294319 m015
# ### no ch_drop!
# # cube 335: 1638301944 m015
# ### no ch_drop!
# no data cube for 1638386189, m015
# # cube 336: 1638639082 m015
# ### no ch_drop!
# no data cube for 1638647186, m015
# # cube 337: 1638898468 m015
# ### no ch_drop!
# no data cube for 1639157507, m015
# # cube 338: 1639331184 m015
# ### no ch_drop!
# # cube 339: 1639935088 m015
# ### no ch_drop!
# no data cube for 1640540184, m015
# # cube 340: 1640712986 m015
# ### no ch_drop!
# no data cube for 1640799689, m015
# no data cube for 1630519596, m016
# no data cube for 1631379874, m016
# # cube 341: 1631387336 m016
# ### no ch_drop!
# # cube 342: 1631552188 m016
# ### no ch_drop!
# # cube 343: 1631559762 m016
# ### no ch_drop!
# # cube 344: 1631659886 m016
# ### no ch_drop!
# # cube 345: 1631667564 m016
# ### no ch_drop!
# # cube 346: 1631724508 m016
# ### no ch_drop!
# # cube 347: 1631732038 m016
# ### no ch_drop!
# # cube 348: 1631810671 m016
# ### no ch_drop!
# # cube 349: 1631818149 m016
# ### no ch_drop!
# no data cube for 1631982988, m016
# no data cube for 1631990463, m016
# no data cube for 1632069690, m016
# no data cube for 1632077222, m016
# no data cube for 1632184922, m016
# no data cube for 1632505883, m016
# # cube 350: 1632760885 m016
# ### no ch_drop!
# # cube 351: 1633365980 m016
# ### no ch_drop!
# no data cube for 1633970780, m016
# # cube 352: 1634252028 m016
# ### no ch_drop!
# # cube 353: 1634402485 m016
# ### no ch_drop!
# no data cube for 1634748682, m016
# no data cube for 1634835083, m016
# no data cube for 1637346562, m016
# # cube 354: 1637354605 m016
# ### no ch_drop!
# no data cube for 1637691677, m016
# # cube 355: 1637699408 m016
# ### no ch_drop!
# # cube 356: 1638130295 m016
# ### no ch_drop!
# # cube 357: 1638294319 m016
# ### no ch_drop!
# # cube 358: 1638301944 m016
# ### no ch_drop!
# no data cube for 1638386189, m016
# # cube 359: 1638639082 m016
# ### no ch_drop!
# no data cube for 1638647186, m016
# # cube 360: 1638898468 m016
# ### no ch_drop!
# no data cube for 1639157507, m016
# # cube 361: 1639331184 m016
# ### no ch_drop!
# # cube 362: 1639935088 m016
# ### no ch_drop!
# no data cube for 1640540184, m016
# no data cube for 1640712986, m016
# no data cube for 1640799689, m016
# no data cube for 1630519596, m017
# # cube 363: 1631379874 m017
# ### no ch_drop!
# # cube 364: 1631387336 m017
# ### no ch_drop!
# # cube 365: 1631552188 m017
# ### no ch_drop!
# # cube 366: 1631559762 m017
# ### no ch_drop!
# # cube 367: 1631659886 m017
# ### no ch_drop!
# # cube 368: 1631667564 m017
# ### no ch_drop!
# no data cube for 1631724508, m017
# no data cube for 1631732038, m017
# # cube 369: 1631810671 m017
# ### no ch_drop!
# no data cube for 1631818149, m017
# no data cube for 1631982988, m017
# no data cube for 1631990463, m017
# # cube 370: 1632069690 m017
# ### no ch_drop!
# # cube 371: 1632077222 m017
# ### no ch_drop!
# # cube 372: 1632184922 m017
# ### no ch_drop!
# no data cube for 1632505883, m017
# # cube 373: 1632760885 m017
# ### no ch_drop!
# # cube 374: 1633365980 m017
# ### no ch_drop!
# no data cube for 1633970780, m017
# # cube 375: 1634252028 m017
# ### no ch_drop!
# # cube 376: 1634402485 m017
# ### no ch_drop!
# no data cube for 1634748682, m017
# no data cube for 1634835083, m017
# no data cube for 1637346562, m017
# # cube 377: 1637354605 m017
# ### no ch_drop!
# no data cube for 1637691677, m017
# # cube 378: 1637699408 m017
# ### no ch_drop!
# # cube 379: 1638130295 m017
# ### no ch_drop!
# # cube 380: 1638294319 m017
# ### no ch_drop!
# # cube 381: 1638301944 m017
# ### no ch_drop!
# no data cube for 1638386189, m017
# no data cube for 1638639082, m017
# no data cube for 1638647186, m017
# # cube 382: 1638898468 m017
# ### no ch_drop!
# # cube 383: 1639157507 m017
# ### no ch_drop!
# no data cube for 1639331184, m017
# # cube 384: 1639935088 m017
# ### no ch_drop!
# no data cube for 1640540184, m017
# # cube 385: 1640712986 m017
# ### no ch_drop!
# # cube 386: 1640799689 m017
# ### no ch_drop!
# # cube 387: 1630519596 m018
# ### no ch_drop!
# # cube 388: 1631379874 m018
# ### no ch_drop!
# # cube 389: 1631387336 m018
# ### no ch_drop!
# # cube 390: 1631552188 m018
# ### no ch_drop!
# # cube 391: 1631559762 m018
# ### no ch_drop!
# # cube 392: 1631659886 m018
# ### no ch_drop!
# # cube 393: 1631667564 m018
# ### no ch_drop!
# # cube 394: 1631724508 m018
# ### no ch_drop!
# # cube 395: 1631732038 m018
# ### no ch_drop!
# # cube 396: 1631810671 m018
# ### no ch_drop!
# # cube 397: 1631818149 m018
# ### no ch_drop!
# no data cube for 1631982988, m018
# # cube 398: 1631990463 m018
# ### no ch_drop!
# # cube 399: 1632069690 m018
# ### no ch_drop!
# # cube 400: 1632077222 m018
# ### no ch_drop!
# # cube 401: 1632184922 m018
# ### no ch_drop!
# no data cube for 1632505883, m018
# no data cube for 1632760885, m018
# # cube 402: 1633365980 m018
# ### no ch_drop!
# no data cube for 1633970780, m018
# # cube 403: 1634252028 m018
# ### no ch_drop!
# # cube 404: 1634402485 m018
# ### no ch_drop!
# no data cube for 1634748682, m018
# no data cube for 1634835083, m018
# no data cube for 1637346562, m018
# # cube 405: 1637354605 m018
# ### no ch_drop!
# no data cube for 1637691677, m018
# # cube 406: 1637699408 m018
# ### no ch_drop!
# # cube 407: 1638130295 m018
# ### no ch_drop!
# # cube 408: 1638294319 m018
# ### no ch_drop!
# # cube 409: 1638301944 m018
# ### no ch_drop!
# no data cube for 1638386189, m018
# # cube 410: 1638639082 m018
# ### no ch_drop!
# no data cube for 1638647186, m018
# # cube 411: 1638898468 m018
# ### no ch_drop!
# # cube 412: 1639157507 m018
# ### no ch_drop!
# no data cube for 1639331184, m018
# # cube 413: 1639935088 m018
# ### no ch_drop!
# no data cube for 1640540184, m018
# # cube 414: 1640712986 m018
# ### no ch_drop!
# # cube 415: 1640799689 m018
# ### no ch_drop!
# # cube 416: 1630519596 m019
# ### no ch_drop!
# # cube 417: 1631379874 m019
# ### no ch_drop!
# no data cube for 1631387336, m019
# # cube 418: 1631552188 m019
# ### no ch_drop!
# # cube 419: 1631559762 m019
# ### no ch_drop!
# # cube 420: 1631659886 m019
# ### no ch_drop!
# # cube 421: 1631667564 m019
# ### no ch_drop!
# # cube 422: 1631724508 m019
# ### no ch_drop!
# # cube 423: 1631732038 m019
# ### no ch_drop!
# # cube 424: 1631810671 m019
# ### no ch_drop!
# # cube 425: 1631818149 m019
# ### no ch_drop!
# no data cube for 1631982988, m019
# no data cube for 1631990463, m019
# no data cube for 1632069690, m019
# # cube 426: 1632077222 m019
# ### no ch_drop!
# # cube 427: 1632184922 m019
# ### no ch_drop!
# no data cube for 1632505883, m019
# no data cube for 1632760885, m019
# # cube 428: 1633365980 m019
# ### no ch_drop!
# no data cube for 1633970780, m019
# # cube 429: 1634252028 m019
# ### no ch_drop!
# # cube 430: 1634402485 m019
# ### no ch_drop!
# no data cube for 1634748682, m019
# no data cube for 1634835083, m019
# no data cube for 1637346562, m019
# # cube 431: 1637354605 m019
# ### no ch_drop!
# no data cube for 1637691677, m019
# # cube 432: 1637699408 m019
# ### no ch_drop!
# # cube 433: 1638130295 m019
# ### no ch_drop!
# # cube 434: 1638294319 m019
# ### no ch_drop!
# # cube 435: 1638301944 m019
# ### no ch_drop!
# no data cube for 1638386189, m019
# no data cube for 1638639082, m019
# no data cube for 1638647186, m019
# # cube 436: 1638898468 m019
# ### no ch_drop!
# no data cube for 1639157507, m019
# no data cube for 1639331184, m019
# # cube 437: 1639935088 m019
# ### no ch_drop!
# no data cube for 1640540184, m019
# no data cube for 1640712986, m019
# no data cube for 1640799689, m019
# # cube 438: 1630519596 m020
# ### no ch_drop!
# no data cube for 1631379874, m020
# # cube 439: 1631387336 m020
# ### no ch_drop!
# # cube 440: 1631552188 m020
# ### no ch_drop!
# # cube 441: 1631559762 m020
# ### no ch_drop!
# # cube 442: 1631659886 m020
# ### no ch_drop!
# # cube 443: 1631667564 m020
# ### no ch_drop!
# no data cube for 1631724508, m020
# # cube 444: 1631732038 m020
# ### no ch_drop!
# # cube 445: 1631810671 m020
# ### no ch_drop!
# no data cube for 1631818149, m020
# no data cube for 1631982988, m020
# no data cube for 1631990463, m020
# # cube 446: 1632069690 m020
# ### no ch_drop!
# # cube 447: 1632077222 m020
# ### no ch_drop!
# # cube 448: 1632184922 m020
# ### no ch_drop!
# no data cube for 1632505883, m020
# no data cube for 1632760885, m020
# # cube 449: 1633365980 m020
# ### no ch_drop!
# no data cube for 1633970780, m020
# # cube 450: 1634252028 m020
# ### no ch_drop!
# # cube 451: 1634402485 m020
# ### no ch_drop!
# no data cube for 1634748682, m020
# no data cube for 1634835083, m020
# no data cube for 1637346562, m020
# # cube 452: 1637354605 m020
# ### no ch_drop!
# no data cube for 1637691677, m020
# # cube 453: 1637699408 m020
# ### no ch_drop!
# # cube 454: 1638130295 m020
# ### no ch_drop!
# # cube 455: 1638294319 m020
# ### no ch_drop!
# # cube 456: 1638301944 m020
# ### no ch_drop!
# # cube 457: 1638386189 m020
# ### no ch_drop!
# no data cube for 1638639082, m020
# no data cube for 1638647186, m020
# # cube 458: 1638898468 m020
# ### no ch_drop!
# # cube 459: 1639157507 m020
# ### no ch_drop!
# # cube 460: 1639331184 m020
# ### no ch_drop!
# # cube 461: 1639935088 m020
# ### no ch_drop!
# no data cube for 1640540184, m020
# # cube 462: 1640712986 m020
# ### no ch_drop!
# no data cube for 1640799689, m020
# # cube 463: 1630519596 m021
# ### no ch_drop!
# # cube 464: 1631379874 m021
# ### no ch_drop!
# # cube 465: 1631387336 m021
# ### no ch_drop!
# # cube 466: 1631552188 m021
# ### no ch_drop!
# # cube 467: 1631559762 m021
# ### no ch_drop!
# # cube 468: 1631659886 m021
# ### no ch_drop!
# # cube 469: 1631667564 m021
# ### no ch_drop!
# no data cube for 1631724508, m021
# # cube 470: 1631732038 m021
# ### no ch_drop!
# # cube 471: 1631810671 m021
# ### no ch_drop!
# # cube 472: 1631818149 m021
# ### no ch_drop!
# no data cube for 1631982988, m021
# no data cube for 1631990463, m021
# no data cube for 1632069690, m021
# # cube 473: 1632077222 m021
# ### no ch_drop!
# # cube 474: 1632184922 m021
# ### no ch_drop!
# no data cube for 1632505883, m021
# no data cube for 1632760885, m021
# # cube 475: 1633365980 m021
# ### no ch_drop!
# no data cube for 1633970780, m021
# # cube 476: 1634252028 m021
# ### no ch_drop!
# # cube 477: 1634402485 m021
# ### no ch_drop!
# no data cube for 1634748682, m021
# no data cube for 1634835083, m021
# no data cube for 1637346562, m021
# # cube 478: 1637354605 m021
# ### no ch_drop!
# no data cube for 1637691677, m021
# # cube 479: 1637699408 m021
# ### no ch_drop!
# # cube 480: 1638130295 m021
# ### no ch_drop!
# # cube 481: 1638294319 m021
# ### no ch_drop!
# # cube 482: 1638301944 m021
# ### no ch_drop!
# no data cube for 1638386189, m021
# no data cube for 1638639082, m021
# # cube 483: 1638647186 m021
# ### no ch_drop!
# # cube 484: 1638898468 m021
# ### no ch_drop!
# no data cube for 1639157507, m021
# no data cube for 1639331184, m021
# # cube 485: 1639935088 m021
# ### no ch_drop!
# no data cube for 1640540184, m021
# # cube 486: 1640712986 m021
# ### no ch_drop!
# no data cube for 1640799689, m021
# no data cube for 1630519596, m022
# no data cube for 1631379874, m022
# no data cube for 1631387336, m022
# no data cube for 1631552188, m022
# no data cube for 1631559762, m022
# # cube 487: 1631659886 m022
# ### no ch_drop!
# # cube 488: 1631667564 m022
# ### no ch_drop!
# no data cube for 1631724508, m022
# no data cube for 1631732038, m022
# no data cube for 1631810671, m022
# no data cube for 1631818149, m022
# no data cube for 1631982988, m022
# no data cube for 1631990463, m022
# no data cube for 1632069690, m022
# # cube 489: 1632077222 m022
# ### no ch_drop!
# # cube 490: 1632184922 m022
# ### no ch_drop!
# no data cube for 1632505883, m022
# no data cube for 1632760885, m022
# # cube 491: 1633365980 m022
# ### no ch_drop!
# no data cube for 1633970780, m022
# # cube 492: 1634252028 m022
# ### no ch_drop!
# # cube 493: 1634402485 m022
# ### no ch_drop!
# no data cube for 1634748682, m022
# no data cube for 1634835083, m022
# no data cube for 1637346562, m022
# # cube 494: 1637354605 m022
# ### no ch_drop!
# no data cube for 1637691677, m022
# # cube 495: 1637699408 m022
# ### no ch_drop!
# # cube 496: 1638130295 m022
# ### no ch_drop!
# # cube 497: 1638294319 m022
# ### no ch_drop!
# # cube 498: 1638301944 m022
# ### no ch_drop!
# no data cube for 1638386189, m022
# # cube 499: 1638639082 m022
# ### no ch_drop!
# no data cube for 1638647186, m022
# # cube 500: 1638898468 m022
# ### no ch_drop!
# no data cube for 1639157507, m022
# no data cube for 1639331184, m022
# # cube 501: 1639935088 m022
# ### no ch_drop!
# no data cube for 1640540184, m022
# no data cube for 1640712986, m022
# no data cube for 1640799689, m022
# no data cube for 1630519596, m023
# no data cube for 1631379874, m023
# no data cube for 1631387336, m023
# no data cube for 1631552188, m023
# # cube 502: 1631559762 m023
# ### no ch_drop!
# # cube 503: 1631659886 m023
# ### no ch_drop!
# # cube 504: 1631667564 m023
# ### no ch_drop!
# no data cube for 1631724508, m023
# # cube 505: 1631732038 m023
# ### no ch_drop!
# no data cube for 1631810671, m023
# no data cube for 1631818149, m023
# no data cube for 1631982988, m023
# no data cube for 1631990463, m023
# # cube 506: 1632069690 m023
# ### no ch_drop!
# # cube 507: 1632077222 m023
# ### no ch_drop!
# # cube 508: 1632184922 m023
# ### no ch_drop!
# no data cube for 1632505883, m023
# # cube 509: 1632760885 m023
# ### no ch_drop!
# # cube 510: 1633365980 m023
# ### no ch_drop!
# no data cube for 1633970780, m023
# # cube 511: 1634252028 m023
# ### no ch_drop!
# # cube 512: 1634402485 m023
# ### no ch_drop!
# no data cube for 1634748682, m023
# no data cube for 1634835083, m023
# no data cube for 1637346562, m023
# # cube 513: 1637354605 m023
# ### no ch_drop!
# no data cube for 1637691677, m023
# # cube 514: 1637699408 m023
# ### no ch_drop!
# # cube 515: 1638130295 m023
# ### no ch_drop!
# # cube 516: 1638294319 m023
# ### no ch_drop!
# # cube 517: 1638301944 m023
# ### no ch_drop!
# no data cube for 1638386189, m023
# # cube 518: 1638639082 m023
# ### no ch_drop!
# no data cube for 1638647186, m023
# # cube 519: 1638898468 m023
# ### no ch_drop!
# no data cube for 1639157507, m023
# no data cube for 1639331184, m023
# # cube 520: 1639935088 m023
# ### no ch_drop!
# no data cube for 1640540184, m023
# # cube 521: 1640712986 m023
# ### no ch_drop!
# # cube 522: 1640799689 m023
# ### no ch_drop!
# no data cube for 1630519596, m024
# no data cube for 1631379874, m024
# no data cube for 1631387336, m024
# no data cube for 1631552188, m024
# no data cube for 1631559762, m024
# # cube 523: 1631659886 m024
# ### no ch_drop!
# # cube 524: 1631667564 m024
# ### no ch_drop!
# no data cube for 1631724508, m024
# no data cube for 1631732038, m024
# no data cube for 1631810671, m024
# no data cube for 1631818149, m024
# no data cube for 1631982988, m024
# no data cube for 1631990463, m024
# no data cube for 1632069690, m024
# # cube 525: 1632077222 m024
# ### no ch_drop!
# no data cube for 1632184922, m024
# no data cube for 1632505883, m024
# no data cube for 1632760885, m024
# # cube 526: 1633365980 m024
# ### no ch_drop!
# no data cube for 1633970780, m024
# # cube 527: 1634252028 m024
# ### no ch_drop!
# # cube 528: 1634402485 m024
# ### no ch_drop!
# no data cube for 1634748682, m024
# no data cube for 1634835083, m024
# no data cube for 1637346562, m024
# no data cube for 1637354605, m024
# no data cube for 1637691677, m024
# # cube 529: 1637699408 m024
# ### no ch_drop!
# # cube 530: 1638130295 m024
# ### no ch_drop!
# # cube 531: 1638294319 m024
# ### no ch_drop!
# # cube 532: 1638301944 m024
# ### no ch_drop!
# no data cube for 1638386189, m024
# no data cube for 1638639082, m024
# no data cube for 1638647186, m024
# # cube 533: 1638898468 m024
# ### no ch_drop!
# no data cube for 1639157507, m024
# no data cube for 1639331184, m024
# no data cube for 1639935088, m024
# no data cube for 1640540184, m024
# no data cube for 1640712986, m024
# no data cube for 1640799689, m024
# # cube 534: 1630519596 m025
# ### no ch_drop!
# no data cube for 1631379874, m025
# no data cube for 1631387336, m025
# no data cube for 1631552188, m025
# no data cube for 1631559762, m025
# # cube 535: 1631659886 m025
# ### no ch_drop!
# # cube 536: 1631667564 m025
# ### no ch_drop!
# no data cube for 1631724508, m025
# no data cube for 1631732038, m025
# no data cube for 1631810671, m025
# no data cube for 1631818149, m025
# no data cube for 1631982988, m025
# no data cube for 1631990463, m025
# # cube 537: 1632069690 m025
# ### no ch_drop!
# # cube 538: 1632077222 m025
# ### no ch_drop!
# # cube 539: 1632184922 m025
# ### no ch_drop!
# no data cube for 1632505883, m025
# no data cube for 1632760885, m025
# # cube 540: 1633365980 m025
# ### no ch_drop!
# no data cube for 1633970780, m025
# # cube 541: 1634252028 m025
# ### no ch_drop!
# # cube 542: 1634402485 m025
# ### no ch_drop!
# no data cube for 1634748682, m025
# no data cube for 1634835083, m025
# no data cube for 1637346562, m025
# no data cube for 1637354605, m025
# no data cube for 1637691677, m025
# # cube 543: 1637699408 m025
# ### no ch_drop!
# # cube 544: 1638130295 m025
# ### no ch_drop!
# no data cube for 1638294319, m025
# # cube 545: 1638301944 m025
# ### no ch_drop!
# no data cube for 1638386189, m025
# # cube 546: 1638639082 m025
# ### no ch_drop!
# no data cube for 1638647186, m025
# no data cube for 1638898468, m025
# # cube 547: 1639157507 m025
# ### no ch_drop!
# no data cube for 1639331184, m025
# # cube 548: 1639935088 m025
# ### no ch_drop!
# no data cube for 1640540184, m025
# no data cube for 1640712986, m025
# # cube 549: 1640799689 m025
# ### no ch_drop!
# no data cube for 1630519596, m026
# no data cube for 1631379874, m026
# no data cube for 1631387336, m026
# no data cube for 1631552188, m026
# no data cube for 1631559762, m026
# # cube 550: 1631659886 m026
# ### no ch_drop!
# # cube 551: 1631667564 m026
# ### no ch_drop!
# no data cube for 1631724508, m026
# no data cube for 1631732038, m026
# no data cube for 1631810671, m026
# no data cube for 1631818149, m026
# no data cube for 1631982988, m026
# no data cube for 1631990463, m026
# # cube 552: 1632069690 m026
# ### no ch_drop!
# # cube 553: 1632077222 m026
# ### no ch_drop!
# # cube 554: 1632184922 m026
# ### no ch_drop!
# no data cube for 1632505883, m026
# # cube 555: 1632760885 m026
# ### no ch_drop!
# # cube 556: 1633365980 m026
# ### no ch_drop!
# no data cube for 1633970780, m026
# # cube 557: 1634252028 m026
# ### no ch_drop!
# # cube 558: 1634402485 m026
# ### no ch_drop!
# no data cube for 1634748682, m026
# no data cube for 1634835083, m026
# no data cube for 1637346562, m026
# # cube 559: 1637354605 m026
# ### no ch_drop!
# no data cube for 1637691677, m026
# # cube 560: 1637699408 m026
# ### no ch_drop!
# # cube 561: 1638130295 m026
# ### no ch_drop!
# # cube 562: 1638294319 m026
# ### no ch_drop!
# # cube 563: 1638301944 m026
# ### no ch_drop!
# no data cube for 1638386189, m026
# # cube 564: 1638639082 m026
# ### no ch_drop!
# no data cube for 1638647186, m026
# # cube 565: 1638898468 m026
# ### no ch_drop!
# # cube 566: 1639157507 m026
# ### no ch_drop!
# # cube 567: 1639331184 m026
# ### no ch_drop!
# # cube 568: 1639935088 m026
# ### no ch_drop!
# no data cube for 1640540184, m026
# # cube 569: 1640712986 m026
# ### no ch_drop!
# no data cube for 1640799689, m026
# # cube 570: 1630519596 m027
# ### no ch_drop!
# no data cube for 1631379874, m027
# # cube 571: 1631387336 m027
# ### no ch_drop!
# no data cube for 1631552188, m027
# no data cube for 1631559762, m027
# no data cube for 1631659886, m027
# no data cube for 1631667564, m027
# no data cube for 1631724508, m027
# no data cube for 1631732038, m027
# # cube 572: 1631810671 m027
# ### no ch_drop!
# no data cube for 1631818149, m027
# # cube 573: 1631982988 m027
# ### no ch_drop!
# # cube 574: 1631990463 m027
# ### no ch_drop!
# # cube 575: 1632069690 m027
# ### no ch_drop!
# # cube 576: 1632077222 m027
# ### no ch_drop!
# # cube 577: 1632184922 m027
# ### no ch_drop!
# no data cube for 1632505883, m027
# # cube 578: 1632760885 m027
# ### no ch_drop!
# # cube 579: 1633365980 m027
# ### no ch_drop!
# no data cube for 1633970780, m027
# # cube 580: 1634252028 m027
# ### no ch_drop!
# # cube 581: 1634402485 m027
# ### no ch_drop!
# no data cube for 1634748682, m027
# no data cube for 1634835083, m027
# no data cube for 1637346562, m027
# # cube 582: 1637354605 m027
# ### no ch_drop!
# no data cube for 1637691677, m027
# # cube 583: 1637699408 m027
# ### no ch_drop!
# # cube 584: 1638130295 m027
# ### no ch_drop!
# # cube 585: 1638294319 m027
# ### no ch_drop!
# # cube 586: 1638301944 m027
# ### no ch_drop!
# # cube 587: 1638386189 m027
# ### no ch_drop!
# # cube 588: 1638639082 m027
# ### no ch_drop!
# # cube 589: 1638647186 m027
# ### no ch_drop!
# # cube 590: 1638898468 m027
# ### no ch_drop!
# # cube 591: 1639157507 m027
# ### no ch_drop!
# no data cube for 1639331184, m027
# # cube 592: 1639935088 m027
# ### no ch_drop!
# no data cube for 1640540184, m027
# # cube 593: 1640712986 m027
# ### no ch_drop!
# no data cube for 1640799689, m027
# no data cube for 1630519596, m028
# # cube 594: 1631379874 m028
# ### no ch_drop!
# # cube 595: 1631387336 m028
# ### no ch_drop!
# no data cube for 1631552188, m028
# no data cube for 1631559762, m028
# no data cube for 1631659886, m028
# no data cube for 1631667564, m028
# # cube 596: 1631724508 m028
# ### no ch_drop!
# # cube 597: 1631732038 m028
# ### no ch_drop!
# # cube 598: 1631810671 m028
# ### no ch_drop!
# no data cube for 1631818149, m028
# # cube 599: 1631982988 m028
# ### no ch_drop!
# no data cube for 1631990463, m028
# # cube 600: 1632069690 m028
# ### no ch_drop!
# # cube 601: 1632077222 m028
# ### no ch_drop!
# # cube 602: 1632184922 m028
# ### no ch_drop!
# no data cube for 1632505883, m028
# # cube 603: 1632760885 m028
# ### no ch_drop!
# # cube 604: 1633365980 m028
# ### no ch_drop!
# no data cube for 1633970780, m028
# # cube 605: 1634252028 m028
# ### no ch_drop!
# # cube 606: 1634402485 m028
# ### no ch_drop!
# no data cube for 1634748682, m028
# no data cube for 1634835083, m028
# no data cube for 1637346562, m028
# no data cube for 1637354605, m028
# no data cube for 1637691677, m028
# no data cube for 1637699408, m028
# no data cube for 1638130295, m028
# # cube 607: 1638294319 m028
# ### no ch_drop!
# # cube 608: 1638301944 m028
# ### no ch_drop!
# no data cube for 1638386189, m028
# # cube 609: 1638639082 m028
# ### no ch_drop!
# no data cube for 1638647186, m028
# # cube 610: 1638898468 m028
# ### no ch_drop!
# # cube 611: 1639157507 m028
# ### no ch_drop!
# no data cube for 1639331184, m028
# # cube 612: 1639935088 m028
# ### no ch_drop!
# no data cube for 1640540184, m028
# # cube 613: 1640712986 m028
# ### no ch_drop!
# # cube 614: 1640799689 m028
# ### no ch_drop!
# # cube 615: 1630519596 m029
# ### no ch_drop!
# # cube 616: 1631379874 m029
# ### no ch_drop!
# # cube 617: 1631387336 m029
# ### no ch_drop!
# no data cube for 1631552188, m029
# no data cube for 1631559762, m029
# no data cube for 1631659886, m029
# no data cube for 1631667564, m029
# # cube 618: 1631724508 m029
# ### no ch_drop!
# # cube 619: 1631732038 m029
# ### no ch_drop!
# # cube 620: 1631810671 m029
# ### no ch_drop!
# no data cube for 1631818149, m029
# no data cube for 1631982988, m029
# # cube 621: 1631990463 m029
# ### no ch_drop!
# no data cube for 1632069690, m029
# # cube 622: 1632077222 m029
# ### no ch_drop!
# # cube 623: 1632184922 m029
# ### no ch_drop!
# no data cube for 1632505883, m029
# no data cube for 1632760885, m029
# # cube 624: 1633365980 m029
# ### no ch_drop!
# no data cube for 1633970780, m029
# # cube 625: 1634252028 m029
# ### no ch_drop!
# # cube 626: 1634402485 m029
# ### no ch_drop!
# no data cube for 1634748682, m029
# no data cube for 1634835083, m029
# no data cube for 1637346562, m029
# # cube 627: 1637354605 m029
# ### no ch_drop!
# no data cube for 1637691677, m029
# # cube 628: 1637699408 m029
# ### no ch_drop!
# # cube 629: 1638130295 m029
# ### no ch_drop!
# # cube 630: 1638294319 m029
# ### no ch_drop!
# # cube 631: 1638301944 m029
# ### no ch_drop!
# no data cube for 1638386189, m029
# ...
# ### no ch_drop!
# # cube 1154: 1633365980 m054
# ### no ch_drop!
# no data cube for 1633970780, m054
# # cube 1155: 1634252028 m054
# ### no ch_drop!
# # cube 1156: 1634402485 m054
# ### no ch_drop!
# no data cube for 1634748682, m054
# no data cube for 1634835083, m054
# no data cube for 1637346562, m054
# no data cube for 1637354605, m054
# no data cube for 1637691677, m054
# # cube 1157: 1637699408 m054
# ### no ch_drop!
# # cube 1158: 1638130295 m054
# ### no ch_drop!
# no data cube for 1638294319, m054
# no data cube for 1638301944, m054
# no data cube for 1638386189, m054
# no data cube for 1638639082, m054
# no data cube for 1638647186, m054
# no data cube for 1638898468, m054
# no data cube for 1639157507, m054
# no data cube for 1639331184, m054
# no data cube for 1639935088, m054
# no data cube for 1640540184, m054
# no data cube for 1640712986, m054
# no data cube for 1640799689, m054
# no data cube for 1630519596, m055
# no data cube for 1631379874, m055
# # cube 1159: 1631387336 m055
# ### no ch_drop!
# # cube 1160: 1631552188 m055
# ### no ch_drop!
# no data cube for 1631559762, m055
# # cube 1161: 1631659886 m055
# ### no ch_drop!
# # cube 1162: 1631667564 m055
# ### no ch_drop!
# no data cube for 1631724508, m055
# # cube 1163: 1631732038 m055
# ### no ch_drop!
# # cube 1164: 1631810671 m055
# ### no ch_drop!
# no data cube for 1631818149, m055
# no data cube for 1631982988, m055
# no data cube for 1631990463, m055
# # cube 1165: 1632069690 m055
# ### no ch_drop!
# # cube 1166: 1632077222 m055
# ### no ch_drop!
# # cube 1167: 1632184922 m055
# ### no ch_drop!
# no data cube for 1632505883, m055
# no data cube for 1632760885, m055
# # cube 1168: 1633365980 m055
# ### no ch_drop!
# no data cube for 1633970780, m055
# # cube 1169: 1634252028 m055
# ### no ch_drop!
# # cube 1170: 1634402485 m055
# ### no ch_drop!
# no data cube for 1634748682, m055
# no data cube for 1634835083, m055
# no data cube for 1637346562, m055
# # cube 1171: 1637354605 m055
# ### no ch_drop!
# no data cube for 1637691677, m055
# no data cube for 1637699408, m055
# no data cube for 1638130295, m055
# # cube 1172: 1638294319 m055
# ### no ch_drop!
# # cube 1173: 1638301944 m055
# ### no ch_drop!
# no data cube for 1638386189, m055
# no data cube for 1638639082, m055
# no data cube for 1638647186, m055
# # cube 1174: 1638898468 m055
# ### no ch_drop!
# no data cube for 1639157507, m055
# no data cube for 1639331184, m055
# # cube 1175: 1639935088 m055
# ### no ch_drop!
# no data cube for 1640540184, m055
# # cube 1176: 1640712986 m055
# ### no ch_drop!
# no data cube for 1640799689, m055
# no data cube for 1630519596, m056
# # cube 1177: 1631379874 m056
# ### no ch_drop!
# # cube 1178: 1631387336 m056
# ### no ch_drop!
# # cube 1179: 1631552188 m056
# ### no ch_drop!
# # cube 1180: 1631559762 m056
# ### no ch_drop!
# # cube 1181: 1631659886 m056
# ### no ch_drop!
# # cube 1182: 1631667564 m056
# ### no ch_drop!
# no data cube for 1631724508, m056
# no data cube for 1631732038, m056
# # cube 1183: 1631810671 m056
# ### no ch_drop!
# no data cube for 1631818149, m056
# no data cube for 1631982988, m056
# no data cube for 1631990463, m056
# no data cube for 1632069690, m056
# # cube 1184: 1632077222 m056
# ### no ch_drop!
# # cube 1185: 1632184922 m056
# ### no ch_drop!
# no data cube for 1632505883, m056
# no data cube for 1632760885, m056
# # cube 1186: 1633365980 m056
# ### no ch_drop!
# no data cube for 1633970780, m056
# # cube 1187: 1634252028 m056
# ### no ch_drop!
# # cube 1188: 1634402485 m056
# ### no ch_drop!
# no data cube for 1634748682, m056
# no data cube for 1634835083, m056
# no data cube for 1637346562, m056
# # cube 1189: 1637354605 m056
# ### no ch_drop!
# no data cube for 1637691677, m056
# # cube 1190: 1637699408 m056
# ### no ch_drop!
# # cube 1191: 1638130295 m056
# ### no ch_drop!
# no data cube for 1638294319, m056
# no data cube for 1638301944, m056
# no data cube for 1638386189, m056
# # cube 1192: 1638639082 m056
# ### no ch_drop!
# # cube 1193: 1638647186 m056
# ### no ch_drop!
# # cube 1194: 1638898468 m056
# ### no ch_drop!
# # cube 1195: 1639157507 m056
# ### no ch_drop!
# no data cube for 1639331184, m056
# # cube 1196: 1639935088 m056
# ### no ch_drop!
# no data cube for 1640540184, m056
# # cube 1197: 1640712986 m056
# ### no ch_drop!
# no data cube for 1640799689, m056
# no data cube for 1630519596, m057
# # cube 1198: 1631379874 m057
# ### no ch_drop!
# no data cube for 1631387336, m057
# # cube 1199: 1631552188 m057
# ### no ch_drop!
# # cube 1200: 1631559762 m057
# ### no ch_drop!
# # cube 1201: 1631659886 m057
# ### no ch_drop!
# # cube 1202: 1631667564 m057
# ### no ch_drop!
# no data cube for 1631724508, m057
# # cube 1203: 1631732038 m057
# ### no ch_drop!
# no data cube for 1631810671, m057
# no data cube for 1631818149, m057
# no data cube for 1631982988, m057
# no data cube for 1631990463, m057
# no data cube for 1632069690, m057
# # cube 1204: 1632077222 m057
# ### no ch_drop!
# no data cube for 1632184922, m057
# no data cube for 1632505883, m057
# no data cube for 1632760885, m057
# # cube 1205: 1633365980 m057
# ### no ch_drop!
# no data cube for 1633970780, m057
# # cube 1206: 1634252028 m057
# ### no ch_drop!
# # cube 1207: 1634402485 m057
# ### no ch_drop!
# no data cube for 1634748682, m057
# no data cube for 1634835083, m057
# no data cube for 1637346562, m057
# # cube 1208: 1637354605 m057
# ### no ch_drop!
# no data cube for 1637691677, m057
# # cube 1209: 1637699408 m057
# ### no ch_drop!
# # cube 1210: 1638130295 m057
# ### no ch_drop!
# # cube 1211: 1638294319 m057
# ### no ch_drop!
# # cube 1212: 1638301944 m057
# ### no ch_drop!
# no data cube for 1638386189, m057
# no data cube for 1638639082, m057
# no data cube for 1638647186, m057
# no data cube for 1638898468, m057
# no data cube for 1639157507, m057
# no data cube for 1639331184, m057
# # cube 1213: 1639935088 m057
# ### no ch_drop!
# no data cube for 1640540184, m057
# no data cube for 1640712986, m057
# no data cube for 1640799689, m057
# # cube 1214: 1630519596 m058
# ### no ch_drop!
# # cube 1215: 1631379874 m058
# ### no ch_drop!
# # cube 1216: 1631387336 m058
# ### no ch_drop!
# # cube 1217: 1631552188 m058
# ### no ch_drop!
# # cube 1218: 1631559762 m058
# ### no ch_drop!
# # cube 1219: 1631659886 m058
# ### no ch_drop!
# # cube 1220: 1631667564 m058
# ### no ch_drop!
# no data cube for 1631724508, m058
# # cube 1221: 1631732038 m058
# ### no ch_drop!
# # cube 1222: 1631810671 m058
# ### no ch_drop!
# # cube 1223: 1631818149 m058
# ### no ch_drop!
# no data cube for 1631982988, m058
# # cube 1224: 1631990463 m058
# ### no ch_drop!
# no data cube for 1632069690, m058
# # cube 1225: 1632077222 m058
# ### no ch_drop!
# # cube 1226: 1632184922 m058
# ### no ch_drop!
# no data cube for 1632505883, m058
# # cube 1227: 1632760885 m058
# ### no ch_drop!
# # cube 1228: 1633365980 m058
# ### no ch_drop!
# no data cube for 1633970780, m058
# # cube 1229: 1634252028 m058
# ### no ch_drop!
# # cube 1230: 1634402485 m058
# ### no ch_drop!
# no data cube for 1634748682, m058
# no data cube for 1634835083, m058
# no data cube for 1637346562, m058
# # cube 1231: 1637354605 m058
# ### no ch_drop!
# no data cube for 1637691677, m058
# # cube 1232: 1637699408 m058
# ### no ch_drop!
# # cube 1233: 1638130295 m058
# ### no ch_drop!
# # cube 1234: 1638294319 m058
# ### no ch_drop!
# # cube 1235: 1638301944 m058
# ### no ch_drop!
# no data cube for 1638386189, m058
# # cube 1236: 1638639082 m058
# ### no ch_drop!
# # cube 1237: 1638647186 m058
# ### no ch_drop!
# # cube 1238: 1638898468 m058
# ### no ch_drop!
# # cube 1239: 1639157507 m058
# ### no ch_drop!
# # cube 1240: 1639331184 m058
# ### no ch_drop!
# # cube 1241: 1639935088 m058
# ### no ch_drop!
# no data cube for 1640540184, m058
# # cube 1242: 1640712986 m058
# ### no ch_drop!
# # cube 1243: 1640799689 m058
# ### no ch_drop!
# # cube 1244: 1630519596 m059
# ### no ch_drop!
# # cube 1245: 1631379874 m059
# ### no ch_drop!
# # cube 1246: 1631387336 m059
# ### no ch_drop!
# # cube 1247: 1631552188 m059
# ### no ch_drop!
# no data cube for 1631559762, m059
# # cube 1248: 1631659886 m059
# ### no ch_drop!
# # cube 1249: 1631667564 m059
# ### no ch_drop!
# # cube 1250: 1631724508 m059
# ### no ch_drop!
# # cube 1251: 1631732038 m059
# ### no ch_drop!
# # cube 1252: 1631810671 m059
# ### no ch_drop!
# no data cube for 1631818149, m059
# no data cube for 1631982988, m059
# # cube 1253: 1631990463 m059
# ### no ch_drop!
# # cube 1254: 1632069690 m059
# ### no ch_drop!
# # cube 1255: 1632077222 m059
# ### no ch_drop!
# # cube 1256: 1632184922 m059
# ### no ch_drop!
# no data cube for 1632505883, m059
# # cube 1257: 1632760885 m059
# ### no ch_drop!
# # cube 1258: 1633365980 m059
# ### no ch_drop!
# no data cube for 1633970780, m059
# # cube 1259: 1634252028 m059
# ### no ch_drop!
# # cube 1260: 1634402485 m059
# ### no ch_drop!
# no data cube for 1634748682, m059
# no data cube for 1634835083, m059
# no data cube for 1637346562, m059
# # cube 1261: 1637354605 m059
# ### no ch_drop!
# no data cube for 1637691677, m059
# # cube 1262: 1637699408 m059
# ### no ch_drop!
# # cube 1263: 1638130295 m059
# ### no ch_drop!
# # cube 1264: 1638294319 m059
# ### no ch_drop!
# # cube 1265: 1638301944 m059
# ### no ch_drop!
# # cube 1266: 1638386189 m059
# ### no ch_drop!
# # cube 1267: 1638639082 m059
# ### no ch_drop!
# # cube 1268: 1638647186 m059
# ### no ch_drop!
# # cube 1269: 1638898468 m059
# ### no ch_drop!
# # cube 1270: 1639157507 m059
# ### no ch_drop!
# no data cube for 1639331184, m059
# # cube 1271: 1639935088 m059
# ### no ch_drop!
# no data cube for 1640540184, m059
# no data cube for 1640712986, m059
# # cube 1272: 1640799689 m059
# ### no ch_drop!
# no data cube for 1630519596, m060
# no data cube for 1631379874, m060
# no data cube for 1631387336, m060
# no data cube for 1631552188, m060
# no data cube for 1631559762, m060
# no data cube for 1631659886, m060
# no data cube for 1631667564, m060
# no data cube for 1631724508, m060
# no data cube for 1631732038, m060
# no data cube for 1631810671, m060
# no data cube for 1631818149, m060
# no data cube for 1631982988, m060
# no data cube for 1631990463, m060
# no data cube for 1632069690, m060
# no data cube for 1632077222, m060
# no data cube for 1632184922, m060
# no data cube for 1632505883, m060
# no data cube for 1632760885, m060
# no data cube for 1633365980, m060
# no data cube for 1633970780, m060
# no data cube for 1634252028, m060
# # cube 1273: 1634402485 m060
# ### no ch_drop!
# no data cube for 1634748682, m060
# no data cube for 1634835083, m060
# no data cube for 1637346562, m060
# # cube 1274: 1637354605 m060
# ### no ch_drop!
# no data cube for 1637691677, m060
# no data cube for 1637699408, m060
# # cube 1275: 1638130295 m060
# ### no ch_drop!
# # cube 1276: 1638294319 m060
# ### no ch_drop!
# # cube 1277: 1638301944 m060
# ### no ch_drop!
# # cube 1278: 1638386189 m060
# ### no ch_drop!
# # cube 1279: 1638639082 m060
# ### no ch_drop!
# # cube 1280: 1638647186 m060
# ### no ch_drop!
# # cube 1281: 1638898468 m060
# ### no ch_drop!
# # cube 1282: 1639157507 m060
# ### no ch_drop!
# no data cube for 1639331184, m060
# no data cube for 1639935088, m060
# no data cube for 1640540184, m060
# # cube 1283: 1640712986 m060
# ### no ch_drop!
# # cube 1284: 1640799689 m060
# ### no ch_drop!
# no data cube for 1630519596, m061
# # cube 1285: 1631379874 m061
# ### no ch_drop!
# no data cube for 1631387336, m061
# # cube 1286: 1631552188 m061
# ### no ch_drop!
# no data cube for 1631559762, m061
# # cube 1287: 1631659886 m061
# ### no ch_drop!
# # cube 1288: 1631667564 m061
# ### no ch_drop!
# no data cube for 1631724508, m061
# no data cube for 1631732038, m061
# no data cube for 1631810671, m061
# no data cube for 1631818149, m061
# no data cube for 1631982988, m061
# no data cube for 1631990463, m061
# no data cube for 1632069690, m061
# # cube 1289: 1632077222 m061
# ### no ch_drop!
# # cube 1290: 1632184922 m061
# ### no ch_drop!
# no data cube for 1632505883, m061
# no data cube for 1632760885, m061
# # cube 1291: 1633365980 m061
# ### no ch_drop!
# no data cube for 1633970780, m061
# no data cube for 1634252028, m061
# # cube 1292: 1634402485 m061
# ### no ch_drop!
# no data cube for 1634748682, m061
# no data cube for 1634835083, m061
# no data cube for 1637346562, m061
# # cube 1293: 1637354605 m061
# ### no ch_drop!
# no data cube for 1637691677, m061
# no data cube for 1637699408, m061
# # cube 1294: 1638130295 m061
# ### no ch_drop!
# # cube 1295: 1638294319 m061
# ### no ch_drop!
# # cube 1296: 1638301944 m061
# ### no ch_drop!
# no data cube for 1638386189, m061
# no data cube for 1638639082, m061
# no data cube for 1638647186, m061
# no data cube for 1638898468, m061
# no data cube for 1639157507, m061
# no data cube for 1639331184, m061
# # cube 1297: 1639935088 m061
# ### no ch_drop!
# no data cube for 1640540184, m061
# no data cube for 1640712986, m061
# no data cube for 1640799689, m061
# # cube 1298: 1630519596 m062
# ### no ch_drop!
# # cube 1299: 1631379874 m062
# ### no ch_drop!
# no data cube for 1631387336, m062
# # cube 1300: 1631552188 m062
# ### no ch_drop!
# # cube 1301: 1631559762 m062
# ### no ch_drop!
# # cube 1302: 1631659886 m062
# ### no ch_drop!
# # cube 1303: 1631667564 m062
# ### no ch_drop!
# no data cube for 1631724508, m062
# # cube 1304: 1631732038 m062
# ### no ch_drop!
# # cube 1305: 1631810671 m062
# ### no ch_drop!
# no data cube for 1631818149, m062
# no data cube for 1631982988, m062
# no data cube for 1631990463, m062
# # cube 1306: 1632069690 m062
# ### no ch_drop!
# # cube 1307: 1632077222 m062
# ### no ch_drop!
# # cube 1308: 1632184922 m062
# ### no ch_drop!
# no data cube for 1632505883, m062
# # cube 1309: 1632760885 m062
# ### no ch_drop!
# no data cube for 1633365980, m062
# no data cube for 1633970780, m062
# # cube 1310: 1634252028 m062
# ### no ch_drop!
# # cube 1311: 1634402485 m062
# ### no ch_drop!
# no data cube for 1634748682, m062
# no data cube for 1634835083, m062
# no data cube for 1637346562, m062
# no data cube for 1637354605, m062
# no data cube for 1637691677, m062
# # cube 1312: 1637699408 m062
# ### no ch_drop!
# # cube 1313: 1638130295 m062
# ### no ch_drop!
# no data cube for 1638294319, m062
# no data cube for 1638301944, m062
# # cube 1314: 1638386189 m062
# ### no ch_drop!
# no data cube for 1638639082, m062
# no data cube for 1638647186, m062
# no data cube for 1638898468, m062
# # cube 1315: 1639157507 m062
# ### no ch_drop!
# # cube 1316: 1639331184 m062
# ### no ch_drop!
# # cube 1317: 1639935088 m062
# ### no ch_drop!
# no data cube for 1640540184, m062
# # cube 1318: 1640712986 m062
# ### no ch_drop!
# no data cube for 1640799689, m062
# no data cube for 1630519596, m063
# no data cube for 1631379874, m063
# # cube 1319: 1631387336 m063
# ### no ch_drop!
# # cube 1320: 1631552188 m063
# ### no ch_drop!
# # cube 1321: 1631559762 m063
# ### no ch_drop!
# # cube 1322: 1631659886 m063
# ### no ch_drop!
# # cube 1323: 1631667564 m063
# ### no ch_drop!
# # cube 1324: 1631724508 m063
# ### no ch_drop!
# # cube 1325: 1631732038 m063
# ### no ch_drop!
# # cube 1326: 1631810671 m063
# ### no ch_drop!
# no data cube for 1631818149, m063
# no data cube for 1631982988, m063
# # cube 1327: 1631990463 m063
# ### no ch_drop!
# no data cube for 1632069690, m063
# # cube 1328: 1632077222 m063
# ### no ch_drop!
# # cube 1329: 1632184922 m063
# ### no ch_drop!
# no data cube for 1632505883, m063
# no data cube for 1632760885, m063
# # cube 1330: 1633365980 m063
# ### no ch_drop!
# no data cube for 1633970780, m063
# # cube 1331: 1634252028 m063
# ### no ch_drop!
# # cube 1332: 1634402485 m063
# ### no ch_drop!
# no data cube for 1634748682, m063
# no data cube for 1634835083, m063
# no data cube for 1637346562, m063
# no data cube for 1637354605, m063
# no data cube for 1637691677, m063
# # cube 1333: 1637699408 m063
# ### no ch_drop!
# # cube 1334: 1638130295 m063
# ### no ch_drop!
# no data cube for 1638294319, m063
# no data cube for 1638301944, m063
# no data cube for 1638386189, m063
# # cube 1335: 1638639082 m063
# ### no ch_drop!
# no data cube for 1638647186, m063
# # cube 1336: 1638898468 m063
# ### no ch_drop!
# # cube 1337: 1639157507 m063
# ### no ch_drop!
# no data cube for 1639331184, m063
# no data cube for 1639935088, m063
# no data cube for 1640540184, m063
# # cube 1338: 1640712986 m063
# ### no ch_drop!
# # cube 1339: 1640799689 m063
# ### no ch_drop!
# 0
# total channel number left: 0
# list for ALL_scan saved
# (array([681]),) [1068.]
# [0. 0. 0. ... 0. 0. 0.]
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:263: RuntimeWarning: invalid value encountered in true_divide
# /usr/local/lib/python3.6/dist-packages/ipykernel/__main__.py:264: RuntimeWarning: invalid value encountered in true_divide
# 1339
# ALL_scan finished, will EXIT soon ...
# ALL_scan finished, will EXIT soon ...
# ALL_scan finished, will EXIT soon ...
# ALL_scan finished, will EXIT soon ...
# ALL_scan finished, will EXIT soon ...
# ALL_scan finished, will EXIT soon ...

# %%
print (n_ch_keep,np.sum(total_count_list))
if n_ch_keep==int(np.sum(total_count_list)):
    print ('# n_ch_keep==np.sum(total_count_list)')
else:
    print ('*** n_ch_keep!=np.sum(total_count_list)')
# Out:
# 0 428025.0
# *** n_ch_keep!=np.sum(total_count_list)

# %% [markdown]
# # reload data to check

# %%
print (pix_deg, std_sigma, i_iter)
# Out:
# 0.3 2.5 0

# %%
total_count=1339
i_iter=0

# %%
input_file2='/idia/projects/hi_im/raw_vis/MeerKLASS2021/level6/'

# %%
Fits0=input_file2+'ALL_scan'+str(total_count)+'_Tsky_cube_p0.3d.fits'
cube0 = fits.open(Fits0)[0].data
print (np.shape(cube0))

Fits1=input_file2+'ALL_scan'+str(total_count)+'_Tresi_cube_p0.3d.fits'
cube1 = fits.open(Fits1)[0].data
print (np.shape(cube1))

Fits2=input_file2+'ALL_scan'+str(total_count)+'_Npix_count_cube_p0.3d.fits'
cube2 = fits.open(Fits2)[0].data
print (np.shape(cube2))

Fits3=input_file2+'ALL_scan'+str(total_count)+'_P_xy_count_p0.3d.fits'
cube3 = fits.open(Fits3)[0].data
print (np.shape(cube3))
# Out:
# (133, 73, 4096)
# (133, 73, 4096)
# (133, 73, 4096)
# (133, 73, 4096)

# %%
w2=WCS(Fits0).dropaxis(-1)
print (w2)
# Out:
# WCS Transformation
#
# This transformation has 2 pixel and 2 world dimensions
#
# Array shape (Numpy order): (133, 73, 4096)
#
# Pixel Dim  Data size  Bounds
#         0       4096  None
#         1         73  None
#
# World Dim  Physical Type  Units
#         0  pos.eq.ra      deg
#         1  pos.eq.dec     deg
#
# Correlation between pixel and world axes:
#
#            Pixel Dim
# World Dim    0    1
#         0  yes  yes
#         1  yes  yes

# %%
#check data
assert((cube0[~np.isnan(cube0)]==Tsky_xy[~np.isnan(Tsky_xy)]).all()==True)
print (np.where(Tsky_xy==np.nanmax(Tsky_xy)), np.nanmax(Tsky_xy))
assert((cube1[~np.isnan(cube1)]==Tresi_xy[~np.isnan(Tresi_xy)]).all()==True)
print (np.where(Tresi_xy==np.nanmax(Tresi_xy)), np.nanmax(Tresi_xy))
# Out:
# (array([92]), array([48]), array([556])) 3.8110466762333837
# (array([92]), array([48]), array([1034])) 0.39779652873407567

# %%
plt.figure(figsize=(18,5))
plt.subplot(projection=w)
plt.grid(color='grey',lw=.1)
plt.imshow(Tsky_xy[:,:,ch_plot].T,cmap=kv.cmap1(),aspect='auto',vmin=2.9,vmax=3.55)
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
#plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
plt.colorbar(label='Kelvin')
plt.xlabel('R. A. (J2000)')
plt.ylabel('Dec (J2000)')
plt.title(r'$\bar T_{sky}$'+' map for '+str(total_count_plot)+' scans, '+str(pix_deg)+' deg/pix, '
                              +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
#plt.savefig('F_Tsky_all_ch'+str(ch_plot)+'_iter'+str(i_iter)+'.pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(18,5))
plt.subplot(projection=w)
plt.grid(color='grey',lw=.1)
plt.imshow(Tresi_xy[:,:,ch_plot].T,cmap=kv.cmap2(),aspect='auto',vmin=-0.25,vmax=0.25)
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
#plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
plt.colorbar(label='Kelvin')
plt.xlabel('R. A. (J2000)')
plt.ylabel('Dec (J2000)')
plt.title(r'$\bar T_{res}$'+' map for '+str(total_count_plot)+' scans, '+str(pix_deg)+' deg/pix, '
                              +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
#plt.savefig('F_Tsky_all_ch'+str(ch_plot)+'_iter'+str(i_iter)+'.pdf', bbox_inches='tight')
plt.show()

# %%
total_count_plot1=total_count

# %%
plt.figure(figsize=(15,5))
ax=plt.subplot(projection=w2)
plt.grid(color='grey',lw=.15)
plt.imshow(cube0[:,:,ch_plot].T,cmap=kv.cmap1(),aspect='auto', vmin=2.9,vmax=3.55)
#plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar(label='Kelvin')
plt.xlabel('R. A. (J2000)',fontsize=16)
plt.ylabel('Dec (J2000)',fontsize=16)
plt.title(r'$\bar T_{sky}$'+' map for '+str(total_count_plot1)+' scans, '+str(pix_deg)+' deg/pix, '
                               +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
plt.xlim([15,Npix_x-15])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
plt.savefig('ALL2.png', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(15,5))
ax=plt.subplot(projection=w2)
plt.grid(color='grey',lw=.15)
plt.imshow(cube1[:,:,ch_plot].T,cmap=kv.cmap2(),aspect='auto', vmin=-0.25,vmax=0.25)
#plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar(label='Kelvin')
plt.xlabel('R. A. (J2000)',fontsize=16)
plt.ylabel('Dec (J2000)',fontsize=16)
plt.title(r'$\bar T_{res}$'+' map for '+str(total_count_plot1)+' scans, '+str(pix_deg)+' deg/pix, '
                                  +str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
plt.xlim([15,Npix_x-15])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
plt.savefig('ALL2.png', bbox_inches='tight')
plt.show()

# %%
aa=cube1[:,:,ch_plot]
aa=aa[~np.isnan(aa)]
print (np.shape(aa))
print (np.mean(aa))
# Out:
# (2784,)
# 0.0002791759702377593

# %%
rms1 = np.sqrt(np.mean(np.square(aa)))
print (rms1)
print (str(round(rms1*1e3,2))+' mK')
# Out:
# 0.047561091805488336
# 47.56 mK

# %%
for ch_i in [ch_plot-1,ch_plot,ch_plot+1,ch_plot+2]:
    plt.figure(figsize=(9,2.5))
    ax=plt.subplot(projection=w2)
    plt.grid(color='grey',lw=.1)
    plt.imshow(cube1[:,:,ch_i].T,cmap=kv.cmap2(),aspect='auto')#, vmin=-0.25,vmax=0.25)
    plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
    plt.colorbar(label='Kelvin')
    plt.xlabel('R. A.')
    plt.ylabel('Dec')
    plt.xlim([0,Npix_x])
    plt.ylim([0,Npix_y])
    plt.title('ch'+str(ch_i))
    ax.invert_xaxis()
    #plt.plot('test B')
    plt.show()

# %%
#ABBA 
bb0=(cube0[:,:,ch_plot]+cube0[:,:,ch_plot+1])/2.-(cube0[:,:,ch_plot-1]+cube0[:,:,ch_plot+2])/2.
bb1=(cube1[:,:,ch_plot]+cube1[:,:,ch_plot+1])/2.-(cube1[:,:,ch_plot-1]+cube1[:,:,ch_plot+2])/2.

# %%
plt.figure(figsize=(18,5))
ax=plt.subplot(projection=w2)
plt.grid(color='grey',lw=.1)
plt.imshow(bb0.T,cmap=kv.cmap2(),aspect='auto')
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar(label='Kelvin')
plt.xlabel('R. A.')
plt.ylabel('Dec')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
#plt.plot('test B')
plt.show()

# %%
plt.figure(figsize=(18,5))
ax=plt.subplot(projection=w2)
plt.grid(color='grey',lw=.1)
plt.imshow(bb1.T,cmap=kv.cmap2(),aspect='auto')
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar(label='Kelvin')
plt.xlabel('R. A.')
plt.ylabel('Dec')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
#plt.plot('test B')
plt.show()

# %%
bb0=bb0[~np.isnan(bb0)]
print (np.shape(bb0))
print (np.mean(bb0))
# Out:
# (2783,)
# 6.078841445436364e-05

# %%
rms2 = np.sqrt(np.mean(np.square(bb0)))
print (rms2)
print (str(round(rms2*1e3,2))+' mK')
# Out:
# 0.00171177346980208
# 1.71 mK

# %%
plt.figure(figsize=(18,5))
plt.subplot(projection=w2)
plt.imshow(cube2[:,:,ch_plot].T,cmap='jet',aspect='auto')
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar()
plt.xlabel('R. A.')
plt.ylabel('Dec')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
plt.show()

# %%
map_2=cube2.copy() #Ncount
map_22=np.ma.array(map_2,mask=True)
map_22.mask[~np.isnan(map_2)]=False
map_22.mask[map_2==0]=True

plt.figure(figsize=(18,5))
ax=plt.subplot(projection=w)
plt.grid(color='grey',lw=.1)
plt.imshow(map_22[:,:,ch_plot].T,cmap='YlOrRd', aspect='auto')
#plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
#plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
plt.colorbar(label='  ')
plt.xlabel('R. A. (J2000)')
plt.ylabel('Dec (J2000)')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
plt.title(r'$N_{count}$'+' map')
plt.savefig('Ncount_'+str(ch_plot)+'_final.pdf', bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(18,5))
plt.subplot(projection=w2)
plt.imshow(cube3[:,:,ch_plot].T,cmap='jet',aspect='auto')
plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
plt.colorbar()
plt.xlabel('R. A.')
plt.ylabel('Dec')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
plt.show()

# %%
map_3=cube3.copy() #Ncount
map_33=np.ma.array(map_3,mask=True)
map_33.mask[~np.isnan(map_3)]=False
map_33.mask[map_3==0]=True

plt.figure(figsize=(18,5))
ax=plt.subplot(projection=w)
plt.grid(color='grey',lw=.1)
plt.imshow(map_33[:,:,ch_plot].T,cmap=kv.cmap3(), aspect='auto')
#plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
#plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
plt.colorbar(label='  ')
plt.xlabel('R. A. (J2000)')
plt.ylabel('Dec (J2000)')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
plt.title(r'$P_{count}$'+' map')
plt.savefig('Pcount_'+str(ch_plot)+'_final.pdf', bbox_inches='tight')
plt.show()

# %%
#test below

# %%
plt.figure(figsize=(8,4))
plt.plot(total_count_list,'.')
plt.plot(ch_plot,total_count_plot,'r*')
plt.xlim(500,1050)
plt.plot([550,550],[150,1350],'k--')
plt.plot([810,810],[150,1350],'k--')
plt.xlabel('channel')
plt.ylabel('scan count')
# Out:
# Text(0,0.5,'scan count')

# %%
print (kio.cal_freq(550)/1e6,kio.cal_freq(810)/1e6)
# Out:
# 970.94140625 1025.27734375

# %%
total_count
# Out:
# 1339

# %%
freqs=kio.cal_freqs(range(4096))

# %%
total_count_list0=np.loadtxt(output_file+'ALL_scan'+str(total_count)+'_list_p'+str(pix_deg)+'d.dat')
#scan_count_list=np.loadtxt('Nscan366_list_p0.3d_sigma2.5_iter2.dat')
scan_count_list=np.loadtxt('ALL_scan1339_list_p0.3d.dat')
plt.figure(figsize=(8,5))
plt.plot([freqs[0]/1e6,freqs[-1]/1e6],[total_count,total_count], 'k--')
plt.plot(freqs/1e6, total_count_list0,'.',color='grey')
plt.plot(freqs/1e6, scan_count_list,'.')
plt.legend(['total number of scans (1339)','number of calibrated scans in each channel', 'number of scans after weak RFI flagging'],fontsize=14)
#plt.ylim(0,530)
plt.xlabel('Frequency (MHz)')
plt.ylabel('Count')
plt.savefig('F_count_comp_final.pdf', bbox_inches='tight')
plt.show()

# %%
for i in range(4096):
    plt.plot(kio.cal_freq(i)/1e6, scan_count_list[i]/total_count,'.')
plt.show()

# %%
a_dat=[]
for i in range(4096):
    a_dat.append([kio.cal_freq(i)/1e6, scan_count_list[i]/total_count])
a_dat=np.array(a_dat)

np.savetxt('freq_MHz_vs_good_scan_ratio.dat',a_dat)

# %%
a_list=np.loadtxt('freq_MHz_vs_good_scan_ratio.dat')

# %%
(a_dat==a_list).all()
# Out:
# True

# %%
plt.plot(a_list[:,0],a_list[:,1],'.')
plt.show()

# %%
#test above

# %% [markdown]
# # the Galactic model

# %%
nside=64 #healpix nside, 64: Mean Spacing (deg) is 0.9161
import pysm
from pysm.nominal import models

# %%
def cal_Gal_pix (pix_ra, pix_dec, freq, nside):
    sky_config = {
        'synchrotron': models("s1", nside),
    }

    sky = pysm.Sky(sky_config)
    
    c = SkyCoord(ra=pix_ra * u.degree, dec=pix_dec * u.degree, frame='icrs')
    theta = 90 - (c.galactic.b / u.degree).value
    phi = (c.galactic.l / u.degree).value
        
    syn = sky.synchrotron(nu=freq/1e9) / 1e6  # K
    I = hp.pixelfunc.get_interp_val(syn[0, :], theta / 180 * np.pi, phi / 180 * np.pi)
        
    return I

# %%
total_count=total_count
model_key=0 #0 for full band count, to achieve a good sky coverage; 
            #1 for Tresi map, to have same coverage as Tresi in certain channel

if model_key==1:
    #Fits='/idia/projects/hi_im/raw_vis/katcali_output/level6_output/p'+str(pix_deg)+'d/p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter)+'/Nscan'+str(total_count)+'_Tresi_cube_p'+str(pix_deg)+'d_sigma'+str(std_sigma)+'_iter'+str(i_iter)+'.fits'
    Fits='ALL_scan1339_Tresi_cube_p0.3d.fits'
    cube = fits.open(Fits)[0].data
    print (np.shape(cube))
    a=np.where(~np.isnan(cube[:,:,ch_plot]))
    print (np.shape(a))
    
if model_key==0:
    #Fits='/idia/projects/hi_im/raw_vis/katcali_output/level6_output/p0.3d/ALL/ALL_scan366_Npix_count_cube_p0.3d.fits'
    Fits='ALL_scan1339_Npix_count_cube_p0.3d.fits'
    cube = fits.open(Fits)[0].data
    print (np.shape(cube))
    #cube1=np.sum(cube,axis=2)
    cube1=cube[:,:,ch_plot]
    a=np.where(cube1>0)
    print (np.shape(a))
# Out:
# (133, 73, 4096)
# (2, 2784)

# %%
pix_list_x=np.array(a[0])
pix_list_y=np.array(a[1])

# %%
pix_radec=pixel_to_skycoord(pix_list_x,pix_list_y,w)
pix_ra,pix_dec=(pix_radec.ra/u.deg).value,(pix_radec.dec/u.deg).value

# %%
gal_pix=np.zeros([Npix_x,Npix_y])
gal_pix[pix_list_x,pix_list_y]=cal_Gal_pix (pix_ra, pix_dec, kio.cal_freq(ch_plot), nside)    

if model_key==1: #1 for Tresi map, to have same coverage as Tresi in certain channel
    gal_pix[np.isnan(cube[:,:,ch_plot])]=np.nan
if model_key==0: #0 for full band count, to achieve a good sky coverage; 
    gal_pix[np.where(cube1==0)]=np.nan

# %%
Tcmb
# Out:
# 2.725

# %%
plt.figure(figsize=(18,5))
ax=plt.subplot(projection=w)
plt.grid(color='grey',lw=.1)
plt.imshow(gal_pix.T,cmap=kv.cmap1(),aspect='auto',vmin=2.9-Tcmb,vmax=3.55-Tcmb)
#plt.plot(ptr_ra_pix,ptr_dec_pix,'mo')
#plt.plot(ptr_ra_pix[22],ptr_dec_pix[22],'mo',ms=12)
plt.colorbar(label='Kelvin')
plt.xlabel('R. A. (J2000)')
plt.ylabel('Dec (J2000)')
plt.title('Galactic model at '+str(int(kio.cal_freq(ch_plot)/1e6))+' MHz')
plt.xlim([0,Npix_x])
plt.ylim([0,Npix_y])
ax.invert_xaxis()
plt.savefig('F_Tgal_model_ch'+str(ch_plot)+'.pdf', bbox_inches='tight')
plt.show()

# %%
print ('end @ ' + time.asctime(time.localtime(time.time())) +'#')
# Out:
# end @ Wed Aug 10 20:30:21 2022#
